# %%
import sys

sys.path.append("/home/weber/PycharmProjects/EXOTIC/src")
from utils.utils import load_config_file, mkdir

yaml = load_config_file(config_file="/home/weber/PycharmProjects/EXOTIC/clean/src/config_clean_clean.yaml")

# %%
import hail as hl
hl.init(min_block_size=128)
import os
import pandas as pd
import subprocess
os.environ['PYSPARK_SUBMIT_ARGS'] = "--driver-memory 200 pyspark-shell"
# !module load java/java-1.8
gs = yaml['4_DEXT']['External']['pext_hail_table']
# gs = "/data/scratch/gnomAD/v3/gnomad.genomes.v3.1.sites.ht/"
data = hl.read_table(gs)
data
# Out:
# Running on Apache Spark version 2.4.1
# SparkUI available at http://vega.local:4041
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.64-1ef70187dc78
# LOGGING: writing to /enadisk/maison/sage2016/weber/PycharmProjects/EXOTIC/notebooks/Hail/hail-20210510-1505-0.2.64-1ef70187dc78.log

# %%
data.show()

# %%
refseq_bed_path = yaml['3_EXONS_PROPERTIES']['TMP']['refseq_bed']
bed_file = hl.import_bed(refseq_bed_path, reference_genome='GRCh37')
bed_file = bed_file.head(10)
bed_file.show()
# Out:
# 2021-05-10 15:06:11 Hail: INFO: Reading table without type imputation
#   Loading field 'f0' as type str (user-supplied)
#   Loading field 'f1' as type int32 (user-supplied)
#   Loading field 'f2' as type int32 (user-supplied)
#   Loading field 'f3' as type str (user-supplied)
# 2021-05-10 15:06:16 Hail: INFO: Ordering unsorted dataset with network shuffle
# +-------------------------+-------------------------+
# | interval                | target                  |
# +-------------------------+-------------------------+
# | interval<locus<GRCh37>> | str                     |
# +-------------------------+-------------------------+
# | [1:901912-1:901994)     | "PLEKHN1_901912-901994" |
# | [1:902084-1:902183)     | "PLEKHN1_902084-902183" |
# | [1:905657-1:905803)     | "PLEKHN1_905657-905803" |
# | [1:905901-1:905981)     | "PLEKHN1_905901-905981" |
# | [1:906066-1:906138)     | "PLEKHN1_906066-906138" |
# | [1:906259-1:906386)     | "PLEKHN1_906259-906386" |
# | [1:906457-1:906588)     | "PLEKHN1_906457-906588" |
# | [1:906493-1:906588)     | "PLEKHN1_906493-906588" |
# | [1:906704-1:906784)     | "PLEKHN1_906704-906784" |
# | [1:907455-1:907530)     | "PLEKHN1_907455-907530" |
# +-------------------------+-------------------------+

# %%
data_lite = data.filter(hl.is_defined(bed_file[data.locus]))
data_lite = data_lite.annotate(
    MAP = bed_file[data_lite.locus].target,
    Gene = hl.str(bed_file[data_lite.locus].target).split('_')[0],
)
data_lite.show()
# Out:
# 2021-05-10 15:06:28 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2021-05-10 15:06:33 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2021-05-10 15:06:37 Hail: INFO: Ordering unsorted dataset with network shuffle
# +-------------------+---------------+-----------+------------------------------+----------+----------+--------------------------+------------------------------+--------------------+-----------------+
# | ensg              | locus         | symbol    | Cells_Transformedfibroblasts | Prostate |   Spleen | Brain_FrontalCortex_BA9_ | SmallIntestine_TerminalIleum | MinorSalivaryGland | Artery_Coronary |
# +-------------------+---------------+-----------+------------------------------+----------+----------+--------------------------+------------------------------+--------------------+-----------------+
# | str               | locus<GRCh37> | str       |                      float64 |  float64 |  float64 |                  float64 |                      float64 |            float64 |         float64 |
# +-------------------+---------------+-----------+------------------------------+----------+----------+--------------------------+------------------------------+--------------------+-----------------+
# | "ENSG00000187583" | 1:901912      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901913      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901914      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901915      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901916      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901917      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901918      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901919      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901920      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901921      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901922      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901923      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901924      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901925      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901926      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901927      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901928      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901929      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901930      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901931      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901932      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901933      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901934      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901935      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901936      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901937      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901938      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901939      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901940      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901941      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901942      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901943      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901944      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901945      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901946      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901947      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901948      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# | "ENSG00000187583" | 1:901949      | "PLEKHN1" |                     1.00e+00 | 9.65e-01 | 1.00e+00 |                      NaN |                     1.00e+00 |           9.21e-01 |        1.00e+00 |
# +-------------------+---------------+-----------+------------------------------+----------+----------+--------------------------+------------------------------+--------------------+-----------------+
#
# +---------------------------+----------------------------------+-------------------+----------------------+--------------------------------------+---------------+--------------------+
# | Skin_SunExposed_Lowerleg_ | Cells_EBV_transformedlymphocytes | Brain_Hippocampus | Esophagus_Muscularis | Brain_Nucleusaccumbens_basalganglia_ | Artery_Tibial | Brain_Hypothalamus |
# +---------------------------+----------------------------------+-------------------+----------------------+--------------------------------------+---------------+--------------------+
# |                   float64 |                          float64 |           float64 |              float64 |                              float64 |       float64 |            float64 |
# +---------------------------+----------------------------------+-------------------+----------------------+--------------------------------------+---------------+--------------------+
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# |                  9.06e-01 |                         9.23e-01 |               NaN |             1.00e+00 |                                  NaN |      1.00e+00 |                NaN |
# +---------------------------+----------------------------------+-------------------+----------------------+--------------------------------------+---------------+--------------------+
#
# +---------------------------+-------------------+-------------------------------+----------------------------+--------------+----------------------+----------+--------------------------------+--------------+
# | Adipose_Visceral_Omentum_ | Cervix_Ectocervix | Brain_Spinalcord_cervicalc_1_ | Brain_CerebellarHemisphere | Nerve_Tibial | Breast_MammaryTissue |    Liver | Skin_NotSunExposed_Suprapubic_ | AdrenalGland |
# +---------------------------+-------------------+-------------------------------+----------------------------+--------------+----------------------+----------+--------------------------------+--------------+
# |                   float64 |           float64 |                       float64 |                    float64 |      float64 |              float64 |  float64 |                        float64 |      float64 |
# +---------------------------+-------------------+-------------------------------+----------------------------+--------------+----------------------+----------+--------------------------------+--------------+
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# |                  1.00e+00 |          8.46e-01 |                           NaN |                        NaN |     1.00e+00 |             1.00e+00 | 1.00e+00 |                       9.09e-01 |     1.00e+00 |
# +---------------------------+-------------------+-------------------------------+----------------------------+--------------+----------------------+----------+--------------------------------+--------------+
#
# +----------+----------+----------+---------------+-----------+-----------------+------------------+--------------+-----------------------+----------------------+------------------+---------------------+
# |   Vagina | Pancreas |     Lung | FallopianTube | Pituitary | Muscle_Skeletal | Colon_Transverse | Artery_Aorta | Heart_AtrialAppendage | Adipose_Subcutaneous | Esophagus_Mucosa | Heart_LeftVentricle |
# +----------+----------+----------+---------------+-----------+-----------------+------------------+--------------+-----------------------+----------------------+------------------+---------------------+
# |  float64 |  float64 |  float64 |       float64 |   float64 |         float64 |          float64 |      float64 |               float64 |              float64 |          float64 |             float64 |
# +----------+----------+----------+---------------+-----------+-----------------+------------------+--------------+-----------------------+----------------------+------------------+---------------------+
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# | 9.32e-01 | 1.00e+00 | 1.00e+00 |      1.00e+00 |  1.00e+00 |        1.00e+00 |         1.00e+00 |     1.00e+00 |              1.00e+00 |             1.00e+00 |         9.06e-01 |            1.00e+00 |
# +----------+----------+----------+---------------+-----------+-----------------+------------------+--------------+-----------------------+----------------------+------------------+---------------------+
#
# +------------------+--------------+----------+-----------------------+---------------+----------+----------+------------+----------+-------------------------------------+-----------------------------+
# | Brain_Cerebellum | Brain_Cortex |  Thyroid | Brain_Substantianigra | Kidney_Cortex |   Uterus |  Stomach | WholeBlood |  Bladder | Brain_Anteriorcingulatecortex_BA24_ | Brain_Putamen_basalganglia_ |
# +------------------+--------------+----------+-----------------------+---------------+----------+----------+------------+----------+-------------------------------------+-----------------------------+
# |          float64 |      float64 |  float64 |               float64 |       float64 |  float64 |  float64 |    float64 |  float64 |                             float64 |                     float64 |
# +------------------+--------------+----------+-----------------------+---------------+----------+----------+------------+----------+-------------------------------------+-----------------------------+
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# |              NaN |          NaN | 1.00e+00 |                   NaN |      1.00e+00 | 1.00e+00 | 1.00e+00 |   1.00e+00 | 9.15e-01 |                                 NaN |                         NaN |
# +------------------+--------------+----------+-----------------------+---------------+----------+----------+------------+----------+-------------------------------------+-----------------------------+
#
# +-----------------------------+---------------+-------------------+---------+------------------------------------+----------+----------------+-----------------+-------------------------+-----------+
# | Brain_Caudate_basalganglia_ | Colon_Sigmoid | Cervix_Endocervix |   Ovary | Esophagus_GastroesophagealJunction |   Testis | Brain_Amygdala | mean_proportion | MAP                     | Gene      |
# +-----------------------------+---------------+-------------------+---------+------------------------------------+----------+----------------+-----------------+-------------------------+-----------+
# |                     float64 |       float64 |           float64 | float64 |                            float64 |  float64 |        float64 |         float64 | str                     | str       |
# +-----------------------------+---------------+-------------------+---------+------------------------------------+----------+----------------+-----------------+-------------------------+-----------+
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# |                         NaN |           NaN |          1.00e+00 |     NaN |                           1.00e+00 | 7.87e-01 |            NaN |        9.74e-01 | "PLEKHN1_901912-901994" | "PLEKHN1" |
# +-----------------------------+---------------+-------------------+---------+------------------------------------+----------+----------------+-----------------+-------------------------+-----------+
# showing top 38 rows

# %%
table_result = (data_lite.group_by('MAP').aggregate(Cells_Transformedfibroblasts_mean = hl.agg.mean(data_lite.Cells_Transformedfibroblasts)))
table_result.show()
# Out:
# 2021-05-10 15:06:50 Hail: INFO: Ordering unsorted dataset with network shuffle
# 2021-05-10 15:06:54 Hail: INFO: Ordering unsorted dataset with network shuffle
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-8c0e1b285ace>", line 2, in <module>
#     table_result.show()
#   File "<decorator-gen-1105>", line 2, in show
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py", line 577, in wrapper
#     return __original_func(*args_, **kwargs_)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1507, in show
#     handler(self._show(n, width, truncate, types))
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/display.py", line 313, in display
#     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py", line 180, in format
#     data = formatter(obj)
#   File "<decorator-gen-10>", line 2, in __call__
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py", line 224, in catch_format_error
#     r = method(self, *args, **kwargs)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py", line 702, in __call__
#     printer.pretty(obj)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/lib/pretty.py", line 394, in pretty
#     return _repr_pprint(obj, self, cycle)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/lib/pretty.py", line 700, in _repr_pprint
#     output = repr(obj)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1297, in __repr__
#     return self.__str__()
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1294, in __str__
#     return self._ascii_str()
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1320, in _ascii_str
#     rows, has_more, dtype = self.data()
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1304, in data
#     rows, has_more = t._take_n(self.n)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1451, in _take_n
#     rows = self.take(n + 1)
#   File "<decorator-gen-1117>", line 2, in take
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py", line 577, in wrapper
#     return __original_func(*args_, **kwargs_)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 2121, in take
#     return self.head(n).collect(_localize)
#   File "<decorator-gen-1111>", line 2, in collect
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py", line 577, in wrapper
#     return __original_func(*args_, **kwargs_)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py", line 1920, in collect
#     return Env.backend().execute(e._ir)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/hail/backend/py4j_backend.py", line 74, in execute
#     result = json.loads(self._jhc.backend().executeJSON(jir))
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py", line 1255, in __call__
#     answer = self.gateway_client.send_command(command)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py", line 985, in send_command
#     response = connection.send_command(command)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py", line 1152, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/home/weber/.conda/envs/hail/lib/python3.6/socket.py", line 586, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/weber/.conda/envs/hail/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/weber/.conda/envs/hail/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-5-8c0e1b285ace> in <module>
#       1 table_result = (data_lite.group_by('MAP').aggregate(Cells_Transformedfibroblasts_mean = hl.agg.mean(data_lite.Cells_Transformedfibroblasts)))
# ----> 2 table_result.show()
#
# <decorator-gen-1105> in show(self, n, width, truncate, types, handler, n_rows)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     576         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 577         return __original_func(*args_, **kwargs_)
#     578
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in show(***failed resolving arguments***)
#    1506             handler = hl.utils.default_handler()
# -> 1507         handler(self._show(n, width, truncate, types))
#    1508
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#
# <decorator-gen-10> in __call__(self, obj)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in __repr__(self)
#    1296         def __repr__(self):
# -> 1297             return self.__str__()
#    1298
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in __str__(self)
#    1293         def __str__(self):
# -> 1294             return self._ascii_str()
#    1295
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in _ascii_str(self)
#    1319
# -> 1320             rows, has_more, dtype = self.data()
#    1321             fields = list(dtype)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in data(self)
#    1303                 t = t.select(**{k: hl._showstr(v) for (k, v) in t.row.items()})
# -> 1304                 rows, has_more = t._take_n(self.n)
#    1305                 self._data = (rows, has_more, row_dtype)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in _take_n(self, n)
#    1450         else:
# -> 1451             rows = self.take(n + 1)
#    1452             has_more = len(rows) > n
#
# <decorator-gen-1117> in take(self, n, _localize)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     576         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 577         return __original_func(*args_, **kwargs_)
#     578
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in take(self, n, _localize)
#    2120
# -> 2121         return self.head(n).collect(_localize)
#    2122
#
# <decorator-gen-1111> in collect(self, _localize)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/typecheck/check.py in wrapper(__original_func, *args, **kwargs)
#     576         args_, kwargs_ = check_all(__original_func, args, kwargs, checkers, is_method=is_method)
# --> 577         return __original_func(*args_, **kwargs_)
#     578
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/table.py in collect(self, _localize)
#    1919         if _localize:
# -> 1920             return Env.backend().execute(e._ir)
#    1921         else:
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/hail/backend/py4j_backend.py in execute(self, ir, timed)
#      73         try:
# ---> 74             result = json.loads(self._jhc.backend().executeJSON(jir))
#      75             value = ir.typ._from_json(result['value'])
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#
# ~/.conda/envs/hail/lib/python3.6/socket.py in readinto(self, b)
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2045                     except Exception:
#    2046                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2047                                             value, tb, tb_offset=tb_offset)
#    2048
#    2049                     self._showtraceback(etype, value, stb)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1434             self.tb = tb
#    1435         return FormattedTB.structured_traceback(
# -> 1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#    1438
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1334             # Verbose modes need a full traceback
#    1335             return VerboseTB.structured_traceback(
# -> 1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#    1338         elif mode == 'Minimal':
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1191
#    1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1193                                                                tb_offset)
#    1194
#    1195         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.conda/envs/hail/lib/python3.6/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     449     # first frame (from in to out) that looks different.
#     450     if not is_recursion_error(etype, value, records):
# --> 451         return len(records), 0
#     452
#     453     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()
