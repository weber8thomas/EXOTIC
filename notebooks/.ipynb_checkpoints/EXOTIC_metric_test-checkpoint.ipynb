# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))
c = [0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502] + [0.525]
c = c[:10] + [0.525]
print(len(c))
print(c)
print(np.mean(c))
print(np.std(c))
print(list(map(sigmoid, zscore(c))))
zscore(c)
# Out:
# 11
# [0.5, 0.501, 0.502, 0.499, 0.498, 0.502, 0.5, 0.501, 0.502, 0.499, 0.525]
# 0.5026363636363637
# 0.00718929415264275
# [0.4093369941977992, 0.4433416048701954, 0.4778855734485415, 0.37617800961097286, 0.34414011104475467, 0.4778855734485415, 0.4093369941977992, 0.4433416048701954, 0.4778855734485415, 0.37617800961097286, 0.9573313845611352]
# array([-0.36670688, -0.22761117, -0.08851545, -0.50580259, -0.64489831,
#        -0.08851545, -0.36670688, -0.22761117, -0.08851545, -0.50580259,
#         3.11068596])

# %%
import math

def sigmoid(x):
  return 1 / (1 + math.exp(-x))
def norm(x):
    min_x = min(x)
    max_x = max(x)
    return [(e - min_x)/(max_x - min_x) for e in x]

def std(x):
    mean = np.mean(x)
    std = np.std(x)
    return [(e - std)/(mean) for e in x]

def luc(x):
    min_x = min(x)
    return [sigmoid((e+min_x)**2) for e in x]

    
# c = [0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502, 0.5,0.501,0.502,0.499,0.498,0.502,0.5,0.501,0.502] + [0.525]
c2 = [0.5]*50 + [0.75]
# c_modified = luc(c)
c_square = [e**2 for e in c]
c2_square = [np.exp(e) for e in c2]

# c = c[:10] + [0.525]
for test in [c2]:
    print(test)
    print(len(test))
    print(test)
    print(np.mean(test))
    print(np.std(test))
    print(list(map(sigmoid, zscore(test))))
    print(zscore(test))
#     print(luc(zscore(test)))
    print('\n')
# Out:
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75]
# 51
# [0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.75]
# 0.5049019607843137
# 0.034662097116987624
# ...
