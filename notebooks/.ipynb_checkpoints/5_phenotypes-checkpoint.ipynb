# %%
# General imports
import os
import sys
import pandas as pd

pd.options.mode.chained_assignment = None  # default='warn'
import numpy as np
import subprocess

# Other imports
import multiprocessing
import parmap
import collections
from tqdm import tqdm

tqdm.pandas()

import json
from pandarallel import pandarallel

pandarallel.initialize(nb_workers=60, progress_bar=True)
from pprint import pprint

# Custom utils
sys.path.append("/home/weber/PycharmProjects/EXOTIC/src")
from utils.utils import load_config_file

# Figures imports
import matplotlib

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from statannot import add_stat_annotation
import matplotlib.font_manager as font_manager

# Font settings
font_dirs = ['/home/weber/Fonts', ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rcParams['font.weight'] = 'light'

## YAML FILES CONFIG
files = load_config_file(config_file="/home/weber/PycharmProjects/EXOTIC/src/config_clean.yaml")

dicts = json.load(open("/home/weber/PycharmProjects/EXOTIC/src/EXOTIC_config.json"))
# Out:
# INFO: Pandarallel will run on 60 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/ipykernel_launcher.py:40: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.

# %% [markdown]
# # Phenotypes

# %% [markdown]
# ## OMIM raw file

# %%
omim_raw = pd.read_csv('/gstock/EXOTIC/data/PHENOTYPES/mim2gene.txt', sep='\t', skiprows=4)
omim_raw.columns = ['MIM', 'Type', 'Gene_ID', 'HGNC_symbol', 'ENSG']
omim_raw = omim_raw.loc[omim_raw['Type'] == 'gene']
omim_raw = omim_raw.drop_duplicates().sort_values(by='HGNC_symbol')
omim_raw = omim_raw.dropna(subset=['HGNC_symbol'])
omim_raw
# Out:
#           MIM  Type   Gene_ID HGNC_symbol             ENSG
# 1689   138670  gene       1.0        A1BG  ENSG00000121410
# 26052  618199  gene   29974.0        A1CF  ENSG00000148584
# 152    103950  gene       2.0         A2M  ENSG00000175899
# 18484  610627  gene  144568.0       A2ML1  ENSG00000166535
# 15779  607922  gene   53947.0      A4GALT  ENSG00000128274
# ...       ...   ...       ...         ...              ...
# 6501   300236  gene  158586.0        ZXDB  ENSG00000198455
# 23601  615746  gene   79364.0        ZXDC  ENSG00000070476
# 26527  618675  gene  440590.0      ZYG11A  ENSG00000203995
# 26525  618673  gene   79699.0      ZYG11B  ENSG00000162378
# 9859   602002  gene    7791.0         ZYX  ENSG00000159840
#
# [16139 rows x 5 columns]

# %%
omim_pheno = pd.read_csv('/gstock/EXOTIC/data/PHENOTYPES/genemap2.txt', sep='\t', skiprows=3)

omim_pheno.columns = ['CHR', 'Start', 'End', 'Cyto', 'Computed_cyto', 'MIM', 'Gene_symbol', 'Gene_descr', 'Approved_symbol', 'Gene_ID', 'ENSG', 'Comments', 'Phenotype', 'Mouse_gene_ID']
omim_pheno = omim_pheno.loc[(omim_pheno['MIM'].isna() == False) & (omim_pheno['Phenotype'].isna() == False)]
omim_pheno['Phenotype'] = omim_pheno['Phenotype'].astype(str)

omim_pheno = omim_pheno.loc[(omim_pheno['ENSG'].isna() == False)]
omim_pheno['MIM'] = omim_pheno['MIM'].astype(int)
# omim_pheno['Gene_symbol'] = omim_pheno['Gene_symbol'].apply(lambda r: r.split(',')[0])
# omim_pheno = omim_pheno.loc[omim_pheno['Phenotype'].str.contains('\[')]
# omim_raw = omim_raw.loc[omim_raw['Type'] == 'gene']
# omim_raw = omim_raw.drop_duplicates().sort_values(by='HGNC_symbol')
# omim_raw = omim_raw.dropna(subset=['HGNC_symbol'])
omim_pheno
# Out:
#         CHR        Start          End         Cyto Computed_cyto     MIM  \
# 22     chr1    1013496.0    1014539.0      1p36.33       1p36.33  147571
# 23     chr1    1020101.0    1056118.0    1pter-p32       1p36.33  103320
# 28     chr1    1211325.0    1216811.0         1p36       1p36.33  600315
# 30     chr1    1232236.0    1235040.0       1p36.3       1p36.33  615291
# 36     chr1    1335277.0    1349417.0         1p36       1p36.33  601365
# ...     ...          ...          ...          ...           ...     ...
# 17060  chrX  155489010.0  155612951.0         Xq28          Xq28  300777
# 17075  chrY     624343.0     659410.0  Ypter-p11.2        Yp11.2  400020
# 17084  chrY    2786854.0    2787681.0       Yp11.3        Yp11.2  480000
# 17090  chrY    6908593.0    7107153.0       Yp11.2        Yp11.2  400033
# 17096  chrY   12701230.0   12860838.0       Yq11.2      Yq11.221  400005
#
#                                Gene_symbol  \
# 22               ISG15, G1P2, IFI15, IMD38
# 23                              AGRN, CMS8
# 28     TNFRSF4, TXGP1L, OX40, ACT35, IMD16
# 30        B3GALT6, SEMDJL1, EDSSPD2, ALGAZ
# 36                              DVL1, DRS2
# ...                                    ...
# 17060   TMLHE, BBOX2, TMLH, TMLHED, AUTSX6
# 17075                                SHOXY
# 17084          SRY, TDF, TDY, SRXX1, SRXY1
# 17090                         TBL1Y, DFNY2
# 17096                 USP9Y, DFFRY, SPGFY2
#
#                                               Gene_descr Approved_symbol  \
# 22                         ISG15 ubiquitin-like modifier           ISG15
# 23                                                 Agrin            AGRN
# 28     Tumor necrosis factor receptor superfamily, me...         TNFRSF4
# 30     UDP-Gal:beta-Gal beta-1,3-galactosyltransferas...         B3GALT6
# 36                Dishevelled segment polarity protein 1            DVL1
# ...                                                  ...             ...
# 17060                Epsilon-trimethyllysine hydroxylase           TMLHE
# 17075                  Short stature homeo box, Y-linked            SHOX
# 17084  Sex-determining region Y (testis determining f...             SRY
# 17090                   Transducin-beta-like 1, Y-linked           TBL1Y
# 17096  Ubiquitin-specific protease-9, Y chromosome (D...           USP9Y
#
#         Gene_ID             ENSG                               Comments  \
# 22       9636.0  ENSG00000187608                                    NaN
# 23     375790.0  ENSG00000188157                                    NaN
# 28       7293.0  ENSG00000186827  mutation identified in 1 IMD16 family
# 30     126792.0  ENSG00000176022                                    NaN
# 36       1855.0  ENSG00000107404                                    NaN
# ...         ...              ...                                    ...
# 17060   55217.0  ENSG00000185973                                    NaN
# 17075    6473.0  ENSG00000185960                        pseudoautosomal
# 17084    6736.0  ENSG00000184895                                    NaN
# 17090   90665.0  ENSG00000092377  mutation identified in 1 DFNY2 family
# 17096    8287.0  ENSG00000114374                                    NaN
#
#                                                Phenotype  \
# 22     Immunodeficiency 38, 616126 (3), Autosomal rec...
# 23     Myasthenic syndrome, congenital, 8, with pre- ...
# 28     ?Immunodeficiency 16, 615593 (3), Autosomal re...
# 30     Al-Gazali syndrome, 609465 (3); Ehlers-Danlos ...
# 36     Robinow syndrome, autosomal dominant 2, 616331...
# ...                                                  ...
# 17060  {Autism, susceptibility to, X-linked 6}, 30087...
# 17075  Leri-Weill dyschondrosteosis, 127300 (3), Pseu...
# 17084  46XY sex reversal 1, 400044 (3), Y-linked; 46X...
# 17090        ?Deafness, Y-linked 2, 400047 (3), Y-linked
# 17096  Spermatogenic failure, Y-linked, 2, 415000 (3)...
#
#                Mouse_gene_ID
# 22       Isg15 (MGI:1855694)
# 23          Agrn (MGI:87961)
# 28      Tnfrsf4 (MGI:104512)
# 30     B3galt6 (MGI:2152819)
# 36          Dvl1 (MGI:94941)
# ...                      ...
# 17060    Tmlhe (MGI:2180203)
# 17075                    NaN
# 17084                    NaN
# 17090                    NaN
# 17096    Usp9y (MGI:1313274)
#
# [4310 rows x 14 columns]

# %%
omim_pheno.ENSG.nunique()

# %% [markdown]
# ## Processed phenotypes through API

# %%
from Phenotypes import omim_associations_exotic
omim = omim_associations_exotic.load_omim(files["EXOTIC"]["omim_detailed"], files["BIOMART"]["biomart_omim"])
# omim.head()
omim

# %%
omim

# %%
omim.OMIM.nunique()

# %% [markdown]
# ## OMIM entries with multiple phenotypes & at least one rare

# %%
def load_omim(omim_path, biomart_omim_path):
    omim = pd.read_csv(
        omim_path,
        compression="gzip",
        sep="\t",
    )
#     return omim

    print("Total : ", omim.OMIM.nunique())
    omim = omim.dropna(subset=list(omim.columns[6:-2]), how="all")
    print("Dropna on all cols : ", omim.OMIM.nunique())

    biomart_omim = pd.read_csv(biomart_omim_path, sep="\t", compression="gzip").dropna(subset=["MIM gene accession"])
    biomart_omim["MIM gene accession"] = biomart_omim["MIM gene accession"].astype(int)
    biomart_omim = biomart_omim.rename({"MIM gene accession": "OMIM", "Gene stable ID": "ensg", "Gene name": "Name"}, axis=1)

    ## ADD Gene TO OMIM
    omim = pd.merge(biomart_omim[["ensg", "Name", "OMIM"]], omim, on="OMIM")
    print("Merge BIOMART : ", omim.OMIM.nunique())


    # MELT
    omim = omim.melt(id_vars=list(omim.columns)[:7], value_vars=list(omim.columns)[7:], var_name="OMIM_BP", value_name="OMIM_BP_phenotypes").dropna()

    return omim
omim = load_omim(files["EXOTIC"]["omim_detailed"], files["BIOMART"]["biomart_omim"])
omim

# %%
l = list()
for gene in tqdm(omim.Name.unique()):

    gene_omim = omim.loc[omim['Name'] == gene]
    if gene_omim.Pheno_OMIM.nunique() > 1:
#         print(gene, gene_omim.shape[0])
        gene_omim_bp = gene_omim[['Name', 'Pheno_OMIM', 'OMIM_BP']].groupby(['Name', 'Pheno_OMIM'])['OMIM_BP'].apply(set).reset_index()
        counter_pheno = collections.Counter([sub_e for e in gene_omim_bp['OMIM_BP'].values.tolist() for sub_e in e])
        counter_pheno_rare = [k for k,v in counter_pheno.items() if v == 1]
        l.append(gene_omim.loc[gene_omim['OMIM_BP'].isin(counter_pheno_rare)])
        
#         for pheno_rare in counter_pheno_rare:
#             print(gene_omim.loc[gene_omim['OMIM_BP'] == pheno_rare, ['Pheno_OMIM', 'Pheno_prefered_title', 'OMIM_BP', 'OMIM_BP_phenotypes']].values.tolist())
omim_multi_pheno_filterred = pd.concat(l)
omim_multi_pheno_filterred

# %%
omim_multi_pheno_filterred.loc[(omim_multi_pheno_filterred['Name'] == 'NF1') & (omim_multi_pheno_filterred['OMIM_BP'] == 'genitourinaryInternalGenitaliaMale'), 'OMIM_BP_phenotypes'].values.tolist()[0]

# %%
omim_multi_pheno_filterred.loc[(omim_multi_pheno_filterred['Name'] == 'NF1'), 'OMIM_BP_phenotypes'].values.tolist()[4]

# %%
omim_multi_pheno_filterred.Name.nunique()

# %%
for col in ['ensg', 'Name', 'OMIM']:
    print(col, omim[col].nunique())

# %% [markdown]
# ## EXOTIC imports

# %%
exotic = pd.read_parquet(files["EXOTIC"]["exotic_modified_zscore"])
exotic[['Exon_start', 'Exon_stop']] = exotic['Exon'].str.split('-', expand=True)
# exotic_up = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'up', cutoff=0.5)
# exotic_down = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'down', cutoff=0.5)

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.rcParams.update({"font.size" : 17})
venn2([set(exotic.symbol.unique().tolist()), set(omim_pheno.Approved_symbol.unique().tolist())], set_labels=['EXOTIC genes', 'OMIM genes with phenotypes'], set_colors=['purple', 'skyblue'], alpha=0.5)

# %%
omim

# %%
def compare_to_omim_basic_exon_level(exotic, min_max, omim, omim_detailed=True):
    print(min_max)
    print(exotic.symbol.nunique())
    print(exotic.MAP.nunique())

    mapping_omim_gtex = dicts["mapping_omim_gtex_detailed"]

    omim = omim.where(pd.notnull(omim), None)

    omim = omim.loc[~omim.duplicated(keep="last", subset=["OMIM", "Pheno_OMIM", "Pheno_prefered_title"])]

#     print(omim)

#     print(exotic)

    merge = pd.merge(omim, exotic, on="ensg")
    merge["EXOTIC_tissue_BP"] = merge["EXOTIC_tissues_above_cutoff_{}".format(min_max)].map(mapping_omim_gtex)
    merge = merge.explode("EXOTIC_tissue_BP")
    merge = merge[
        [
            "ensg",
            "symbol",
            "MAP",
            "OMIM",
            "OMIM_BP",
            "OMIM_BP_phenotypes",
            "EXOTIC_tissues_above_cutoff_{}".format(min_max),
            "EXOTIC_{}".format(min_max),
            "EXOTIC_bins_{}".format(min_max),
            "EXOTIC_tissue_BP",
        ]
    ]

#     print(merge)
    print(merge.loc[merge["OMIM_BP"] == merge["EXOTIC_tissue_BP"], 'symbol'].nunique())
    print(merge.loc[merge["OMIM_BP"] == merge["EXOTIC_tissue_BP"], 'MAP'].nunique())

# %%
compare_to_omim_basic_exon_level(exotic_up, 'up', omim)

# %%
compare_to_omim_basic_exon_level(exotic_down, 'down', omim)

# %% [markdown]
# # Clinvar

# %%
clinvar = pd.read_parquet(files['EXOTIC']['clinvar_file_path'])
clinvar = clinvar.loc[(clinvar['Status'] == 'Pathogenic') & (clinvar['Real_Status'].str.contains('onflict') == False)]
# clinvar = clinvar.loc[clinvar['OMIM_VARIANT_ID'] != ""]
# clinvar['ALT_Lite'] = clinvar['ALT'].apply(lambda r: eval(r)[0]) 
# clinvar['VAR_ID_Lite'] = clinvar['CHROM'].astype(str) + '_' + clinvar['POS'].astype(str) + '_' + clinvar['REF'].astype(str) + '_' + clinvar['ALT_Lite'].astype(str)

clinvar
# Out:
#           GENE             VAR_ID CHROM     POS REF     ALT  \
# 79      SAMD11   1_879375_C_['T']     1  879375   C   ['T']
# 105     KLHL17   1_899892_C_['A']     1  899892   C   ['A']
# 125      ISG15   1_949523_C_['T']     1  949523   C   ['T']
# 138      ISG15  1_949696_C_['CG']     1  949696   C  ['CG']
# 141      ISG15   1_949739_G_['T']     1  949739   G   ['T']
# ...        ...                ...   ...     ...  ..     ...
# 770451  MT-CYB   MT_15637_C_['T']    MT   15637   C   ['T']
# 770457  MT-CYB   MT_15649_A_['G']    MT   15649   A   ['G']
# 770467  MT-CYB   MT_15670_T_['C']    MT   15670   T   ['C']
# 770470  MT-CYB   MT_15682_A_['G']    MT   15682   A   ['G']
# 770493  MT-CYB   MT_15784_T_['C']    MT   15784   T   ['C']
#
#                         MC      Status        Real_Status  RS_STARS  \
# 79                nonsense  Pathogenic         Pathogenic         1
# 105       missense_variant  Pathogenic  Likely_pathogenic         0
# 125               nonsense  Pathogenic         Pathogenic         0
# 138     frameshift_variant  Pathogenic         Pathogenic         0
# 141               nonsense  Pathogenic         Pathogenic         0
# ...                    ...         ...                ...       ...
# 770451  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770457  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770467  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770470  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770493  synonymous_variant  Pathogenic  Likely_pathogenic         0
#
#                                  CLNREVSTAT           HPO         rs  \
# 79      criteria_provided,_single_submitter            []       None
# 105          no_assertion_criteria_provided  [HP:0002575]       None
# 125          no_assertion_criteria_provided            []  786201005
# 138          no_assertion_criteria_provided            []  672601345
# 141          no_assertion_criteria_provided            []  672601312
# ...                                     ...           ...        ...
# 770451       no_assertion_criteria_provided            []  527236190
# 770457       no_assertion_criteria_provided            []  527236191
# 770467       no_assertion_criteria_provided  [HP:0100615]  193302997
# 770470       no_assertion_criteria_provided            []  527236192
# 770493       no_assertion_criteria_provided            []  527236194
#
#         alleleid OMIM_VARIANT_ID
# 79        929884
# 105       904889
# 125       181485     147571.0003
# 138       171289     147571.0002
# 141       171288     147571.0001
# ...          ...             ...
# 770451    153620
# 770457    153621
# 770467    153650
# 770470    153622
# 770493    153624
#
# [126006 rows x 15 columns]

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.rcParams.update({"font.size" : 17})
venn2([
    set(exotic.symbol.unique().tolist()), 
    set(clinvar.GENE.unique().tolist())
], 
    set_labels=['EXOTIC genes', 'ClinVar Pathogenic (RV)'], 
    set_colors=['purple', 'green'], alpha=0.5)

# %%
from matplotlib_venn import venn2
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.rcParams.update({"font.size" : 17})
venn2([
    set(omim_pheno.Approved_symbol.unique().tolist()),
    set(clinvar.GENE.unique().tolist())
], 
    set_labels=['OMIM genes with phenotypes', 'ClinVar Pathogenic (RV)'], 
    set_colors=['skyblue', 'green'], alpha=0.5)

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.rcParams.update({"font.size" : 17})
venn3([
    set(exotic.symbol.unique().tolist()), 
    set(omim_pheno.Approved_symbol.unique().tolist()),
    set(clinvar.GENE.unique().tolist())
], 
    set_labels=['EXOTIC genes', 'OMIM genes with phenotypes', 'ClinVar (P/LP with OMIM IDs)'], 
    set_colors=['purple', 'skyblue', 'green'], alpha=0.5)

# %%
exotic.head()
# Out:
#   symbol             ensg   HGNC             Exon  Ratio_num  mRNA_nb  \
# 0  A2ML1  ENSG00000166535  23336  8975248-8975309        0.5        1
# 1  A2ML1  ENSG00000166535  23336  8975778-8975961        0.5        1
# 2  A2ML1  ENSG00000166535  23336  8976316-8976478        0.5        1
# 3  A2ML1  ENSG00000166535  23336  8982323-8982375        0.5        1
# 4  A2ML1  ENSG00000166535  23336  8987258-8987278        0.5        1
#
#    mRNA_nb_total                    MAP  mean_proportion  \
# 0              2  A2ML1_8975248-8975309          0.69514
# 1              2  A2ML1_8975778-8975961          0.69514
# 2              2  A2ML1_8976316-8976478          0.69514
# 3              2  A2ML1_8982323-8982375          0.69514
# 4              2  A2ML1_8987258-8987278          0.69514
#
#    Adipose - Subcutaneous  ...  Vagina  Whole Blood  EXOTIC_down  \
# 0                0.578349  ...     0.5     0.578349     0.713205
# 1                0.578349  ...     0.5     0.578349     0.713205
# 2                0.578349  ...     0.5     0.578349     0.713205
# 3                0.578349  ...     0.5     0.578349     0.713205
# 4                0.578349  ...     0.5     0.578349     0.713205
#
#    EXOTIC_bins_down              EXOTIC_tissues_down  EXOTIC_up  \
# 0        0.7 - 0.75  [Brain - Cerebellar Hemisphere]   0.578349
# 1        0.7 - 0.75  [Brain - Cerebellar Hemisphere]   0.578349
# 2        0.7 - 0.75  [Brain - Cerebellar Hemisphere]   0.578349
# 3        0.7 - 0.75  [Brain - Cerebellar Hemisphere]   0.578349
# 4        0.7 - 0.75  [Brain - Cerebellar Hemisphere]   0.578349
#
#    EXOTIC_bins_up                                  EXOTIC_tissues_up  \
# 0      0.55 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 1      0.55 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 2      0.55 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 3      0.55 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 4      0.55 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
#
#    Exon_start  Exon_stop
# 0     8975248    8975309
# 1     8975778    8975961
# 2     8976316    8976478
# 3     8982323    8982375
# 4     8987258    8987278
#
# [5 rows x 70 columns]

# %%
clinvar.tail()
# Out:
#           GENE            VAR_ID CHROM    POS REF    ALT                  MC  \
# 770451  MT-CYB  MT_15637_C_['T']    MT  15637   C  ['T']  synonymous_variant
# 770457  MT-CYB  MT_15649_A_['G']    MT  15649   A  ['G']  synonymous_variant
# 770467  MT-CYB  MT_15670_T_['C']    MT  15670   T  ['C']  synonymous_variant
# 770470  MT-CYB  MT_15682_A_['G']    MT  15682   A  ['G']  synonymous_variant
# 770493  MT-CYB  MT_15784_T_['C']    MT  15784   T  ['C']  synonymous_variant
#
#             Status        Real_Status  RS_STARS  \
# 770451  Pathogenic  Likely_pathogenic         0
# 770457  Pathogenic  Likely_pathogenic         0
# 770467  Pathogenic  Likely_pathogenic         0
# 770470  Pathogenic  Likely_pathogenic         0
# 770493  Pathogenic  Likely_pathogenic         0
#
#                             CLNREVSTAT           HPO         rs  alleleid  \
# 770451  no_assertion_criteria_provided            []  527236190    153620
# 770457  no_assertion_criteria_provided            []  527236191    153621
# 770467  no_assertion_criteria_provided  [HP:0100615]  193302997    153650
# 770470  no_assertion_criteria_provided            []  527236192    153622
# 770493  no_assertion_criteria_provided            []  527236194    153624
#
#        OMIM_VARIANT_ID
# 770451
# 770457
# 770467
# 770470
# 770493

# %%
def mp_variants(gene, exotic, clinvar, l):
    exotic_tmp_gene = exotic.loc[exotic['symbol'] == gene]
    clinvar_tmp_gene = clinvar.loc[clinvar['GENE'] == gene]
    for exon in exotic_tmp_gene.Exon.unique().tolist():
        match_variants = clinvar_tmp_gene.POS.between(int(exon.split('-')[0]), int(exon.split('-')[1]))
        match_variants = clinvar_tmp_gene.loc[match_variants.loc[match_variants == True].index.tolist(), 'alleleid'].values.tolist()
        if match_variants:
            l.append({exon : match_variants})
        
# for gene in tqdm():
m = multiprocessing.Manager()
l = m.list()
genes = exotic.symbol.unique().tolist()
parmap.starmap(mp_variants, list(zip(genes)), exotic, clinvar, l, pm_pbar=True)
map_d = {k: v for d in l for k, v in d.items()}
exotic['AlleleIDs_clinvar'] = exotic['Exon'].map(map_d)
# exotic_up['AlleleIDs_clinvar'] = exotic_up['Exon'].map(map_d)
# exotic_down['AlleleIDs_clinvar'] = exotic_down['Exon'].map(map_d)


# print(l)
# Out:
# 6300it [06:00, 17.46it/s]

# %%
exotic.loc[exotic['AlleleIDs_clinvar'].isna() == False, 'symbol'].nunique()
# Out:
# 983

# %%
exotic_clinvar = pd.merge(exotic.explode('AlleleIDs_clinvar').rename({'AlleleIDs_clinvar' : 'alleleid'}, axis=1), clinvar, on='alleleid')
exotic_clinvar.to_csv('/gstock/EXOTIC/data/VARIATIONS/exotic_clinvar.csv.gz', compression='gzip', sep='\t')
exotic_clinvar
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 12814  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12815  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12816  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12817  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 12818  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 12814        1              2  ZNF462_109686414-109689445          0.54621
# 12815        1              2  ZNF462_109686414-109689445          0.54621
# 12816        1              2  ZNF462_109686414-109689445          0.54621
# 12817        1              3    ZNF644_91403829-91406866          0.33853
# 12818        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...    REF        ALT  \
# 0                    0.578349  ...      C      ['T']
# 1                    0.510498  ...    ACT      ['A']
# 2                    0.495250  ...  CAAGA      ['C']
# 3                    0.495250  ...      G      ['A']
# 4                    0.495250  ...      T      ['C']
# ...                       ...  ...    ...        ...
# 12814                0.496500  ...    CCT  ['TGGTG']
# 12815                0.496500  ...     TG      ['A']
# 12816                0.496500  ...      C      ['T']
# 12817                0.500250  ...      T      ['C']
# 12818                0.500250  ...      T      ['C']
#
#                                         MC      Status        Real_Status  \
# 0                                 nonsense  Pathogenic  Likely_pathogenic
# 1                       frameshift_variant  Pathogenic         Pathogenic
# 2            frameshift_variant,SO:0001623  Pathogenic         Pathogenic
# 3                      nonsense,SO:0001623  Pathogenic         Pathogenic
# 4      initiatior_codon_variant,SO:0001583  Pathogenic         Pathogenic
# ...                                    ...         ...                ...
# 12814                   frameshift_variant  Pathogenic  Likely_pathogenic
# 12815                   frameshift_variant  Pathogenic         Pathogenic
# 12816                             nonsense  Pathogenic         Pathogenic
# 12817          missense_variant,SO:0001627  Pathogenic         Pathogenic
# 12818          missense_variant,SO:0001627  Pathogenic         Pathogenic
#
#        RS_STARS                           CLNREVSTAT  \
# 0             1  criteria_provided,_single_submitter
# 1             0       no_assertion_criteria_provided
# 2             0       no_assertion_criteria_provided
# 3             1  criteria_provided,_single_submitter
# 4             1  criteria_provided,_single_submitter
# ...         ...                                  ...
# 12814         1  criteria_provided,_single_submitter
# 12815         1  criteria_provided,_single_submitter
# 12816         1  criteria_provided,_single_submitter
# 12817         0       no_assertion_criteria_provided
# 12818         0       no_assertion_criteria_provided
#
#                                                      HPO          rs  \
# 0                                           [HP:0000388]  1409944554
# 1                                                     []  1567027297
# 2                                                     []  1567027610
# 3                                                     []  1567037561
# 4                                                     []        None
# ...                                                  ...         ...
# 12814                                                 []  1564106503
# 12815  [HP:0001363, HP:0001365, HP:0004494, HP:000544...  1060499550
# 12816                                                 []   562767308
# 12817                                                 []   387907109
# 12818                                                 []   146936371
#
#        OMIM_VARIANT_ID
# 0
# 1          614888.0003
# 2          614888.0005
# 3
# 4
# ...                ...
# 12814
# 12815      617371.0002
# 12816
# 12817      614159.0001
# 12818      614159.0002
#
# [12819 rows x 85 columns]

# %%
exotic['AlleleIDs_clinvar'] = exotic['Exon'].map(map_d)
exotic_up['AlleleIDs_clinvar'] = exotic_up['Exon'].map(map_d)
exotic_down['AlleleIDs_clinvar'] = exotic_down['Exon'].map(map_d)

# %%
exotic_clinvar = exotic.loc[exotic['AlleleIDs_clinvar'].isna() == False]
print(exotic_clinvar.symbol.nunique())
print(exotic_clinvar.MAP.nunique())

# %%
from matplotlib_venn import venn3
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
plt.rcParams.update({"font.size" : 17})
venn3([
    set(exotic_clinvar.symbol.unique().tolist()), 
    set(omim_pheno.Approved_symbol.unique().tolist()),
    set(clinvar.GENE.unique().tolist())
], 
    set_labels=['EXOTIC genes with\npathogenic variants\ninside EXOTIC exon', 'OMIM genes with phenotypes', 'ClinVar Pathogenic (RV)'], 
    set_colors=['purple', 'skyblue', 'green'], alpha=0.5)

# %%
exotic_up[['symbol', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index()

# %%
exotic_up[['MAP', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index()

# %%
min_max = 'down'
concat_up_stats_exotic_clinvar = pd.concat([
    exotic_up[['symbol', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_up[['MAP', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_up.loc[exotic_up['AlleleIDs_clinvar'].isna() == False][['symbol', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_up.loc[exotic_up['AlleleIDs_clinvar'].isna() == False][['MAP', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
], axis=1
)
concat_up_stats_exotic_clinvar.columns = ['EXOTIC genes', 'EXOTIC exons', 'Clinvar X EXOTIC genes', 'Clinvar X EXOTIC exons']
cols = concat_up_stats_exotic_clinvar.columns
concat_up_stats_exotic_clinvar
# Out:
#             EXOTIC genes  EXOTIC exons  Clinvar X EXOTIC genes  \
# 0.5 - 0.55          2294          5408                      70
# 0.55 - 0.6          2661          7188                      96
# 0.6 - 0.65          1697          4042                      60
# 0.65 - 0.7          1097          2585                      36
# 0.7 - 0.75           695          1494                      23
# 0.75 - 0.8           504          1159                      18
# 0.8 - 0.85           327           814                      11
# 0.85 - 0.9           311           605                      12
# 0.9 - 0.95           221           469                      11
# 0.95 - 1.0           227           529                       6
#
#             Clinvar X EXOTIC exons
# 0.5 - 0.55                      95
# 0.55 - 0.6                     136
# 0.6 - 0.65                      80
# 0.65 - 0.7                      46
# 0.7 - 0.75                      34
# 0.75 - 0.8                      26
# 0.8 - 0.85                      15
# 0.85 - 0.9                      15
# 0.9 - 0.95                      20
# 0.95 - 1.0                       6

# %%
def show_values_on_bars(axs, i=0, fontsize=10, rotation=0, color='black', pad=0):
    def _show_on_single_plot(ax):
        for p in ax.patches:
            print(p)
            _x = p.get_x() + p.get_width()/2 
            _y = p.get_y() + (p.get_height()) + pad
            if i == 0:
                value = "{:,.0f}".format(p.get_height())
            if i == 2:
                value = "{:.2f}".format(p.get_height())

            if i == 3:
                value = "{:.3f}".format(p.get_height())
            if p.get_height() > 0:
                ax.text(_x, _y, value, ha="center", fontsize=fontsize, rotation=rotation, color=color)

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

plt.rcParams.update({"font.size" : 20, 'text.color' : 'black', 'axes.labelcolor' : 'black'})
min_max = 'down'
sns.set_context('paper', font_scale=2)
f, ax = plt.subplots(figsize=(15,15))
# data = concat_up_stats_exotic_clinvar.reset_index()
data = concat_down_stats_exotic_clinvar.reset_index()

concat_down_stats_exotic_clinvar
data.columns = ['EXOTIC_bins'] + list(cols)
data = data.melt(id_vars=['EXOTIC_bins'], value_vars=cols)


sns.barplot(data=data, x='EXOTIC_bins', y='value', hue='variable', palette='Reds', ax=ax)
plt.yscale('log')
plt.legend(title='')
ax.set_ylabel('Count', labelpad=0.2)
ax.set_xlabel('EXOTIC-{}'.format(min_max), labelpad=3)
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax.ticklabel_format(axis='y', useOffset=False)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# plt.xlabel('TEST')
ax.set_ylim(ymin=2, ymax=1e4)
ax.grid(axis='y', alpha=0.4)
show_values_on_bars(ax)
plt.tight_layout()
# Out:
# Rectangle(xy=(-0.4, 0), width=0.2, height=2294, angle=0)
# Rectangle(xy=(0.6, 0), width=0.2, height=2661, angle=0)
# Rectangle(xy=(1.6, 0), width=0.2, height=1697, angle=0)
# Rectangle(xy=(2.6, 0), width=0.2, height=1097, angle=0)
# Rectangle(xy=(3.6, 0), width=0.2, height=695, angle=0)
# Rectangle(xy=(4.6, 0), width=0.2, height=504, angle=0)
# Rectangle(xy=(5.6, 0), width=0.2, height=327, angle=0)
# Rectangle(xy=(6.6, 0), width=0.2, height=311, angle=0)
# Rectangle(xy=(7.6, 0), width=0.2, height=221, angle=0)
# Rectangle(xy=(8.6, 0), width=0.2, height=227, angle=0)
# Rectangle(xy=(-0.2, 0), width=0.2, height=5408, angle=0)
# Rectangle(xy=(0.8, 0), width=0.2, height=7188, angle=0)
# Rectangle(xy=(1.8, 0), width=0.2, height=4042, angle=0)
# Rectangle(xy=(2.8, 0), width=0.2, height=2585, angle=0)
# Rectangle(xy=(3.8, 0), width=0.2, height=1494, angle=0)
# Rectangle(xy=(4.8, 0), width=0.2, height=1159, angle=0)
# Rectangle(xy=(5.8, 0), width=0.2, height=814, angle=0)
# Rectangle(xy=(6.8, 0), width=0.2, height=605, angle=0)
# Rectangle(xy=(7.8, 0), width=0.2, height=469, angle=0)
# Rectangle(xy=(8.8, 0), width=0.2, height=529, angle=0)
# Rectangle(xy=(2.77556e-17, 0), width=0.2, height=70, angle=0)
# Rectangle(xy=(1, 0), width=0.2, height=96, angle=0)
# Rectangle(xy=(2, 0), width=0.2, height=60, angle=0)
# Rectangle(xy=(3, 0), width=0.2, height=36, angle=0)
# Rectangle(xy=(4, 0), width=0.2, height=23, angle=0)
# Rectangle(xy=(5, 0), width=0.2, height=18, angle=0)
# Rectangle(xy=(6, 0), width=0.2, height=11, angle=0)
# Rectangle(xy=(7, 0), width=0.2, height=12, angle=0)
# Rectangle(xy=(8, 0), width=0.2, height=11, angle=0)
# Rectangle(xy=(9, 0), width=0.2, height=6, angle=0)
# Rectangle(xy=(0.2, 0), width=0.2, height=95, angle=0)
# Rectangle(xy=(1.2, 0), width=0.2, height=136, angle=0)
# Rectangle(xy=(2.2, 0), width=0.2, height=80, angle=0)
# Rectangle(xy=(3.2, 0), width=0.2, height=46, angle=0)
# Rectangle(xy=(4.2, 0), width=0.2, height=34, angle=0)
# Rectangle(xy=(5.2, 0), width=0.2, height=26, angle=0)
# Rectangle(xy=(6.2, 0), width=0.2, height=15, angle=0)
# Rectangle(xy=(7.2, 0), width=0.2, height=15, angle=0)
# Rectangle(xy=(8.2, 0), width=0.2, height=20, angle=0)
# Rectangle(xy=(9.2, 0), width=0.2, height=6, angle=0)

# %%
concat_up_stats_exotic_clinvar.reset_index()
# Out:
#         index  EXOTIC genes  EXOTIC exons  Clinvar X EXOTIC genes  \
# 0  0.5 - 0.55          3099          7777                     122
# 1  0.55 - 0.6          2375          6267                      83
# 2  0.6 - 0.65          1610          4025                      58
# 3  0.65 - 0.7           922          2377                      31
# 4  0.7 - 0.75           621          1551                      19
# 5  0.75 - 0.8           386           803                       9
# 6  0.8 - 0.85           276           538                      11
# 7  0.85 - 0.9           185           456                       5
# 8  0.9 - 0.95           134           255                       4
# 9  0.95 - 1.0            79           244                       0
#
#    Clinvar X EXOTIC exons
# 0                     182
# 1                     117
# 2                      70
# 3                      43
# 4                      21
# 5                      14
# 6                      12
# 7                       5
# 8                       9
# 9                       0

# %%
concat_up_stats_exotic_clinvar_tmp = concat_up_stats_exotic_clinvar.reset_index()
concat_up_stats_exotic_clinvar_tmp.columns = ['EXOTIC_bins'] + list(cols)
concat_up_stats_exotic_clinvar_tmp['EXOTIC_bin_start'] = concat_up_stats_exotic_clinvar_tmp['EXOTIC_bins'].apply(lambda r: r.split(' - ')[0])
concat_up_stats_exotic_clinvar_tmp = concat_up_stats_exotic_clinvar_tmp.melt(id_vars=['EXOTIC_bin_start'], value_vars=cols)


sns.set_context('paper', font_scale=2)
f, ax = plt.subplots(figsize=(10,10))
data = concat_up_stats_exotic_clinvar_tmp.reset_index()
ax1_ = ax.bar(data.EXOTIC_bin_start.values, data.snpId_total.values,
#        yerr=error,
       align='edge',
       
       color='#8491B4FF',
       width=-0.020
      )
ax2 = ax.twinx()
ax2_ = ax2.bar(data.EXOTIC_bin_start.values, data.snpId.values, color='#91D1C2FF', align='edge', width=0.02)
ax.yaxis.label.set_color('#8491B4FF')
ax2.yaxis.label.set_color('#91D1C2FF')

ax.set_xticks(np.arange(min(data.EXOTIC_bin_start), max(data.EXOTIC_bin_start)+0.05, 0.05))


tkw = dict(size=4, width=1.5)
ax.tick_params(axis='y', colors='#8491B4FF', **tkw)
ax2.tick_params(axis='y', colors='#91D1C2FF', **tkw)
ax.set_ylabel('All sQTLs')
ax.set_xlabel('EXOTIC-max score')
ax2.set_ylabel('Tissue-specific sQTLs')
ax.spines['top'].set_linewidth(0)
ax2.spines['top'].set_linewidth(0)
# plt.title('Up')
# Out:
# ----------------------------------------------------------
# AttributeError           Traceback (most recent call last)
# <ipython-input-171-7f811980e330> in <module>
#       8 f, ax = plt.subplots(figsize=(10,10))
#       9 data = concat_up_stats_exotic_clinvar_tmp.reset_index()
# ---> 10 ax1_ = ax.bar(data.EXOTIC_bin_start.values, data.snpId_total.values,
#      11 #        yerr=error,
#      12        align='edge',
#
# ~/.conda/envs/ExoCarto/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'snpId_total'

# %%
min_max = 'down'
concat_down_stats_exotic_clinvar = pd.concat([
    exotic_down[['symbol', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_down[['MAP', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_down.loc[exotic_down['AlleleIDs_clinvar'].isna() == False][['symbol', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
    exotic_down.loc[exotic_down['AlleleIDs_clinvar'].isna() == False][['MAP', 'EXOTIC_bins_{}'.format(min_max)]].drop_duplicates()['EXOTIC_bins_{}'.format(min_max)].value_counts().sort_index(),
], axis=1
)
concat_down_stats_exotic_clinvar.columns = ['EXOTIC genes', 'EXOTIC exons', 'Clinvar X EXOTIC genes', 'Clinvar X EXOTIC exons']
concat_down_stats_exotic_clinvar
# Out:
#             EXOTIC genes  EXOTIC exons  Clinvar X EXOTIC genes  \
# 0.5 - 0.55          2294          5408                      70
# 0.55 - 0.6          2661          7188                      96
# 0.6 - 0.65          1697          4042                      60
# 0.65 - 0.7          1097          2585                      36
# 0.7 - 0.75           695          1494                      23
# 0.75 - 0.8           504          1159                      18
# 0.8 - 0.85           327           814                      11
# 0.85 - 0.9           311           605                      12
# 0.9 - 0.95           221           469                      11
# 0.95 - 1.0           227           529                       6
#
#             Clinvar X EXOTIC exons
# 0.5 - 0.55                      95
# 0.55 - 0.6                     136
# 0.6 - 0.65                      80
# 0.65 - 0.7                      46
# 0.7 - 0.75                      34
# 0.75 - 0.8                      26
# 0.8 - 0.85                      15
# 0.85 - 0.9                      15
# 0.9 - 0.95                      20
# 0.95 - 1.0                       6

# %%
f, ax = plt.subplots(figsize=(15,15))
data = concat_down_stats_exotic_clinvar.reset_index()
data.columns = ['EXOTIC_bins'] + list(cols)
data = data.melt(id_vars=['EXOTIC_bins'], value_vars=cols)
palette = ['#DC0000', '#E64B35',"#fab1a0", "#fd79a8"]
min_max = 'down'

sns.barplot(data=data, x='EXOTIC_bins', y='value', hue='variable', palette='Reds')
plt.legend(title='')
plt.yscale('log')
ax.spines['top'].set_linewidth(0)
ax.spines['right'].set_linewidth(0)
import matplotlib
ax.get_yaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
ax.ticklabel_format(axis='y', useOffset=False)
ax.get_yaxis().set_major_formatter(matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
ax.set_ylabel('Count')
ax.set_xlabel('EXOTIC-{}'.format(min_max))
ax.set_ylim(ymin=2, ymax=1e4)
# ax.set_yticks()
# Out:
# (2, 10000.0)

# %% [markdown]
# ## ClinVar PMID

# %%
clinvar_pmid = pd.read_csv(files['EXOTIC']['clinvar_pmid_mapping_path'], sep='\t')
clinvar_pmid

# %%
clinvar_pmid.loc[clinvar_pmid['#AlleleID'].isin(exotic_clinvar.explode('AlleleIDs_clinvar').AlleleIDs_clinvar.unique().tolist()), 'citation_id'].unique().tolist()

# %%
exotic.symbol.nunique()

# %%
exotic_clinvar.explode('AlleleIDs_clinvar')

# %%
def return_pmid(r):
    l = list()
    for e in r:
        pmids = clinvar_pmid.loc[clinvar_pmid['#AlleleID'] == e, 'citation_id'].values.tolist()
        if pmids :
            l.append(pmids[0])
    return l 

exotic_clinvar['citation_id'] = exotic_clinvar.explode('AlleleIDs_clinvar').AlleleIDs_clinvar.apply(lambda r: return_pmid(r))
exotic_clinvar

# %%
exotic.loc[exotic['symbol'] == 'SPRED1']

# %%
exotic_clinvar_exploded_variants = exotic_clinvar.explode('AlleleIDs_clinvar')
exotic_clinvar_exploded_variants = pd.merge(exotic_clinvar_exploded_variants.drop('citation_id', axis=1), clinvar_pmid[['#AlleleID', 'citation_id']], left_on='AlleleIDs_clinvar', right_on='#AlleleID').drop('#AlleleID', axis=1)

exotic_clinvar_exploded_variants

# %%
exotic_clinvar_exploded_pmids = exotic_clinvar.explode('citation_id').dropna(subset=['citation_id'])
exotic_clinvar_exploded_pmids

# %%
exotic_clinvar_exploded_pmids.loc[exotic_clinvar_exploded_pmids['symbol'] == 'SPRED1', 'citation_id'].unique()

# %%
exotic_clinvar_exploded_pmids.citation_id.nunique()

# %%
import requests
pmid = "25264593"
pubtator_cat = "pm"
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format(pubtator_cat, pmid)
r = requests.get(url)
j = r.json()
title = j['passages'][0]['text']
title

# %%
import requests

def retrieve_pmid_infos(pmid, l):
#     pmid = "31009165"
    pubtator_cat = "pm"
    url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format(pubtator_cat, pmid)
    try:
        r = requests.get(url)
        j = r.json()
        title = j['passages'][0]['text']
        abstract = j['passages'][1]['text']
        l.append({
            'citation_id' : pmid,
            'title' : title,
            'abstract' : abstract,
            }
        )
    except:
        print(pmid)

pmids = clinvar_pmid.loc[clinvar_pmid['#AlleleID'].isin(exotic_clinvar.explode('AlleleIDs_clinvar').AlleleIDs_clinvar.unique().tolist()), 'citation_id'].unique().tolist()
pmids = [e for e in pmids if 'NBK' not in e]
m = multiprocessing.Manager()
l = m.list()

parmap.starmap(retrieve_pmid_infos, list(zip(pmids)), l, pm_pbar=True)
    
pmids_infos = pd.DataFrame(list(l))
pmids_infos

# %%
exotic_clinvar_pmid_lite

# %%
import requests

def retrieve_pmid_infos(pmid, l):
#     pmid = "31009165"
    pubtator_cat = "pm"
    url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format(pubtator_cat, pmid)
    try:
        r = requests.get(url)
        j = r.json()
        title = j['passages'][0]['text']
        abstract = j['passages'][1]['text']
        l.append({
            'citation_id' : pmid,
            'title' : title,
            'abstract' : abstract,
            }
        )
    except:
        print(pmid)

pmids = exotic_clinvar_pmid.loc[exotic_clinvar_pmid['title'].isna() == True, 'citation_id'].unique().tolist()
pmids = [e for e in pmids if 'NBK' not in e]
m = multiprocessing.Manager()
l = m.list()

parmap.starmap(retrieve_pmid_infos, list(zip(pmids)), l, pm_pbar=True)
    
pmids_infos_second = pd.DataFrame(list(l))
pmids_infos_second

# %%
pd.concat([pmids_infos, pmids_infos_second])

# %%
exotic_clinvar_pmid.columns

# %%
exotic_clinvar_pmid = pd.merge(exotic_clinvar_exploded_variants, pd.concat([pmids_infos, pmids_infos_second]), how='left', on='citation_id')
exotic_clinvar_pmid = exotic_clinvar_pmid.loc[exotic_clinvar_pmid['citation_id'].isin(citation_to_keep)]
exotic_clinvar_pmid['AlleleIDs_clinvar'] = exotic_clinvar_pmid['AlleleIDs_clinvar'].astype(str)

exotic_clinvar_pmid_lite = exotic_clinvar_pmid[['MAP', 'citation_id', 'AlleleIDs_clinvar']].groupby(['MAP', 'citation_id'])['AlleleIDs_clinvar'].apply(lambda r: ','.join(r))
exotic_clinvar_pmid_lite = exotic_clinvar_pmid_lite.reset_index().drop_duplicates()


exotic_clinvar_pmid = pd.merge(exotic_clinvar_pmid.drop(['AlleleIDs_clinvar'], axis=1).drop_duplicates(subset=['MAP', 'citation_id']), exotic_clinvar_pmid_lite, on=['MAP', 'citation_id'])

# COMPUTE BINS
r = np.arange(0.5,1.05,0.1)
bins = r
labels = bins.copy()
labels_ratio = [str(round(labels[j], 3)) + " - " + str(round(labels[j + 1], 3)) for j in range(len(labels) - 1)]
for min_max in ['up', 'down']:
    for j, b in enumerate(labels_ratio):
        if j > 0:
            b_start = float(b.split(' - ')[0])
            b_end = float(b.split(' - ')[1])
            print(b_start)
#             print(len(exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].columns))
#             print(exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].columns)
            if min_max == 'up':
                exotic_clinvar_pmid['EXOTIC_{}_{}'.format(b, min_max)] = exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].apply(lambda r: [exotic_clinvar_pmid.columns[9:9+53][i] for i, e in enumerate(r) if float(e) >= b_start and float(e) < b_end], axis=1)
            elif min_max == 'down':
                exotic_clinvar_pmid['EXOTIC_{}_{}'.format(b, min_max)] = exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].apply(lambda r: [exotic_clinvar_pmid.columns[9:9+53][i] for i, e in enumerate(r) if (1-float(e)) >= b_start and (1-float(e)) < b_end], axis=1)

                
exotic_clinvar_pmid['abstract'] = exotic_clinvar_pmid['abstract'].astype(str)

exotic_clinvar_pmid['Isoform_abstract'] = exotic_clinvar_pmid['abstract'].apply(lambda r: "isoform" in r.lower())
# exotic_clinvar_pmid = exotic_clinvar_pmid.loc[exotic_clinvar_pmid['Isoform_abstract'] == True]
exotic_clinvar_pmid = exotic_clinvar_pmid.loc[exotic_clinvar_pmid['symbol'] == 'NF1']


exotic_clinvar_pmid = exotic_clinvar_pmid[[
    'symbol', 'Exon', 'EXOTIC_0.6 - 0.7_up', 'EXOTIC_0.7 - 0.8_up', 'EXOTIC_0.8 - 0.9_up',
       'EXOTIC_0.9 - 1.0_up', 'EXOTIC_0.6 - 0.7_down', 'EXOTIC_0.7 - 0.8_down',
       'EXOTIC_0.8 - 0.9_down', 'EXOTIC_0.9 - 1.0_down', 'AlleleIDs_clinvar', 'citation_id', 'title', 'abstract', 'Isoform_abstract'
]]
exotic_clinvar_pmid.to_excel('/gstock/EXOTIC/data/PMIDS/NF1_EXOTIC_clinvar_PMIDS.xlsx', index=False)
exotic_clinvar_pmid


# exotic_clinvar_pmid[['symbol', 'citation_id']].drop_duplicates().symbol.value_counts()

# exotic_clinvar_pmid[['symbol', 'ensg', 'Exon', 'EXOTIC_bins_up', 'EXOTIC_tissues_up', 'EXOTIC_bins_down', 'EXOTIC_tissues_down', 'AlleleIDs_clinvar', 'citation_id', "title", 'abstract']].to_excel('/gstock/EXOTIC/data/PMIDS/EXOTIC_clinvar_PMIDS.xlsx', index=False)

# %%
exotic_clinvar_pmid.loc[exotic_clinvar_pmid['title'].isna() == True]

# %%
exotic_clinvar_exploded_pmids.loc[exotic_clinvar_exploded_pmids['citation_id'] == "10835642"]

# %%
exotic_clinvar_pmid.loc[exotic_clinvar_pmid['symbol'] == 'NF1', 'citation_id']

# %%
exotic_clinvar_pmid.loc[exotic_clinvar_pmid['symbol'] == 'NF1']

# %%
sorted(list(exotic_clinvar_exploded_pmids.loc[exotic_clinvar_exploded_pmids['symbol'] == 'ABCC6', 'citation_id'].unique()))

# %%
exotic_clinvar_pmid.citation_id.nunique()

# %%
exotic_pmids_count = exotic_clinvar_pmid[['symbol', 'citation_id']].drop_duplicates().groupby('symbol').count().sort_values(by='citation_id', ascending=False)
exotic_pmids_count.to_excel('/gstock/EXOTIC/data/PMIDS/PMIDS_count_per_gene.xlsx')
exotic_pmids_count

# %%
exotic_pmids_count = exotic_clinvar_pmid[['symbol', 'citation_id']].drop_duplicates()
exotic_pmids_count

# %%
exotic_pmids_count = exotic_clinvar_pmid[['symbol', 'citation_id']].drop_duplicates()
d = dict(collections.Counter(exotic_pmids_count.citation_id.values.tolist()))
d = {k: d[k] for k in sorted(d, key=d.get, reverse=True)}
exotic_pmids_count = pd.DataFrame.from_dict(d, orient='index')
exotic_pmids_count.columns = ['count']
# exotic_pmids_count.to_excel('/gstock/EXOTIC/data/PMIDS/PMIDS_count_across_genes.xlsx')
# citation_to_keep = exotic_pmids_count.loc[exotic_pmids_count['count'] < 10].index.tolist()
exotic_pmids_count.head(15)

# %%
nf1_publis = ["10076878", "10090487", "10336779", "10494088", "10534774", "10543400", "10607834", "10677298", "10678181", "10712197", "1071297", "10721668", "10726756", "10862084", "10980545", "11137998", "11292340", "11459867", "11476066", "11735023", "11857752", "12112660", "12483293", "12522551", "125305868", "12552569", "12707950", "12746402", "12787671", "12807981", "12822827", "12872266", "14517963", "14569132", "14722917", "15060124", "15146469", "15221447", "15627836", "1568246", "1568247", "15863657", "15948193", "16005615", "16138229", "16199547", "16380919", "16479075", "16513807", "16542390", "16544997", "16773574", "16786042", "16786508", "16835897", "16870183", "16941471", "16944272", "16961930", "17103458", "17105749", "17114577", "17160901", "17209131", "17311297", "17353900", "17369502", "17426081", "17551851", "1757093", "1770531", "17712740", "17726231", "1783401", "17914445", "17960768", "18041031", "18172006", "18183640", "18484666", "18503770", "18546366", "190611", "19061981", "19117870", "19120036", "19142971", "19221814", "19292874", "19539839", "19665063", "19738042", "19845691", "19863548", "19920235", "20142468", "20602485", "20605257", "21031597", "21089071", "2114220", "21271658", "21354044", "21362601", "21532985", "21567923", "21618341", "22034633", "22041710", "22108604", "22155606", "22190595", "22207399", "22222937", "22429592", "22604720", "22664660", "22807134", "22925204", "22965773", "23010473", "23047742", "23165953", "23222849", "23244495", "23354915", "23404336", "23460398", "23583981", "23624750", "23656349", "23668869", "23758643", "23812910", "23906300", "23913538", "23954459", "24219125", "24232412", "24357598", "24413922", "24676424", "24694336", "24711935", "24789688", "24803665", "24922668", "24932921", "24951259", "25074460", "25156439", "25211147", "25240281", "25293717", "25324428", "25324867", "25325900", "25356970", "25370043", "25403449", "25480383", "25541118", "25624686", "25810463", "25877329", "25951773", "25966637", "26056819", "26076063", "26178382", "26331193", "26345759", "26458495", "26478990", "26635368", "26659639", "26706011", "26740943", "26758488", "26840085", "26908603", "26962827", "26969325", "26973730", "27069254", "27074763", "27170677", "27171602", "27322474", "27482814", "27716896", "27838393", "27862945", "27980226", "27999334", "28068329", "28213670", "28422438", "28529006", "28706617", "28891274", "28924536", "28955729", "28961165", "29100083", "29290338", "29415745", "29449315", "29483232", "2948975", "29522274", "29566708", "29618358", "29620724", "29673180", "29685074", "29872168", "29914388", "29952103", "29957862", "30014477", "30087692", "30104415", "30190611", "30290804", "30291346", "30308447", "30530636", "31347283", "31370276", "31371350", "31533797", "31595648", "31717729", "31730495", "32860008", "6025371", "7586657", "7607663", "7649559", "7655472", "7874161", "7903661", "7904209", "7981679", "8069310", "8081387", "8242079", "8264648", "8385067", "8437860", "8544190", "8628317", "8807336", "8834249", "8837715", "8845843", "9003501", "9042399", "9101300", "9109662", "9150739", "9180088", "9195229", "9219684", "9298829", "9302992", "9375928", "9385374", "9452037", "9463322", "9475595", "9545275", "9668168", "9687500", "9783703", ]
for pmid in nf1_publis:
    print(pmid)
    url = "https://www.ncbi.nlm.nih.gov/pmc/utils/idconv/v1.0/?tool=my_tool&email=my_email@example.com&ids={}&format=json".format(pmid)
    r = requests.get(url)
    j = r.json()
    pubmed_id = j["records"][0]["pmid"]
    pmc_id = ""
    if "pmcid" in j["records"][0]:
        pmc_id= j["records"][0]["pmcid"]
    pubtator_cat = "pmc" if pmc_id else "pm"
    check = False
    if pubtator_cat == "pmc":
        try:
            print(pmc_id)
            pubtator_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format("pmc", pmc_id)
            print(pubtator_url)
            r = requests.get(pubtator_url)
            j = r.json()
            check_pheno = False
            crypto_mesh = "D003456"
            for passage in j['passages']:
                mesh_terms = [annot['infons']['identifier'] for annot in passage['annotations']]
                check_pheno = True if 'MESH:{}'.format(crypto_mesh) in mesh_terms else False
                if check_pheno:
                    print(passage)
            
            check = True if j else False
        except:
            print('PMC {} BUT NO TEXT ONLINE AVAILABLE FOR PMID : {}'.format(pmc_id, pubmed_id))

            pass
    if check is False:
        try: 
            pubtator_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format("pm", pubmed_id)
            r = requests.get(pubtator_url)
            j = r.json()
            print(pubtator_url)
            check_pheno = False
            crypto_mesh = "D003456"
            for passage in j['passages']:
                mesh_terms = [annot['infons']['identifier'] for annot in passage['annotations']]
                check_pheno = True if 'MESH:{}'.format(crypto_mesh) in mesh_terms else False
                if check_pheno:
                    print(passage)
        except:
            print('ERROR WITH {}'.format(pubmed_id))

# %%
pubtator_cat = 'pmc'
pubmed_id = 'PMC1288164'
pubtator_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?{}ids={}".format(pubtator_cat, pubmed_id)
print(pubtator_url)
r = requests.get(pubtator_url)
j = r.json()
j

# %% [markdown]
# ## OMIM entries with multiple phenotypes & at least one rare

# %% [markdown]
# ## Processed phenotypes through API

# %%
from Phenotypes import omim_associations_exotic
omim = omim_associations_exotic.load_omim(files["EXOTIC"]["omim_detailed"], files["BIOMART"]["biomart_omim"])
# omim.head()
omim
# Out:
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# INFO: Pandarallel will run on 60 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
#                    ensg      Name    OMIM  Pheno_OMIM  \
# 0       ENSG00000274891  TRAPPC12  614139      617669
# 1       ENSG00000171853  TRAPPC12  614139      617669
# 2       ENSG00000282650     MEIOB  617670      617706
# 3       ENSG00000162039     MEIOB  617670      617706
# 4       ENSG00000277603       TPO  606765      274500
# ...                 ...       ...     ...         ...
# 264340  ENSG00000164867      NOS3  163729      189800
# 264469  ENSG00000171759       PAH  612349      261600
# 264470  ENSG00000171759       PAH  612349      261600
# 264502  ENSG00000173218    VANGL1  610132      600145
# 264555  ENSG00000131779    PEX11B  603867      614920
#
#                                                Pheno_Name  \
# 0       Encephalopathy, progressive, early-onset, with...
# 1       Encephalopathy, progressive, early-onset, with...
# 2                               ?Spermatogenic failure 22
# 3                               ?Spermatogenic failure 22
# 4                            Thyroid dyshormonogenesis 2A
# ...                                                   ...
# 264340                  {Hypertension, pregnancy-induced}
# 264469              [Hyperphenylalaninemia, non-PKU mild]
# 264470                                    Phenylketonuria
# 264502                         Caudal regression syndrome
# 264555                ?Peroxisome biogenesis disorder 14B
#
#                                      Pheno_prefered_title  \
# 0       ENCEPHALOPATHY, PROGRESSIVE, EARLY-ONSET, WITH...
# 1       ENCEPHALOPATHY, PROGRESSIVE, EARLY-ONSET, WITH...
# 2                        SPERMATOGENIC FAILURE 22; SPGF22
# 3                        SPERMATOGENIC FAILURE 22; SPGF22
# 4                     THYROID DYSHORMONOGENESIS 2A; TDH2A
# ...                                                   ...
# 264340                     PREECLAMPSIA/ECLAMPSIA 1; PEE1
# 264469                               PHENYLKETONURIA; PKU
# 264470                               PHENYLKETONURIA; PKU
# 264502            SACRAL DEFECT WITH ANTERIOR MENINGOCELE
# 264555         PEROXISOME BIOGENESIS DISORDER 14B; PEX14B
#
#                                                      PMID  \
# 0                                              [28777934]
# 1                                              [28777934]
# 2                                              [28206990]
# 3                                              [28206990]
# 4       [1401057, 4189569, 1339470, 11061528, 8027236,...
# ...                                                   ...
# 264340  [6102633, 2901618, 2242360, 9311740, 10441346,...
# 264469  [8098245, 2574153, 11035829, 5461364, 5432154,...
# 264470  [8098245, 2574153, 11035829, 5461364, 5432154,...
# 264502  [5505693, 2334530, 4891160, 10631160, 13641302...
# 264555   [22581968, 3515938, 12024045, 2445576, 22581969]
#
#                                OMIM_BP  \
# 0                          inheritance
# 1                          inheritance
# 2                          inheritance
# 3                          inheritance
# 4                          inheritance
# ...                                ...
# 264340  prenatalManifestationsMaternal
# 264469  prenatalManifestationsMaternal
# 264470  prenatalManifestationsMaternal
# 264502  prenatalManifestationsMaternal
# 264555  prenatalManifestationsMaternal
#
#                                        OMIM_BP_phenotypes
# 0       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 1       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 2       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 3       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 4       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# ...                                                   ...
# 264340  ['Maternal hypertension (after 20th week gesta...
# 264469  ['Maternal hyperphenylalaninemia teratogenic {...
# 264470  ['Maternal hyperphenylalaninemia teratogenic {...
# 264502  ['Prolonged labor {SNOMEDCT:161810005,53443007...
# 264555  ['Uncomplicated pregnancy {UMLS C4314562};\nUn...
#
# [40056 rows x 9 columns]

# %%
l = list()
import math

for gene in tqdm(omim.Name.unique()):

    gene_omim = omim.loc[omim['Name'] == gene]
    if gene_omim.Pheno_OMIM.nunique() > 1:
#         print(gene, gene_omim.shape[0])
        gene_omim_bp = gene_omim[['Name', 'Pheno_OMIM', 'OMIM_BP']].groupby(['Name', 'Pheno_OMIM'])['OMIM_BP'].apply(set).reset_index()
        nb_pheno = gene_omim_bp.Pheno_OMIM.nunique()
        counter_pheno = collections.Counter([sub_e for e in gene_omim_bp['OMIM_BP'].values.tolist() for sub_e in e])
        cutoff = 1 if nb_pheno < 4 else math.floor(nb_pheno/2)
        counter_pheno_rare = [k for k,v in counter_pheno.items() if v <= cutoff]
#         print(nb_pheno, cutoff)
#         print(counter_pheno_rare)
        l.append(gene_omim.loc[gene_omim['OMIM_BP'].isin(counter_pheno_rare)])
        
#         for pheno_rare in counter_pheno_rare:
#             print(gene_omim.loc[gene_omim['OMIM_BP'] == pheno_rare, ['Pheno_OMIM', 'Pheno_prefered_title', 'OMIM_BP', 'OMIM_BP_phenotypes']].values.tolist())
omim_multi_pheno_filterred = pd.concat(l)
omim_multi_pheno_filterred
# Out:
# 100%|██████████| 2570/2570 [00:08<00:00, 311.36it/s]
#                    ensg   Name    OMIM  Pheno_OMIM  \
# 66248   ENSG00000281289    LSS  600909      618840
# 66251   ENSG00000160285    LSS  600909      618840
# 78668   ENSG00000281289    LSS  600909      618840
# 78671   ENSG00000160285    LSS  600909      618840
# 82809   ENSG00000281289    LSS  600909      616509
# ...                 ...    ...     ...         ...
# 111776  ENSG00000162711  NLRP3  606416      617772
# 111779  ENSG00000162711  NLRP3  606416      191900
# 132477  ENSG00000162711  NLRP3  606416      120100
# 132479  ENSG00000162711  NLRP3  606416      191900
# 198715  ENSG00000162711  NLRP3  606416      607115
#
#                                                Pheno_Name  \
# 66248              Alopecia-mental retardation syndrome 4
# 66251              Alopecia-mental retardation syndrome 4
# 78668              Alopecia-mental retardation syndrome 4
# 78671              Alopecia-mental retardation syndrome 4
# 82809                                         Cataract 44
# ...                                                   ...
# 111776  Deafness, autosomal dominant 34, with or witho...
# 111779                              Muckle-Wells syndrome
# 132477              Familial cold inflammatory syndrome 1
# 132479                              Muckle-Wells syndrome
# 198715                                     CINCA syndrome
#
#                                      Pheno_prefered_title  \
# 66248       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 66251       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 78668       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 78671       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 82809                                CATARACT 44; CTRCT44
# ...                                                   ...
# 111776  DEAFNESS, AUTOSOMAL DOMINANT 34, WITH OR WITHO...
# 111779                         MUCKLE-WELLS SYNDROME; MWS
# 132477   FAMILIAL COLD AUTOINFLAMMATORY SYNDROME 1; FCAS1
# 132479                         MUCKLE-WELLS SYNDROME; MWS
# 198715                              CINCA SYNDROME; CINCA
#
#                                                      PMID  \
# 66248                                [30723320, 30401459]
# 66251                                [30723320, 30401459]
# 78668                                [30723320, 30401459]
# 78671                                [30723320, 30401459]
# 82809            [29016354, 16440058, 30401459, 26200341]
# ...                                                   ...
# 111776                                         [28847925]
# 111779  [7802040, 5769632, 10486324, 11992256, 9797932...
# 132477  [5029834, 4855507, 4141601, 4682536, 11687797,...
# 132479  [7802040, 5769632, 10486324, 11992256, 9797932...
# 198715  [12483741, 16532456, 12032915, 6847730, 129288...
#
#                            OMIM_BP  \
# 66248      laboratoryAbnormalities
# 66251      laboratoryAbnormalities
# 78668              headAndNeckHead
# 78671              headAndNeckHead
# 82809              headAndNeckEyes
# ...                            ...
# 111776            headAndNeckMouth
# 111779            headAndNeckMouth
# 132477            muscleSoftTissue
# 132479            muscleSoftTissue
# 198715  skinNailsHairSkinHistology
#
#                                        OMIM_BP_phenotypes
# 66248                       ['Normal or low cholesterol']
# 66251                       ['Normal or low cholesterol']
# 78668   ['Microcephaly (in some patients) {UMLS C18491...
# 78671   ['Microcephaly (in some patients) {UMLS C18491...
# 82809   ['Cataract, congenital, severe {UMLS C4228509}...
# ...                                                   ...
# 111776  ['Oral ulcers {SNOMEDCT:26284000} {UMLS C01497...
# 111779  ['Aphthous ulcers {SNOMEDCT:426965005,42761700...
# 132477  ['Myalgia, episodic {UMLS C2674035} {HPO HP:00...
# 132479  ['Myalgia, episodic {UMLS C2674035} {HPO HP:00...
# 198715  ['Perivascular polymorphonuclear infiltrates {...
#
# [7151 rows x 9 columns]

# %%
omim_multi_pheno_filterred[['Name', 'Pheno_OMIM', 'OMIM_BP', 'OMIM_BP_phenotypes']]

# %%
omim_multi_pheno_filterred[['Name', 'Pheno_OMIM']].drop_duplicates().groupby(['Name'])['Pheno_OMIM'].apply(set).reset_index()

# %%
omim_multi_pheno_filterred.OMIM.nunique()
# Out:
# 582

# %% [markdown]
# ## EXOTIC imports & Filter with multi pheno OMIM genes

# %%
exotic = pd.read_parquet(files["EXOTIC"]["exotic_modified_zscore_mean_prop_corrected"])
# exotic[['Exon_start', 'Exon_stop']] = exotic['Exon'].str.split('-', expand=True)
# exotic_up = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'up', cutoff=0.5)
# exotic_down = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'down', cutoff=0.5)
exotic = exotic.loc[exotic['symbol'].isin(omim_multi_pheno_filterred.Name.unique().tolist())]

# COMPUTE BINS
r = np.arange(0.5,1.05,0.1)
bins = r
labels = bins.copy()
labels_ratio = [str(round(labels[j], 3)) + " - " + str(round(labels[j + 1], 3)) for j in range(len(labels) - 1)]
for min_max in ['up', 'down']:
    for j, b in enumerate(labels_ratio):
        if j > 0:
            b_start = float(b.split(' - ')[0])
            b_end = float(b.split(' - ')[1])
            print(b_start)
#             print(len(exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].columns))
#             print(exotic_clinvar_pmid[list(exotic_clinvar_pmid.columns)[9:9+53]].columns)
            if min_max == 'up':
                exotic['EXOTIC_{}_{}'.format(b, min_max)] = exotic[list(exotic.columns)[9:9+53]].apply(lambda r: [exotic.columns[9:9+53][i] for i, e in enumerate(r) if float(e) >= b_start and float(e) < b_end], axis=1)
            elif min_max == 'down':
                exotic['EXOTIC_{}_{}'.format(b, min_max)] = exotic[list(exotic.columns)[9:9+53]].apply(lambda r: [exotic.columns[9:9+53][i] for i, e in enumerate(r) if (1-float(e)) >= b_start and (1-float(e)) < b_end], axis=1)
exotic
# Out:
# 0.6
# 0.7
# 0.8
# 0.9
# 0.6
# 0.7
# 0.8
# 0.9
#       symbol             ensg   HGNC                 Exon  Ratio_num  mRNA_nb  \
# 50     ABCB6  ENSG00000115657     47  220082392-220082529   0.500000        1
# 112    ABCC6  ENSG00000091262     57    16243990-16244098   0.666667        2
# 113    ABCC6  ENSG00000091262     57    16244435-16244629   0.666667        2
# 114    ABCC6  ENSG00000091262     57    16248485-16248651   0.666667        2
# 115    ABCC6  ENSG00000091262     57    16248730-16248888   0.666667        2
# ...      ...              ...    ...                  ...        ...      ...
# 26513  ZAP70  ENSG00000115085  12858    98349346-98349484   0.500000        1
# 26514  ZAP70  ENSG00000115085  12858    98349588-98349675   0.500000        1
# 26515  ZAP70  ENSG00000115085  12858    98349760-98349806   0.500000        1
# 26516  ZAP70  ENSG00000115085  12858    98350007-98350058   0.500000        1
# 26517  ZAP70  ENSG00000115085  12858    98351015-98351175   0.500000        1
#
#        mRNA_nb_total                        MAP  mean_proportion  \
# 50                 2  ABCB6_220082392-220082529          0.20161
# 112                3    ABCC6_16243990-16244098          0.32334
# 113                3    ABCC6_16244435-16244629          0.32334
# 114                3    ABCC6_16248485-16248651          0.32334
# 115                3    ABCC6_16248730-16248888          0.32334
# ...              ...                        ...              ...
# 26513              2    ZAP70_98349346-98349484          0.52513
# 26514              2    ZAP70_98349588-98349675          0.52513
# 26515              2    ZAP70_98349760-98349806          0.52513
# 26516              2    ZAP70_98350007-98350058          0.52513
# 26517              2    ZAP70_98351015-98351175          0.53976
#
#        Adipose - Subcutaneous  ...  EXOTIC_bins_up  \
# 50                   0.501000  ...      0.6 - 0.65
# 112                  0.486503  ...      0.9 - 0.95
# 113                  0.486503  ...      0.9 - 0.95
# 114                  0.486503  ...      0.9 - 0.95
# 115                  0.486503  ...      0.9 - 0.95
# ...                       ...  ...             ...
# 26513                0.481259  ...      0.6 - 0.65
# 26514                0.481259  ...      0.6 - 0.65
# 26515                0.481259  ...      0.6 - 0.65
# 26516                0.481259  ...      0.6 - 0.65
# 26517                0.476767  ...      0.6 - 0.65
#
#                            EXOTIC_tissues_up  \
# 50                       [Muscle - Skeletal]
# 112    [Cells - EBV-transformed lymphocytes]
# 113    [Cells - EBV-transformed lymphocytes]
# 114    [Cells - EBV-transformed lymphocytes]
# 115    [Cells - EBV-transformed lymphocytes]
# ...                                      ...
# 26513        [Brain - Cerebellar Hemisphere]
# 26514        [Brain - Cerebellar Hemisphere]
# 26515        [Brain - Cerebellar Hemisphere]
# 26516        [Brain - Cerebellar Hemisphere]
# 26517        [Brain - Cerebellar Hemisphere]
#
#                                      EXOTIC_0.6 - 0.7_up  EXOTIC_0.7 - 0.8_up  \
# 50                                   [Muscle - Skeletal]                   []
# 112                             [Esophagus - Muscularis]                   []
# 113                             [Esophagus - Muscularis]                   []
# 114                             [Esophagus - Muscularis]                   []
# 115                             [Esophagus - Muscularis]                   []
# ...                                                  ...                  ...
# 26513                    [Brain - Cerebellar Hemisphere]                   []
# 26514                    [Brain - Cerebellar Hemisphere]                   []
# 26515                    [Brain - Cerebellar Hemisphere]                   []
# 26516                    [Brain - Cerebellar Hemisphere]                   []
# 26517  [Brain - Cerebellar Hemisphere, Brain - Cerebe...                   []
#
#        EXOTIC_0.8 - 0.9_up                    EXOTIC_0.9 - 1.0_up  \
# 50                      []                                     []
# 112                     []  [Cells - EBV-transformed lymphocytes]
# 113                     []  [Cells - EBV-transformed lymphocytes]
# 114                     []  [Cells - EBV-transformed lymphocytes]
# 115                     []  [Cells - EBV-transformed lymphocytes]
# ...                    ...                                    ...
# 26513                   []                                     []
# 26514                   []                                     []
# 26515                   []                                     []
# 26516                   []                                     []
# 26517                   []                                     []
#
#        EXOTIC_0.6 - 0.7_down  EXOTIC_0.7 - 0.8_down  EXOTIC_0.8 - 0.9_down  \
# 50             [Whole Blood]                     []                     []
# 112                       []                     []                     []
# 113                       []                     []                     []
# 114                       []                     []                     []
# 115                       []                     []                     []
# ...                      ...                    ...                    ...
# 26513                     []                     []                     []
# 26514                     []                     []                     []
# 26515                     []                     []                     []
# 26516                     []                     []                     []
# 26517                     []                     []                     []
#
#        EXOTIC_0.9 - 1.0_down
# 50                        []
# 112                       []
# 113                       []
# 114                       []
# 115                       []
# ...                      ...
# 26513                     []
# 26514                     []
# 26515                     []
# 26516                     []
# 26517                     []
#
# [2386 rows x 76 columns]

# %%
print(exotic.symbol.nunique())
# Out:
# 352

# %% [markdown]
# # Clinvar

# %%
clinvar = pd.read_parquet(files['EXOTIC']['clinvar_file_path'])
clinvar = clinvar.loc[(clinvar['Status'] == 'Pathogenic') & (clinvar['Real_Status'].str.contains('onflict') == False)]
clinvar = clinvar.loc[clinvar['OMIM_VARIANT_ID'] != ""]
clinvar
# Out:
#           GENE             VAR_ID CHROM      POS REF     ALT  \
# 125      ISG15   1_949523_C_['T']     1   949523   C   ['T']
# 138      ISG15  1_949696_C_['CG']     1   949696   C  ['CG']
# 141      ISG15   1_949739_G_['T']     1   949739   G   ['T']
# 247       AGRN   1_976962_C_['T']     1   976962   C   ['T']
# 777       AGRN   1_985955_G_['C']     1   985955   G   ['C']
# ...        ...                ...   ...      ...  ..     ...
# 768743     SRY  Y_2655633_A_['T']     Y  2655633   A   ['T']
# 768744     SRY  Y_2655641_G_['A']     Y  2655641   G   ['A']
# 768745   TBL1Y  Y_6931939_A_['T']     Y  6931939   A   ['T']
# 769854  MT-ND4   MT_11778_G_['A']    MT    11778   G   ['A']
# 770208  MT-ND6   MT_14484_T_['C']    MT    14484   T   ['C']
#
#                         MC      Status Real_Status  RS_STARS  \
# 125               nonsense  Pathogenic  Pathogenic         0
# 138     frameshift_variant  Pathogenic  Pathogenic         0
# 141               nonsense  Pathogenic  Pathogenic         0
# 247               nonsense  Pathogenic  Pathogenic         0
# 777       missense_variant  Pathogenic  Pathogenic         0
# ...                    ...         ...         ...       ...
# 768743            nonsense  Pathogenic  Pathogenic         0
# 768744            nonsense  Pathogenic  Pathogenic         0
# 768745    missense_variant  Pathogenic  Pathogenic         0
# 769854    missense_variant  Pathogenic  Pathogenic         2
# 770208    missense_variant  Pathogenic  Pathogenic         2
#
#                                                CLNREVSTAT  \
# 125                        no_assertion_criteria_provided
# 138                        no_assertion_criteria_provided
# 141                        no_assertion_criteria_provided
# 247                        no_assertion_criteria_provided
# 777                        no_assertion_criteria_provided
# ...                                                   ...
# 768743                     no_assertion_criteria_provided
# 768744                     no_assertion_criteria_provided
# 768745                     no_assertion_criteria_provided
# 769854  criteria_provided,_multiple_submitters,_no_con...
# 770208  criteria_provided,_multiple_submitters,_no_con...
#
#                              HPO         rs  alleleid OMIM_VARIANT_ID
# 125                           []  786201005    181485     147571.0003
# 138                           []  672601345    171289     147571.0002
# 141                           []  672601312    171288     147571.0001
# 247                           []  587777299    132069     103320.0003
# 777                           []  199476396     33280     103320.0001
# ...                          ...        ...       ...             ...
# 768743                        []  104894975     24790     480000.0018
# 768744                        []  104894977     24792     480000.0020
# 768745                        []  199659121    613772     400033.0001
# 769854  [HP:0001086, HP:0001112]  199476112     24747     516003.0001
# 770208  [HP:0001086, HP:0001112]  199476104     24727     516006.0001
#
# [22275 rows x 15 columns]

# %%
exotic
# Out:
#       symbol             ensg   HGNC                 Exon  Ratio_num  mRNA_nb  \
# 50     ABCB6  ENSG00000115657     47  220082392-220082529   0.500000        1
# 112    ABCC6  ENSG00000091262     57    16243990-16244098   0.666667        2
# 113    ABCC6  ENSG00000091262     57    16244435-16244629   0.666667        2
# 114    ABCC6  ENSG00000091262     57    16248485-16248651   0.666667        2
# 115    ABCC6  ENSG00000091262     57    16248730-16248888   0.666667        2
# ...      ...              ...    ...                  ...        ...      ...
# 26513  ZAP70  ENSG00000115085  12858    98349346-98349484   0.500000        1
# 26514  ZAP70  ENSG00000115085  12858    98349588-98349675   0.500000        1
# 26515  ZAP70  ENSG00000115085  12858    98349760-98349806   0.500000        1
# 26516  ZAP70  ENSG00000115085  12858    98350007-98350058   0.500000        1
# 26517  ZAP70  ENSG00000115085  12858    98351015-98351175   0.500000        1
#
#        mRNA_nb_total                        MAP  mean_proportion  \
# 50                 2  ABCB6_220082392-220082529          0.20161
# 112                3    ABCC6_16243990-16244098          0.32334
# 113                3    ABCC6_16244435-16244629          0.32334
# 114                3    ABCC6_16248485-16248651          0.32334
# 115                3    ABCC6_16248730-16248888          0.32334
# ...              ...                        ...              ...
# 26513              2    ZAP70_98349346-98349484          0.52513
# 26514              2    ZAP70_98349588-98349675          0.52513
# 26515              2    ZAP70_98349760-98349806          0.52513
# 26516              2    ZAP70_98350007-98350058          0.52513
# 26517              2    ZAP70_98351015-98351175          0.53976
#
#        Adipose - Subcutaneous  ...                      EXOTIC_tissues_up  \
# 50                   0.501000  ...                    [Muscle - Skeletal]
# 112                  0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 113                  0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 114                  0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 115                  0.486503  ...  [Cells - EBV-transformed lymphocytes]
# ...                       ...  ...                                    ...
# 26513                0.481259  ...        [Brain - Cerebellar Hemisphere]
# 26514                0.481259  ...        [Brain - Cerebellar Hemisphere]
# 26515                0.481259  ...        [Brain - Cerebellar Hemisphere]
# 26516                0.481259  ...        [Brain - Cerebellar Hemisphere]
# 26517                0.476767  ...        [Brain - Cerebellar Hemisphere]
#
#                                      EXOTIC_0.6 - 0.7_up  EXOTIC_0.7 - 0.8_up  \
# 50                                   [Muscle - Skeletal]                   []
# 112                             [Esophagus - Muscularis]                   []
# 113                             [Esophagus - Muscularis]                   []
# 114                             [Esophagus - Muscularis]                   []
# 115                             [Esophagus - Muscularis]                   []
# ...                                                  ...                  ...
# 26513                    [Brain - Cerebellar Hemisphere]                   []
# 26514                    [Brain - Cerebellar Hemisphere]                   []
# 26515                    [Brain - Cerebellar Hemisphere]                   []
# 26516                    [Brain - Cerebellar Hemisphere]                   []
# 26517  [Brain - Cerebellar Hemisphere, Brain - Cerebe...                   []
#
#        EXOTIC_0.8 - 0.9_up                    EXOTIC_0.9 - 1.0_up  \
# 50                      []                                     []
# 112                     []  [Cells - EBV-transformed lymphocytes]
# 113                     []  [Cells - EBV-transformed lymphocytes]
# 114                     []  [Cells - EBV-transformed lymphocytes]
# 115                     []  [Cells - EBV-transformed lymphocytes]
# ...                    ...                                    ...
# 26513                   []                                     []
# 26514                   []                                     []
# 26515                   []                                     []
# 26516                   []                                     []
# 26517                   []                                     []
#
#        EXOTIC_0.6 - 0.7_down  EXOTIC_0.7 - 0.8_down  EXOTIC_0.8 - 0.9_down  \
# 50             [Whole Blood]                     []                     []
# 112                       []                     []                     []
# 113                       []                     []                     []
# 114                       []                     []                     []
# 115                       []                     []                     []
# ...                      ...                    ...                    ...
# 26513                     []                     []                     []
# 26514                     []                     []                     []
# 26515                     []                     []                     []
# 26516                     []                     []                     []
# 26517                     []                     []                     []
#
#        EXOTIC_0.9 - 1.0_down  \
# 50                        []
# 112                       []
# 113                       []
# 114                       []
# 115                       []
# ...                      ...
# 26513                     []
# 26514                     []
# 26515                     []
# 26516                     []
# 26517                     []
#
#                                            OMIM_variants
# 50                                                   NaN
# 112                                                  NaN
# 113                           [603234.0008, 603234.0026]
# 114                                                  NaN
# 115    [603234.0017, 603234.0021, 603234.0006, 603234...
# ...                                                  ...
# 26513                                      [176947.0006]
# 26514                                                NaN
# 26515                                                NaN
# 26516                                                NaN
# 26517                                      [176947.0007]
#
# [2386 rows x 77 columns]

# %%
def mp_variants(gene, exotic, clinvar, l):
    exotic_tmp_gene = exotic.loc[exotic['symbol'] == gene]
    clinvar_tmp_gene = clinvar.loc[clinvar['GENE'] == gene]
    for exon in exotic_tmp_gene.Exon.unique().tolist():
        match_variants = clinvar_tmp_gene.POS.between(-10 + int(exon.split('-')[0]), int(exon.split('-')[1]) + 10)
        match_variants = clinvar_tmp_gene.loc[match_variants.loc[match_variants == True].index.tolist(), 'OMIM_VARIANT_ID'].values.tolist()
        if match_variants:
            l.append({exon : match_variants})
        
# for gene in tqdm():
m = multiprocessing.Manager()
l = m.list()
genes = exotic.symbol.unique().tolist()
parmap.starmap(mp_variants, list(zip(genes)), exotic, clinvar, l, pm_pbar=True)
map_d = {k: v for d in l for k, v in d.items()}
exotic['OMIM_variants'] = exotic['Exon'].map(map_d)
exotic.head()

# print(l)
# Out:
# 100%|██████████| 352/352 [00:33<00:00, 10.39it/s]
#     symbol             ensg  HGNC                 Exon  Ratio_num  mRNA_nb  \
# 50   ABCB6  ENSG00000115657    47  220082392-220082529   0.500000        1
# 112  ABCC6  ENSG00000091262    57    16243990-16244098   0.666667        2
# 113  ABCC6  ENSG00000091262    57    16244435-16244629   0.666667        2
# 114  ABCC6  ENSG00000091262    57    16248485-16248651   0.666667        2
# 115  ABCC6  ENSG00000091262    57    16248730-16248888   0.666667        2
#
#      mRNA_nb_total                        MAP  mean_proportion  \
# 50               2  ABCB6_220082392-220082529          0.20161
# 112              3    ABCC6_16243990-16244098          0.32334
# 113              3    ABCC6_16244435-16244629          0.32334
# 114              3    ABCC6_16248485-16248651          0.32334
# 115              3    ABCC6_16248730-16248888          0.32334
#
#      Adipose - Subcutaneous  ...                      EXOTIC_tissues_up  \
# 50                 0.501000  ...                    [Muscle - Skeletal]
# 112                0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 113                0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 114                0.486503  ...  [Cells - EBV-transformed lymphocytes]
# 115                0.486503  ...  [Cells - EBV-transformed lymphocytes]
#
#           EXOTIC_0.6 - 0.7_up  EXOTIC_0.7 - 0.8_up  EXOTIC_0.8 - 0.9_up  \
# 50        [Muscle - Skeletal]                   []                   []
# 112  [Esophagus - Muscularis]                   []                   []
# 113  [Esophagus - Muscularis]                   []                   []
# 114  [Esophagus - Muscularis]                   []                   []
# 115  [Esophagus - Muscularis]                   []                   []
#
#                        EXOTIC_0.9 - 1.0_up  EXOTIC_0.6 - 0.7_down  \
# 50                                      []          [Whole Blood]
# 112  [Cells - EBV-transformed lymphocytes]                     []
# 113  [Cells - EBV-transformed lymphocytes]                     []
# 114  [Cells - EBV-transformed lymphocytes]                     []
# 115  [Cells - EBV-transformed lymphocytes]                     []
#
#      EXOTIC_0.7 - 0.8_down  EXOTIC_0.8 - 0.9_down  EXOTIC_0.9 - 1.0_down  \
# 50                      []                     []                     []
# 112                     []                     []                     []
# 113                     []                     []                     []
# 114                     []                     []                     []
# 115                     []                     []                     []
#
#                                          OMIM_variants
# 50                                                 NaN
# 112                                                NaN
# 113                         [603234.0008, 603234.0026]
# 114                                                NaN
# 115  [603234.0017, 603234.0021, 603234.0006, 603234...
#
# [5 rows x 77 columns]

# %%
list(exotic_omim_variants_exploded.Pheno_OMIM.values.tolist()[0])[0]

# %%
dicts_omim_gtex = pd.DataFrame.from_dict(dicts['mapping_omim_gtex_neurologic'], orient='index')
dicts_omim_gtex['Pheno'] = dicts_omim_gtex.apply(lambda r: [e for e in r if e], axis=1)
dicts_omim_gtex = dicts_omim_gtex['Pheno']
dicts_omim_gtex = dicts_omim_gtex.reset_index()
dicts_omim_gtex.columns = ['value', 'Pheno']
dicts_omim_gtex = dicts_omim_gtex.explode('Pheno')

# %%
exotic_omim_variants = exotic.loc[exotic['OMIM_variants'].isna() == False]
exotic_omim_variants_exploded = exotic_omim_variants.explode('OMIM_variants')
exotic_omim_variants_exploded['OMIM'] = exotic_omim_variants_exploded['OMIM_variants'].apply(lambda r: r.split('.')[0])
exotic_omim_variants_exploded['OMIM_variants'] = exotic_omim_variants_exploded['OMIM_variants'].astype(str)
exotic_omim_variants_exploded['OMIM_variant_nb'] = exotic_omim_variants_exploded['OMIM_variants'].apply(lambda r : int(r.split('.')[1]))
exotic_omim_variants_exploded = pd.merge(exotic_omim_variants_exploded, omim_multi_pheno_filterred[['Name', 'Pheno_OMIM', 'OMIM_BP', 'OMIM_BP_phenotypes']], left_on='symbol', right_on='Name')
exotic_omim_variants_exploded = exotic_omim_variants_exploded.melt(id_vars=['symbol', 'ensg', 'HGNC', 'Exon', 'Ratio_num', 'mRNA_nb', 'mRNA_nb_total', 'MAP', 'OMIM_variants', 'OMIM', 'OMIM_variant_nb', 'Name', 'Pheno_OMIM', 'OMIM_BP', 'OMIM_BP_phenotypes'],
                                  value_vars=['EXOTIC_0.6 - 0.7_up', 'EXOTIC_0.7 - 0.8_up', 'EXOTIC_0.8 - 0.9_up', 'EXOTIC_0.9 - 1.0_up', 'EXOTIC_0.6 - 0.7_down', 'EXOTIC_0.7 - 0.8_down', 'EXOTIC_0.8 - 0.9_down', 'EXOTIC_0.9 - 1.0_down']).explode('value').dropna(subset=['value'])
print(exotic_omim_variants_exploded.shape)
exotic_omim_variants_exploded.head()
exotic_omim_variants_exploded = pd.merge(exotic_omim_variants_exploded, dicts_omim_gtex, on='value')
exotic_omim_variants_exploded = exotic_omim_variants_exploded.loc[exotic_omim_variants_exploded['OMIM_BP'] == exotic_omim_variants_exploded['Pheno']]
exotic_omim_variants_exploded = pd.merge(exotic_omim_variants_exploded.rename({'OMIM_variants' : 'OMIM_VARIANT_ID'}, axis=1), clinvar[['VAR_ID', 'MC', 'Real_Status', 'RS_STARS', 'CLNREVSTAT', 'alleleid', 'OMIM_VARIANT_ID']], on='OMIM_VARIANT_ID')
exotic_omim_variants_exploded
# Out:
# (70216, 17)
#       symbol             ensg   HGNC                 Exon  Ratio_num  mRNA_nb  \
# 0      ACOX1  ENSG00000161533    119    73956296-73956456   0.666667        2
# 1     CLCNKB  ENSG00000184908   2027    16373030-16373158   0.500000        1
# 2     CLCNKB  ENSG00000184908   2027    16373030-16373158   0.500000        1
# 3     CLCNKB  ENSG00000184908   2027    16374400-16374539   0.500000        1
# 4     CLCNKB  ENSG00000184908   2027    16374400-16374539   0.500000        1
# ...      ...              ...    ...                  ...        ...      ...
# 1522    TP63  ENSG00000073282  15979  189608578-189608671   0.750000        3
# 1523     WT1  ENSG00000184937  12796    32456246-32456906   0.333333        1
# 1524     WT1  ENSG00000184937  12796    32456246-32456906   0.333333        1
# 1525    GLB1  ENSG00000170266   4298    33138503-33138577   0.750000        3
# 1526    GLB1  ENSG00000170266   4298    33138503-33138577   0.750000        3
#
#       mRNA_nb_total                       MAP OMIM_VARIANT_ID    OMIM  ...  \
# 0                 3   ACOX1_73956296-73956456     609751.0006  609751  ...
# 1                 2  CLCNKB_16373030-16373158     602023.0010  602023  ...
# 2                 2  CLCNKB_16373030-16373158     602023.0010  602023  ...
# 3                 2  CLCNKB_16374400-16374539     602023.0001  602023  ...
# 4                 2  CLCNKB_16374400-16374539     602023.0001  602023  ...
# ...             ...                       ...             ...     ...  ...
# 1522              4  TP63_189608578-189608671     603273.0019  603273  ...
# 1523              3     WT1_32456246-32456906     607102.0027  607102  ...
# 1524              3     WT1_32456246-32456906     607102.0027  607102  ...
# 1525              4    GLB1_33138503-33138577     611458.0014  611458  ...
# 1526              4    GLB1_33138503-33138577     611458.0014  611458  ...
#
#                                      OMIM_BP_phenotypes  \
# 0     ['Brachycephaly {SNOMEDCT:13649004} {UMLS C022...
# 1     ['Delayed motor development {UMLS C1854301 HP:...
# 2     ['Delayed motor development {UMLS C1854301 HP:...
# 3     ['Delayed motor development {UMLS C1854301 HP:...
# 4     ['Delayed motor development {UMLS C1854301 HP:...
# ...                                                 ...
# 1522  ['Ventricular septal defect {SNOMEDCT:76855200...
# 1523  ['Gonadal dysgenesis {SNOMEDCT:205681004,38804...
# 1524  ['Pure gonadal dysgenesis {SNOMEDCT:95219002} ...
# 1525  ['Angiokeratoma corporis diffusum {SNOMEDCT:16...
# 1526  ['Angiokeratoma corporis diffusum {SNOMEDCT:16...
#
#                    variable                                value  \
# 0       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 1       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 2       EXOTIC_0.6 - 0.7_up        Brain - Cerebellar Hemisphere
# 3       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 4       EXOTIC_0.6 - 0.7_up        Brain - Cerebellar Hemisphere
# ...                     ...                                  ...
# 1522  EXOTIC_0.9 - 1.0_down             Heart - Atrial Appendage
# 1523    EXOTIC_0.6 - 0.7_up                  Cervix - Endocervix
# 1524    EXOTIC_0.6 - 0.7_up                  Cervix - Endocervix
# 1525  EXOTIC_0.6 - 0.7_down  Skin - Not Sun Exposed (Suprapubic)
# 1526  EXOTIC_0.6 - 0.7_down       Skin - Sun Exposed (Lower leg)
#
#                                      Pheno  \
# 0                          headAndNeckHead
# 1           neurologicCentralNervousSystem
# 2           neurologicCentralNervousSystem
# 3           neurologicCentralNervousSystem
# 4           neurologicCentralNervousSystem
# ...                                    ...
# 1522                   cardiovascularHeart
# 1523  genitourinaryInternalGenitaliaFemale
# 1524  genitourinaryInternalGenitaliaFemale
# 1525                     skinNailsHairSkin
# 1526                     skinNailsHairSkin
#
#                                      VAR_ID                               MC  \
# 0     17_73956336_CAAGTTCCAGGCGGGCATG_['C']      inframe_deletion,SO:0001627
# 1                        1_16373029_G_['C']          splice_acceptor_variant
# 2                        1_16373029_G_['C']          splice_acceptor_variant
# 3                        1_16374412_C_['T']                 missense_variant
# 4                        1_16374412_C_['T']                 missense_variant
# ...                                     ...                              ...
# 1522                    3_189608663_T_['C']      missense_variant,SO:0001627
# 1523                    11_32456361_G_['T']              nonsense,SO:0001619
# 1524                    11_32456361_G_['T']              nonsense,SO:0001619
# 1525                    3_33138500_T_['TA']  splice_donor_variant,SO:0001623
# 1526                    3_33138500_T_['TA']  splice_donor_variant,SO:0001623
#
#      Real_Status RS_STARS                                         CLNREVSTAT  \
# 0     Pathogenic        0                     no_assertion_criteria_provided
# 1     Pathogenic        0                     no_assertion_criteria_provided
# 2     Pathogenic        0                     no_assertion_criteria_provided
# 3     Pathogenic        0                     no_assertion_criteria_provided
# 4     Pathogenic        0                     no_assertion_criteria_provided
# ...          ...      ...                                                ...
# 1522  Pathogenic        0                     no_assertion_criteria_provided
# 1523  Pathogenic        0                     no_assertion_criteria_provided
# 1524  Pathogenic        0                     no_assertion_criteria_provided
# 1525  Pathogenic        2  criteria_provided,_multiple_submitters,_no_con...
# 1526  Pathogenic        2  criteria_provided,_multiple_submitters,_no_con...
#
#      alleleid
# 0       16542
# 1       22639
# 2       22639
# 3       22630
# 4       22630
# ...       ...
# 1522    21584
# 1523    18545
# 1524    18545
# 1525    15975
# 1526    15975
#
# [1527 rows x 24 columns]

# %%
import _pickle
import re
# for gene in exotic_omim_variants_exploded['OMIM'].unique()[:1]:
def retrieve_omim_variants_info(r):
#     print(r)
#     print(r['Pheno_OMIM'])
    omim_gene_json = _pickle.load(open('/gstock/biolo_datasets/variation/benchmark/Databases/OMIM/JSON_API/{}.pkl'.format(str(r['OMIM'])), 'rb'))
    variant_json = omim_gene_json['omim']['entryList'][0]['entry']['allelicVariantList'][r['OMIM_variant_nb'] - 1]['allelicVariant']
#     print(variant_json)
    if variant_json['text'].startswith('See {') is False:

        pheno_id = [publi for publi in re.findall('\{.*?\}', variant_json['text']) if ':' not in publi and  '.' not in publi]
        if pheno_id:
            pheno_id = pheno_id[0]
            pheno_id = int(pheno_id.replace('{', '').replace('}', ''))
            publi_ids = [publi for publi in re.findall('\{.*?\}', variant_json['text']) if ':' in publi]
            publi_ids = [sub_publi for publi in publi_ids for sub_publi in publi.split(':')[0].replace('{', '').split(',')]

            
            if pheno_id == r['Pheno_OMIM']:
                pmids = []
                try:
                    pmids = [omim_gene_json['omim']['entryList'][0]['entry']['referenceList'][int(publi.split(':')[0].replace('{', '')) - 1]['reference']['pubmedID'] for publi in publi_ids]
                except:
#                     pprint([omim_gene_json['omim']['entryList'][0]['entry']['referenceList'][int(publi.split(':')[0].replace('{', '')) - 1]['reference'] for publi in publi_ids])
                    pass
                return pmids
# exotic_omim_variants_exploded.loc[exotic_omim_variants_exploded['symbol'] == 'TP63'].apply(lambda r: retrieve_omim_variants_info(r), axis=1)   
exotic_omim_variants_exploded['PMIDS_OMIM'] = exotic_omim_variants_exploded.apply(lambda r: retrieve_omim_variants_info(r), axis=1)    
exotic_omim_variants_exploded
# Out:
#       symbol             ensg   HGNC                 Exon  Ratio_num  mRNA_nb  \
# 0      ACOX1  ENSG00000161533    119    73956296-73956456   0.666667        2
# 1     CLCNKB  ENSG00000184908   2027    16373030-16373158   0.500000        1
# 2     CLCNKB  ENSG00000184908   2027    16373030-16373158   0.500000        1
# 3     CLCNKB  ENSG00000184908   2027    16374400-16374539   0.500000        1
# 4     CLCNKB  ENSG00000184908   2027    16374400-16374539   0.500000        1
# ...      ...              ...    ...                  ...        ...      ...
# 1522    TP63  ENSG00000073282  15979  189608578-189608671   0.750000        3
# 1523     WT1  ENSG00000184937  12796    32456246-32456906   0.333333        1
# 1524     WT1  ENSG00000184937  12796    32456246-32456906   0.333333        1
# 1525    GLB1  ENSG00000170266   4298    33138503-33138577   0.750000        3
# 1526    GLB1  ENSG00000170266   4298    33138503-33138577   0.750000        3
#
#       mRNA_nb_total                       MAP OMIM_VARIANT_ID    OMIM  ...  \
# 0                 3   ACOX1_73956296-73956456     609751.0006  609751  ...
# 1                 2  CLCNKB_16373030-16373158     602023.0010  602023  ...
# 2                 2  CLCNKB_16373030-16373158     602023.0010  602023  ...
# 3                 2  CLCNKB_16374400-16374539     602023.0001  602023  ...
# 4                 2  CLCNKB_16374400-16374539     602023.0001  602023  ...
# ...             ...                       ...             ...     ...  ...
# 1522              4  TP63_189608578-189608671     603273.0019  603273  ...
# 1523              3     WT1_32456246-32456906     607102.0027  607102  ...
# 1524              3     WT1_32456246-32456906     607102.0027  607102  ...
# 1525              4    GLB1_33138503-33138577     611458.0014  611458  ...
# 1526              4    GLB1_33138503-33138577     611458.0014  611458  ...
#
#                    variable                                value  \
# 0       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 1       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 2       EXOTIC_0.6 - 0.7_up        Brain - Cerebellar Hemisphere
# 3       EXOTIC_0.6 - 0.7_up                   Brain - Cerebellum
# 4       EXOTIC_0.6 - 0.7_up        Brain - Cerebellar Hemisphere
# ...                     ...                                  ...
# 1522  EXOTIC_0.9 - 1.0_down             Heart - Atrial Appendage
# 1523    EXOTIC_0.6 - 0.7_up                  Cervix - Endocervix
# 1524    EXOTIC_0.6 - 0.7_up                  Cervix - Endocervix
# 1525  EXOTIC_0.6 - 0.7_down  Skin - Not Sun Exposed (Suprapubic)
# 1526  EXOTIC_0.6 - 0.7_down       Skin - Sun Exposed (Lower leg)
#
#                                      Pheno  \
# 0                          headAndNeckHead
# 1           neurologicCentralNervousSystem
# 2           neurologicCentralNervousSystem
# 3           neurologicCentralNervousSystem
# 4           neurologicCentralNervousSystem
# ...                                    ...
# 1522                   cardiovascularHeart
# 1523  genitourinaryInternalGenitaliaFemale
# 1524  genitourinaryInternalGenitaliaFemale
# 1525                     skinNailsHairSkin
# 1526                     skinNailsHairSkin
#
#                                      VAR_ID                               MC  \
# 0     17_73956336_CAAGTTCCAGGCGGGCATG_['C']      inframe_deletion,SO:0001627
# 1                        1_16373029_G_['C']          splice_acceptor_variant
# 2                        1_16373029_G_['C']          splice_acceptor_variant
# 3                        1_16374412_C_['T']                 missense_variant
# 4                        1_16374412_C_['T']                 missense_variant
# ...                                     ...                              ...
# 1522                    3_189608663_T_['C']      missense_variant,SO:0001627
# 1523                    11_32456361_G_['T']              nonsense,SO:0001619
# 1524                    11_32456361_G_['T']              nonsense,SO:0001619
# 1525                    3_33138500_T_['TA']  splice_donor_variant,SO:0001623
# 1526                    3_33138500_T_['TA']  splice_donor_variant,SO:0001623
#
#      Real_Status RS_STARS                                         CLNREVSTAT  \
# 0     Pathogenic        0                     no_assertion_criteria_provided
# 1     Pathogenic        0                     no_assertion_criteria_provided
# 2     Pathogenic        0                     no_assertion_criteria_provided
# 3     Pathogenic        0                     no_assertion_criteria_provided
# 4     Pathogenic        0                     no_assertion_criteria_provided
# ...          ...      ...                                                ...
# 1522  Pathogenic        0                     no_assertion_criteria_provided
# 1523  Pathogenic        0                     no_assertion_criteria_provided
# 1524  Pathogenic        0                     no_assertion_criteria_provided
# 1525  Pathogenic        2  criteria_provided,_multiple_submitters,_no_con...
# 1526  Pathogenic        2  criteria_provided,_multiple_submitters,_no_con...
#
#      alleleid          PMIDS_OMIM
# 0       16542          [17458872]
# 1       22639                None
# 2       22639                None
# 3       22630                None
# 4       22630                None
# ...       ...                 ...
# 1522    21584                None
# 1523    18545                None
# 1524    18545                None
# 1525    15975  [8199591, 8198123]
# 1526    15975  [8199591, 8198123]
#
# [1527 rows x 25 columns]

# %%
exotic_omim_variants_exploded.symbol.nunique()
# Out:
# 37

# %%
sorted(exotic_omim_variants_exploded.symbol.unique().tolist())
# Out:
# ['ACOX1',
#  'BCS1L',
#  'CACNA1D',
#  'DGUOK',
#  'DNM1L',
#  'DOK7',
#  'ERBB3',
#  'FGFR2',
#  'FGFR3',
#  'GATA2',
#  'GATA4',
#  'GLB1',
#  'GNAO1',
#  'GNAS',
#  'GNE',
#  'IFT43',
#  'KLHL7',
#  'LRP5',
#  'MECP2',
#  'MVK',
#  'MYRF',
#  'NAA10',
#  'NF1',
#  'NLRC4',
#  'NUP214',
#  'POLD1',
#  'PRX',
#  'PTEN',
#  'RAD51',
#  'REEP1',
#  'SCN1B',
#  'TGFBR1',
#  'TNFRSF11A',
#  'TP63',
#  'TPM2',
#  'TTC8',
#  'WWOX']

# %%
pd.options.display.max_rows = 515
exotic_omim_variants_exploded = exotic_omim_variants_exploded.loc[exotic_omim_variants_exploded['PMIDS_OMIM'].isna() == False]
exotic_omim_variants_exploded.loc[exotic_omim_variants_exploded['symbol'] != 'PTEN'].sort_values(by='symbol', ascending=True).to_excel('/gstock/EXOTIC/data/PHENOTYPES/exotic_omim_variants_filtered.xlsx', index=False)

# %%
exotic.loc[exotic['symbol'] == 'LRP5']
# Out:
#       symbol             ensg  HGNC               Exon  Ratio_num  mRNA_nb  \
# 12844   LRP5  ENSG00000162337  6697  68080183-68080273        0.5        1
# 12845   LRP5  ENSG00000162337  6697  68115315-68115711        0.5        1
# 12846   LRP5  ENSG00000162337  6697  68125118-68125315        0.5        1
# 12847   LRP5  ENSG00000162337  6697  68131215-68131411        0.5        1
# 12848   LRP5  ENSG00000162337  6697  68133039-68133170        0.5        1
# 12849   LRP5  ENSG00000162337  6697  68153784-68154180        0.5        1
# 12850   LRP5  ENSG00000162337  6697  68157349-68157520        0.5        1
# 12851   LRP5  ENSG00000162337  6697  68170951-68171167        0.5        1
#
#        mRNA_nb_total                     MAP  mean_proportion  \
# 12844              2  LRP5_68080183-68080273          0.58403
# 12845              2  LRP5_68115315-68115711          0.58403
# 12846              2  LRP5_68125118-68125315          0.58403
# 12847              2  LRP5_68131215-68131411          0.58403
# 12848              2  LRP5_68133039-68133170          0.58403
# 12849              2  LRP5_68153784-68154180          0.58403
# 12850              2  LRP5_68157349-68157520          0.58403
# 12851              2  LRP5_68170951-68171167          0.58403
#
#        Adipose - Subcutaneous  ...               EXOTIC_tissues_up  \
# 12844                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12845                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12846                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12847                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12848                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12849                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12850                 0.50175  ...  [Cells - Cultured fibroblasts]
# 12851                 0.50175  ...  [Cells - Cultured fibroblasts]
#
#        EXOTIC_0.6 - 0.7_up  EXOTIC_0.7 - 0.8_up  EXOTIC_0.8 - 0.9_up  \
# 12844                   []                   []                   []
# 12845                   []                   []                   []
# 12846                   []                   []                   []
# 12847                   []                   []                   []
# 12848                   []                   []                   []
# 12849                   []                   []                   []
# 12850                   []                   []                   []
# 12851                   []                   []                   []
#
#        EXOTIC_0.9 - 1.0_up  EXOTIC_0.6 - 0.7_down  EXOTIC_0.7 - 0.8_down  \
# 12844                   []                     []                [Liver]
# 12845                   []                     []                [Liver]
# 12846                   []                     []                [Liver]
# 12847                   []                     []                [Liver]
# 12848                   []                     []                [Liver]
# 12849                   []                     []                [Liver]
# 12850                   []                     []                [Liver]
# 12851                   []                     []                [Liver]
#
#        EXOTIC_0.8 - 0.9_down  EXOTIC_0.9 - 1.0_down  \
# 12844                     []                     []
# 12845                     []                     []
# 12846                     []                     []
# 12847                     []                     []
# 12848                     []                     []
# 12849                     []                     []
# 12850                     []                     []
# 12851                     []                     []
#
#                                            OMIM_variants
# 12844                                      [603506.0001]
# 12845                                      [603506.0025]
# 12846  [603506.0014, 603506.0013, 603506.0016, 603506...
# 12847  [603506.0015, 603506.0031, 603506.0018, 603506...
# 12848                                                NaN
# 12849  [603506.0030, 603506.0002, 603506.0026, 603506...
# 12850            [603506.0010, 603506.0003, 603506.0007]
# 12851            [603506.0029, 603506.0008, 603506.0022]
#
# [8 rows x 77 columns]

# %%
exotic_omim_variants_exploded.symbol.nunique()
# Out:
# 36

# %%
pd.options.display.max_rows = 400
exotic_omim_variants_exploded[[
    'symbol', 'Exon', 'EXOTIC_0.6 - 0.7_up', 'EXOTIC_0.7 - 0.8_up', 'EXOTIC_0.8 - 0.9_up',
       'EXOTIC_0.9 - 1.0_up', 'EXOTIC_0.6 - 0.7_down', 'EXOTIC_0.7 - 0.8_down',
       'EXOTIC_0.8 - 0.9_down', 'EXOTIC_0.9 - 1.0_down', 'PMIDS_OMIM', 'Pheno_OMIM', 'OMIM_variants'
]]

# %% [markdown]
# # Complete table to build inverted pyramid

# %% [markdown]
# ## EXOTIC imports

# %%
exotic = pd.read_parquet(files["EXOTIC"]["exotic_modified_zscore"])
exotic[['Exon_start', 'Exon_stop']] = exotic['Exon'].str.split('-', expand=True)
# exotic_up = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'up', cutoff=0.5)
# exotic_down = omim_associations_exotic.load_exotic(files["EXOTIC"]["exotic_modified_zscore"], 'down', cutoff=0.5)

# %% [markdown]
# # Clinvar

# %%
clinvar = pd.read_parquet(files['EXOTIC']['clinvar_file_path'])
clinvar = clinvar.loc[(clinvar['Status'] == 'Pathogenic') & (clinvar['Real_Status'].str.contains('onflict') == False)]
# clinvar = clinvar.loc[clinvar['OMIM_VARIANT_ID'] != ""]
# clinvar['ALT_Lite'] = clinvar['ALT'].apply(lambda r: eval(r)[0]) 
# clinvar['VAR_ID_Lite'] = clinvar['CHROM'].astype(str) + '_' + clinvar['POS'].astype(str) + '_' + clinvar['REF'].astype(str) + '_' + clinvar['ALT_Lite'].astype(str)

clinvar
# Out:
#           GENE             VAR_ID CHROM     POS REF     ALT  \
# 79      SAMD11   1_879375_C_['T']     1  879375   C   ['T']
# 105     KLHL17   1_899892_C_['A']     1  899892   C   ['A']
# 125      ISG15   1_949523_C_['T']     1  949523   C   ['T']
# 138      ISG15  1_949696_C_['CG']     1  949696   C  ['CG']
# 141      ISG15   1_949739_G_['T']     1  949739   G   ['T']
# ...        ...                ...   ...     ...  ..     ...
# 770451  MT-CYB   MT_15637_C_['T']    MT   15637   C   ['T']
# 770457  MT-CYB   MT_15649_A_['G']    MT   15649   A   ['G']
# 770467  MT-CYB   MT_15670_T_['C']    MT   15670   T   ['C']
# 770470  MT-CYB   MT_15682_A_['G']    MT   15682   A   ['G']
# 770493  MT-CYB   MT_15784_T_['C']    MT   15784   T   ['C']
#
#                         MC      Status        Real_Status  RS_STARS  \
# 79                nonsense  Pathogenic         Pathogenic         1
# 105       missense_variant  Pathogenic  Likely_pathogenic         0
# 125               nonsense  Pathogenic         Pathogenic         0
# 138     frameshift_variant  Pathogenic         Pathogenic         0
# 141               nonsense  Pathogenic         Pathogenic         0
# ...                    ...         ...                ...       ...
# 770451  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770457  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770467  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770470  synonymous_variant  Pathogenic  Likely_pathogenic         0
# 770493  synonymous_variant  Pathogenic  Likely_pathogenic         0
#
#                                  CLNREVSTAT           HPO         rs  \
# 79      criteria_provided,_single_submitter            []       None
# 105          no_assertion_criteria_provided  [HP:0002575]       None
# 125          no_assertion_criteria_provided            []  786201005
# 138          no_assertion_criteria_provided            []  672601345
# 141          no_assertion_criteria_provided            []  672601312
# ...                                     ...           ...        ...
# 770451       no_assertion_criteria_provided            []  527236190
# 770457       no_assertion_criteria_provided            []  527236191
# 770467       no_assertion_criteria_provided  [HP:0100615]  193302997
# 770470       no_assertion_criteria_provided            []  527236192
# 770493       no_assertion_criteria_provided            []  527236194
#
#         alleleid OMIM_VARIANT_ID
# 79        929884
# 105       904889
# 125       181485     147571.0003
# 138       171289     147571.0002
# 141       171288     147571.0001
# ...          ...             ...
# 770451    153620
# 770457    153621
# 770467    153650
# 770470    153622
# 770493    153624
#
# [126006 rows x 15 columns]

# %%
def mp_variants(gene, exotic, clinvar, l):
    exotic_tmp_gene = exotic.loc[exotic['symbol'] == gene]
    clinvar_tmp_gene = clinvar.loc[clinvar['GENE'] == gene]
    for exon in exotic_tmp_gene.Exon.unique().tolist():
        match_variants = clinvar_tmp_gene.POS.between(int(exon.split('-')[0]), int(exon.split('-')[1]))
        match_variants = clinvar_tmp_gene.loc[match_variants.loc[match_variants == True].index.tolist(), 'alleleid'].values.tolist()
        if match_variants:
            l.append({exon : match_variants})
        
# for gene in tqdm():
m = multiprocessing.Manager()
l = m.list()
genes = exotic.symbol.unique().tolist()
parmap.starmap(mp_variants, list(zip(genes)), exotic, clinvar, l, pm_pbar=True)
map_d = {k: v for d in l for k, v in d.items()}
exotic['AlleleIDs_clinvar'] = exotic['Exon'].map(map_d)
# exotic_up['AlleleIDs_clinvar'] = exotic_up['Exon'].map(map_d)
# exotic_down['AlleleIDs_clinvar'] = exotic_down['Exon'].map(map_d)


# print(l)
# Out:
# 6300it [06:00, 17.46it/s]

# %%
exotic.loc[exotic['AlleleIDs_clinvar'].isna() == False, 'symbol'].nunique()
# Out:
# 983

# %%
exotic_clinvar = pd.merge(exotic.explode('AlleleIDs_clinvar').rename({'AlleleIDs_clinvar' : 'alleleid'}, axis=1), clinvar, on='alleleid')
exotic_clinvar['OMIM'] = exotic_clinvar['OMIM_VARIANT_ID'].apply(lambda r: str(r).split('.')[0])
exotic_clinvar.loc[exotic_clinvar['OMIM_VARIANT_ID'] != '', 'OMIM_variant_nb'] = exotic_clinvar.loc[exotic_clinvar['OMIM_VARIANT_ID'] != '']['OMIM_VARIANT_ID'].apply(lambda r: int(str(r).split('.')[1]))
exotic_clinvar.to_csv('/gstock/EXOTIC/data/VARIATIONS/exotic_clinvar.csv.gz', compression='gzip', sep='\t', index=False)
exotic_clinvar.to_excel('/gstock/EXOTIC/data/VARIATIONS/exotic_clinvar.xlsx', index=False)
exotic_clinvar
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 12814  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12815  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12816  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12817  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 12818  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 12814        1              2  ZNF462_109686414-109689445          0.54621
# 12815        1              2  ZNF462_109686414-109689445          0.54621
# 12816        1              2  ZNF462_109686414-109689445          0.54621
# 12817        1              3    ZNF644_91403829-91406866          0.33853
# 12818        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...                                   MC  \
# 0                    0.578349  ...                             nonsense
# 1                    0.510498  ...                   frameshift_variant
# 2                    0.495250  ...        frameshift_variant,SO:0001623
# 3                    0.495250  ...                  nonsense,SO:0001623
# 4                    0.495250  ...  initiatior_codon_variant,SO:0001583
# ...                       ...  ...                                  ...
# 12814                0.496500  ...                   frameshift_variant
# 12815                0.496500  ...                   frameshift_variant
# 12816                0.496500  ...                             nonsense
# 12817                0.500250  ...          missense_variant,SO:0001627
# 12818                0.500250  ...          missense_variant,SO:0001627
#
#            Status        Real_Status  RS_STARS  \
# 0      Pathogenic  Likely_pathogenic         1
# 1      Pathogenic         Pathogenic         0
# 2      Pathogenic         Pathogenic         0
# 3      Pathogenic         Pathogenic         1
# 4      Pathogenic         Pathogenic         1
# ...           ...                ...       ...
# 12814  Pathogenic  Likely_pathogenic         1
# 12815  Pathogenic         Pathogenic         1
# 12816  Pathogenic         Pathogenic         1
# 12817  Pathogenic         Pathogenic         0
# 12818  Pathogenic         Pathogenic         0
#
#                                 CLNREVSTAT  \
# 0      criteria_provided,_single_submitter
# 1           no_assertion_criteria_provided
# 2           no_assertion_criteria_provided
# 3      criteria_provided,_single_submitter
# 4      criteria_provided,_single_submitter
# ...                                    ...
# 12814  criteria_provided,_single_submitter
# 12815  criteria_provided,_single_submitter
# 12816  criteria_provided,_single_submitter
# 12817       no_assertion_criteria_provided
# 12818       no_assertion_criteria_provided
#
#                                                      HPO          rs  \
# 0                                           [HP:0000388]  1409944554
# 1                                                     []  1567027297
# 2                                                     []  1567027610
# 3                                                     []  1567037561
# 4                                                     []        None
# ...                                                  ...         ...
# 12814                                                 []  1564106503
# 12815  [HP:0001363, HP:0001365, HP:0004494, HP:000544...  1060499550
# 12816                                                 []   562767308
# 12817                                                 []   387907109
# 12818                                                 []   146936371
#
#        OMIM_VARIANT_ID    OMIM  OMIM_variant_nb
# 0                                           NaN
# 1          614888.0003  614888              3.0
# 2          614888.0005  614888              5.0
# 3                                           NaN
# 4                                           NaN
# ...                ...     ...              ...
# 12814                                       NaN
# 12815      617371.0002  617371              2.0
# 12816                                       NaN
# 12817      614159.0001  614159              1.0
# 12818      614159.0002  614159              2.0
#
# [12819 rows x 87 columns]

# %%
exotic_clinvar
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
#       ...
# 95    None
# 96    None
# 97    None
# 98    None
# 99    None
# Length: 100, dtype: object

# %%
exotic_clinvar = pd.read_csv('/gstock/EXOTIC/data/VARIATIONS/exotic_clinvar.csv.gz', compression='gzip', sep='\t')
exotic_clinvar['OMIM'] = exotic_clinvar['OMIM'].astype(int)
# exotic_clinvar.loc[exotic_clinvar['OMIM_VARIANT_ID'] != '', 'OMIM_variant_nb'] = exotic_clinvar.loc[exotic_clinvar['OMIM_VARIANT_ID'] != '']['OMIM_VARIANT_ID'].apply(lambda r: int(str(r).split('.')[1]))
exotic_clinvar
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 12814  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12815  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12816  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12817  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 12818  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 12814        1              2  ZNF462_109686414-109689445          0.54621
# 12815        1              2  ZNF462_109686414-109689445          0.54621
# 12816        1              2  ZNF462_109686414-109689445          0.54621
# 12817        1              3    ZNF644_91403829-91406866          0.33853
# 12818        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...                                   MC  \
# 0                    0.578349  ...                             nonsense
# 1                    0.510498  ...                   frameshift_variant
# 2                    0.495250  ...        frameshift_variant,SO:0001623
# 3                    0.495250  ...                  nonsense,SO:0001623
# 4                    0.495250  ...  initiatior_codon_variant,SO:0001583
# ...                       ...  ...                                  ...
# 12814                0.496500  ...                   frameshift_variant
# 12815                0.496500  ...                   frameshift_variant
# 12816                0.496500  ...                             nonsense
# 12817                0.500250  ...          missense_variant,SO:0001627
# 12818                0.500250  ...          missense_variant,SO:0001627
#
#            Status        Real_Status  RS_STARS  \
# 0      Pathogenic  Likely_pathogenic         1
# 1      Pathogenic         Pathogenic         0
# 2      Pathogenic         Pathogenic         0
# 3      Pathogenic         Pathogenic         1
# 4      Pathogenic         Pathogenic         1
# ...           ...                ...       ...
# 12814  Pathogenic  Likely_pathogenic         1
# 12815  Pathogenic         Pathogenic         1
# 12816  Pathogenic         Pathogenic         1
# 12817  Pathogenic         Pathogenic         0
# 12818  Pathogenic         Pathogenic         0
#
#                                 CLNREVSTAT  \
# 0      criteria_provided,_single_submitter
# 1           no_assertion_criteria_provided
# 2           no_assertion_criteria_provided
# 3      criteria_provided,_single_submitter
# 4      criteria_provided,_single_submitter
# ...                                    ...
# 12814  criteria_provided,_single_submitter
# 12815  criteria_provided,_single_submitter
# 12816  criteria_provided,_single_submitter
# 12817       no_assertion_criteria_provided
# 12818       no_assertion_criteria_provided
#
#                                                      HPO            rs  \
# 0                                         ['HP:0000388']  1.409945e+09
# 1                                                     []  1.567027e+09
# 2                                                     []  1.567028e+09
# 3                                                     []  1.567038e+09
# 4                                                     []           NaN
# ...                                                  ...           ...
# 12814                                                 []  1.564107e+09
# 12815  ['HP:0001363' 'HP:0001365' 'HP:0004494' 'HP:00...  1.060500e+09
# 12816                                                 []  5.627673e+08
# 12817                                                 []  3.879071e+08
# 12818                                                 []  1.469364e+08
#
#        OMIM_VARIANT_ID      OMIM  OMIM_variant_nb
# 0                  NaN       NaN              NaN
# 1          614888.0003  614888.0              3.0
# 2          614888.0005  614888.0              5.0
# 3                  NaN       NaN              NaN
# 4                  NaN       NaN              NaN
# ...                ...       ...              ...
# 12814              NaN       NaN              NaN
# 12815      617371.0002  617371.0              2.0
# 12816              NaN       NaN              NaN
# 12817      614159.0001  614159.0              1.0
# 12818      614159.0002  614159.0              2.0
#
# [12819 rows x 87 columns]

# %%
exotic_clinvar.columns
# Out:
# Index(['symbol', 'ensg', 'HGNC', 'Exon', 'Ratio_num', 'mRNA_nb',
#        'mRNA_nb_total', 'MAP', 'mean_proportion', 'Adipose - Subcutaneous',
#        'Adipose - Visceral (Omentum)', 'Adrenal Gland', 'Artery - Aorta',
#        'Artery - Coronary', 'Artery - Tibial', 'Bladder', 'Brain - Amygdala',
#        'Brain - Anterior cingulate cortex (BA24)',
#        'Brain - Caudate (basal ganglia)', 'Brain - Cerebellar Hemisphere',
#        'Brain - Cerebellum', 'Brain - Cortex', 'Brain - Frontal Cortex (BA9)',
#        'Brain - Hippocampus', 'Brain - Hypothalamus',
#        'Brain - Nucleus accumbens (basal ganglia)',
#        'Brain - Putamen (basal ganglia)', 'Brain - Spinal cord (cervical c-1)',
#        'Brain - Substantia nigra', 'Breast - Mammary Tissue',
#        'Cells - Cultured fibroblasts', 'Cells - EBV-transformed lymphocytes',
#        'Cervix - Ectocervix', 'Cervix - Endocervix', 'Colon - Sigmoid',
#        'Colon - Transverse', 'Esophagus - Gastroesophageal Junction',
#        'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Fallopian Tube',
#        'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Kidney - Cortex',
#        'Liver', 'Lung', 'Minor Salivary Gland', 'Muscle - Skeletal',
#        'Nerve - Tibial', 'Ovary', 'Pancreas', 'Pituitary', 'Prostate',
#        'Skin - Not Sun Exposed (Suprapubic)', 'Skin - Sun Exposed (Lower leg)',
#        'Small Intestine - Terminal Ileum', 'Spleen', 'Stomach', 'Testis',
#        'Thyroid', 'Uterus', 'Vagina', 'Whole Blood', 'EXOTIC_down',
#        'EXOTIC_bins_down', 'EXOTIC_tissues_down', 'EXOTIC_up',
#        'EXOTIC_bins_up', 'EXOTIC_tissues_up', 'Exon_start', 'Exon_stop',
#        'alleleid', 'GENE', 'VAR_ID', 'CHROM', 'POS', 'REF', 'ALT', 'MC',
#        'Status', 'Real_Status', 'RS_STARS', 'CLNREVSTAT', 'HPO', 'rs',
#        'OMIM_VARIANT_ID', 'OMIM', 'OMIM_variant_nb'],
#       dtype='object')

# %%
import _pickle
import re
# for gene in exotic_omim_variants_exploded['OMIM'].unique()[:1]:
l = list()

def forbid(r):
    forbidden = [':', '.', 'rs', 'ss', 'dbSNP']
    check = True if set([True if e not in r else False for e in forbidden]) == {True} else False
    return check 

def retrieve_omim_variants_info(r):
#     print(r)
#     print(r['Pheno_OMIM'])
#     try:
    if r['OMIM']:
        omim_gene_json = _pickle.load(open('/gstock/biolo_datasets/variation/benchmark/Databases/OMIM/JSON_API/{}.pkl'.format(str(r['OMIM'])), 'rb'))
        if 'allelicVariantList' in  omim_gene_json['omim']['entryList'][0]['entry']:
            variant_json = omim_gene_json['omim']['entryList'][0]['entry']['allelicVariantList'][r['OMIM_variant_nb'] - 1]['allelicVariant']
#             print(variant_json)
        #     print(variant_json)
            if variant_json['text'].startswith('See {') is False:
                
                pheno_ids = [publi for publi in re.findall('\{.*?\}', variant_json['text']) if forbid(publi) is True]
    #             pheno_id = pheno_id[0]
                pheno_ids = [int(pheno.replace('{', '').replace('}', '')) for pheno in pheno_ids]
                publi_ids = [publi for publi in re.findall('\{.*?\}', variant_json['text']) if ':' in publi]
                publi_ids = [sub_publi for publi in publi_ids for sub_publi in publi.split(':')[0].replace('{', '').split(',')]
    #             print(r, pheno_ids)


    #             if pheno_id == r['Pheno_OMIM']:
                pmids = []
                try:
                    pmids = [omim_gene_json['omim']['entryList'][0]['entry']['referenceList'][int(publi.split(':')[0].replace('{', '')) - 1]['reference']['pubmedID'] for publi in publi_ids]
                    
                except:
    #                     pprint([omim_gene_json['omim']['entryList'][0]['entry']['referenceList'][int(publi.split(':')[0].replace('{', '')) - 1]['reference'] for publi in publi_ids])
                    pass
                r['PMIDS_OMIM'] = pmids
                r['PHENOS_OMIM'] = pheno_ids
    return r
                
#                     l.append(r['OMIM'])
#     except:
#         l.append(r['OMIM'])
            
                
# exotic_omim_variants_exploded.loc[exotic_omim_variants_exploded['symbol'] == 'TP63'].apply(lambda r: retrieve_omim_variants_info(r), axis=1) 
exotic_clinvar_tmp  = exotic_clinvar.dropna(subset=['OMIM', 'OMIM_variant_nb'])
exotic_clinvar_tmp['OMIM_variant_nb'] = exotic_clinvar_tmp['OMIM_variant_nb'].astype(int)
exotic_clinvar_tmp['OMIM'] = exotic_clinvar_tmp['OMIM'].astype(int)

exotic_clinvar_tmp = exotic_clinvar_tmp.apply(retrieve_omim_variants_info, axis=1)
exotic_clinvar_tmp = exotic_clinvar_tmp[list(exotic_clinvar.columns) + ['PMIDS_OMIM', 'PHENOS_OMIM']]
exotic_clinvar_tmp
# print(len(l))
# print(l)
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 19      ABCC6  ENSG00000091262     57    16244435-16244629   0.666667
# 22      ABCC6  ENSG00000091262     57    16244435-16244629   0.666667
# 40      ABCC6  ENSG00000091262     57    16248730-16248888   0.666667
# ...       ...              ...    ...                  ...        ...
# 12809  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12813  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12815  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12817  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 12818  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 19           2              3     ABCC6_16244435-16244629          0.32334
# 22           2              3     ABCC6_16244435-16244629          0.32334
# 40           2              3     ABCC6_16248730-16248888          0.32334
# ...        ...            ...                         ...              ...
# 12809        1              2  ZNF462_109686414-109689445          0.54621
# 12813        1              2  ZNF462_109686414-109689445          0.54621
# 12815        1              2  ZNF462_109686414-109689445          0.54621
# 12817        1              3    ZNF644_91403829-91406866          0.33853
# 12818        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...  Real_Status  RS_STARS  \
# 1                    0.510498  ...   Pathogenic         0
# 2                    0.495250  ...   Pathogenic         0
# 19                   0.486503  ...   Pathogenic         0
# 22                   0.486503  ...   Pathogenic         0
# 40                   0.486503  ...   Pathogenic         0
# ...                       ...  ...          ...       ...
# 12809                0.496500  ...   Pathogenic         1
# 12813                0.496500  ...   Pathogenic         0
# 12815                0.496500  ...   Pathogenic         1
# 12817                0.500250  ...   Pathogenic         0
# 12818                0.500250  ...   Pathogenic         0
#
#                                 CLNREVSTAT  \
# 1           no_assertion_criteria_provided
# 2           no_assertion_criteria_provided
# 19          no_assertion_criteria_provided
# 22          no_assertion_criteria_provided
# 40          no_assertion_criteria_provided
# ...                                    ...
# 12809  criteria_provided,_single_submitter
# 12813       no_assertion_criteria_provided
# 12815  criteria_provided,_single_submitter
# 12817       no_assertion_criteria_provided
# 12818       no_assertion_criteria_provided
#
#                                                      HPO            rs  \
# 1                                                     []  1.567027e+09
# 2                                                     []  1.567028e+09
# 19                                                    []  3.879064e+08
# 22                                                    []  3.879069e+08
# 40                                                    []  2.893970e+07
# ...                                                  ...           ...
# 12809                                                 []  1.588063e+09
# 12813                                                 []  1.588067e+09
# 12815  ['HP:0001363' 'HP:0001365' 'HP:0004494' 'HP:00...  1.060500e+09
# 12817                                                 []  3.879071e+08
# 12818                                                 []  1.469364e+08
#
#        OMIM_VARIANT_ID    OMIM  OMIM_variant_nb            PMIDS_OMIM  \
# 1          614888.0003  614888                3  [20417359, 23064416]
# 2          614888.0005  614888                5            [23064416]
# 19         603234.0008  603234                8            [10835643]
# 22         603234.0026  603234               26            [20034067]
# 40         603234.0017  603234               17            [12384774]
# ...                ...     ...              ...                   ...
# 12809      617371.0006  617371                6            [31361404]
# 12813      617371.0004  617371                4            [31361404]
# 12815      617371.0002  617371                2            [28513610]
# 12817      614159.0001  614159                1            [21695231]
# 12818      614159.0002  614159                2            [21695231]
#
#             PHENOS_OMIM
# 1              [148600]
# 2              [148600]
# 19             [177850]
# 22     [264800, 614473]
# 40             [264800]
# ...                 ...
# 12809          [618619]
# 12813          [618619]
# 12815          [618619]
# 12817          [614167]
# 12818          [614167]
#
# [2109 rows x 89 columns]

# %%
exotic_clinvar_complete = pd.concat([exotic_clinvar_tmp, exotic_clinvar.loc[exotic_clinvar['OMIM'].isna() == True]], axis=0).sort_values(by='MAP')
# test.loc[test['symbol'].isna() == True]
print(exotic_clinvar_complete.symbol.nunique())
exotic_clinvar_complete
# Out:
# 983
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 12809  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12813  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12815  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 12818  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 12817  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 12809        1              2  ZNF462_109686414-109689445          0.54621
# 12813        1              2  ZNF462_109686414-109689445          0.54621
# 12815        1              2  ZNF462_109686414-109689445          0.54621
# 12818        1              3    ZNF644_91403829-91406866          0.33853
# 12817        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...        Real_Status  RS_STARS  \
# 0                    0.578349  ...  Likely_pathogenic         1
# 1                    0.510498  ...         Pathogenic         0
# 2                    0.495250  ...         Pathogenic         0
# 4                    0.495250  ...         Pathogenic         1
# 3                    0.495250  ...         Pathogenic         1
# ...                       ...  ...                ...       ...
# 12809                0.496500  ...         Pathogenic         1
# 12813                0.496500  ...         Pathogenic         0
# 12815                0.496500  ...         Pathogenic         1
# 12818                0.500250  ...         Pathogenic         0
# 12817                0.500250  ...         Pathogenic         0
#
#                                 CLNREVSTAT  \
# 0      criteria_provided,_single_submitter
# 1           no_assertion_criteria_provided
# 2           no_assertion_criteria_provided
# 4      criteria_provided,_single_submitter
# 3      criteria_provided,_single_submitter
# ...                                    ...
# 12809  criteria_provided,_single_submitter
# 12813       no_assertion_criteria_provided
# 12815  criteria_provided,_single_submitter
# 12818       no_assertion_criteria_provided
# 12817       no_assertion_criteria_provided
#
#                                                      HPO            rs  \
# 0                                         ['HP:0000388']  1.409945e+09
# 1                                                     []  1.567027e+09
# 2                                                     []  1.567028e+09
# 4                                                     []           NaN
# 3                                                     []  1.567038e+09
# ...                                                  ...           ...
# 12809                                                 []  1.588063e+09
# 12813                                                 []  1.588067e+09
# 12815  ['HP:0001363' 'HP:0001365' 'HP:0004494' 'HP:00...  1.060500e+09
# 12818                                                 []  1.469364e+08
# 12817                                                 []  3.879071e+08
#
#        OMIM_VARIANT_ID      OMIM  OMIM_variant_nb            PMIDS_OMIM  \
# 0                  NaN       NaN              NaN                   NaN
# 1          614888.0003  614888.0              3.0  [20417359, 23064416]
# 2          614888.0005  614888.0              5.0            [23064416]
# 4                  NaN       NaN              NaN                   NaN
# 3                  NaN       NaN              NaN                   NaN
# ...                ...       ...              ...                   ...
# 12809      617371.0006  617371.0              6.0            [31361404]
# 12813      617371.0004  617371.0              4.0            [31361404]
# 12815      617371.0002  617371.0              2.0            [28513610]
# 12818      614159.0002  614159.0              2.0            [21695231]
# 12817      614159.0001  614159.0              1.0            [21695231]
#
#        PHENOS_OMIM
# 0              NaN
# 1         [148600]
# 2         [148600]
# 4              NaN
# 3              NaN
# ...            ...
# 12809     [618619]
# 12813     [618619]
# 12815     [618619]
# 12818     [614167]
# 12817     [614167]
#
# [12819 rows x 89 columns]

# %% [markdown]
# ## OMIM entries with multiple phenotypes & at least one rare

# %%
def load_omim(omim_path, biomart_omim_path):
    omim = pd.read_csv(
        omim_path,
        compression="gzip",
        sep="\t",
    )
#     return omim

    print("Total : ", omim.OMIM.nunique())
    omim = omim.dropna(subset=list(omim.columns[6:-2]), how="all")
    print("Dropna on all cols : ", omim.OMIM.nunique())

    biomart_omim = pd.read_csv(biomart_omim_path, sep="\t", compression="gzip").dropna(subset=["MIM gene accession"])
    biomart_omim["MIM gene accession"] = biomart_omim["MIM gene accession"].astype(int)
    biomart_omim = biomart_omim.rename({"MIM gene accession": "OMIM", "Gene stable ID": "ensg", "Gene name": "Name"}, axis=1)

    ## ADD Gene TO OMIM
    omim = pd.merge(biomart_omim[["ensg", "Name", "OMIM"]], omim, on="OMIM")
    print("Merge BIOMART : ", omim.OMIM.nunique())


    # MELT
    omim = omim.melt(id_vars=list(omim.columns)[:7], value_vars=list(omim.columns)[7:], var_name="OMIM_BP", value_name="OMIM_BP_phenotypes").dropna()

    return omim
omim = load_omim(files["EXOTIC"]["omim_detailed"], files["BIOMART"]["biomart_omim"])
omim
# Out:
# Total :  2655
# Dropna on all cols :  2567
# Merge BIOMART :  2567
#                    ensg      Name    OMIM  Pheno_OMIM  \
# 0       ENSG00000274891  TRAPPC12  614139      617669
# 1       ENSG00000171853  TRAPPC12  614139      617669
# 2       ENSG00000282650     MEIOB  617670      617706
# 3       ENSG00000162039     MEIOB  617670      617706
# 4       ENSG00000277603       TPO  606765      274500
# ...                 ...       ...     ...         ...
# 264340  ENSG00000164867      NOS3  163729      189800
# 264469  ENSG00000171759       PAH  612349      261600
# 264470  ENSG00000171759       PAH  612349      261600
# 264502  ENSG00000173218    VANGL1  610132      600145
# 264555  ENSG00000131779    PEX11B  603867      614920
#
#                                                Pheno_Name  \
# 0       Encephalopathy, progressive, early-onset, with...
# 1       Encephalopathy, progressive, early-onset, with...
# 2                               ?Spermatogenic failure 22
# 3                               ?Spermatogenic failure 22
# 4                            Thyroid dyshormonogenesis 2A
# ...                                                   ...
# 264340                  {Hypertension, pregnancy-induced}
# 264469              [Hyperphenylalaninemia, non-PKU mild]
# 264470                                    Phenylketonuria
# 264502                         Caudal regression syndrome
# 264555                ?Peroxisome biogenesis disorder 14B
#
#                                      Pheno_prefered_title  \
# 0       ENCEPHALOPATHY, PROGRESSIVE, EARLY-ONSET, WITH...
# 1       ENCEPHALOPATHY, PROGRESSIVE, EARLY-ONSET, WITH...
# 2                        SPERMATOGENIC FAILURE 22; SPGF22
# 3                        SPERMATOGENIC FAILURE 22; SPGF22
# 4                     THYROID DYSHORMONOGENESIS 2A; TDH2A
# ...                                                   ...
# 264340                     PREECLAMPSIA/ECLAMPSIA 1; PEE1
# 264469                               PHENYLKETONURIA; PKU
# 264470                               PHENYLKETONURIA; PKU
# 264502            SACRAL DEFECT WITH ANTERIOR MENINGOCELE
# 264555         PEROXISOME BIOGENESIS DISORDER 14B; PEX14B
#
#                                                      PMID  \
# 0                                              [28777934]
# 1                                              [28777934]
# 2                                              [28206990]
# 3                                              [28206990]
# 4       [1401057, 4189569, 1339470, 11061528, 8027236,...
# ...                                                   ...
# 264340  [6102633, 2901618, 2242360, 9311740, 10441346,...
# 264469  [8098245, 2574153, 11035829, 5461364, 5432154,...
# 264470  [8098245, 2574153, 11035829, 5461364, 5432154,...
# 264502  [5505693, 2334530, 4891160, 10631160, 13641302...
# 264555   [22581968, 3515938, 12024045, 2445576, 22581969]
#
#                                OMIM_BP  \
# 0                          inheritance
# 1                          inheritance
# 2                          inheritance
# 3                          inheritance
# 4                          inheritance
# ...                                ...
# 264340  prenatalManifestationsMaternal
# 264469  prenatalManifestationsMaternal
# 264470  prenatalManifestationsMaternal
# 264502  prenatalManifestationsMaternal
# 264555  prenatalManifestationsMaternal
#
#                                        OMIM_BP_phenotypes
# 0       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 1       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 2       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 3       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# 4       ['Autosomal recessive {SNOMEDCT:258211005} {UM...
# ...                                                   ...
# 264340  ['Maternal hypertension (after 20th week gesta...
# 264469  ['Maternal hyperphenylalaninemia teratogenic {...
# 264470  ['Maternal hyperphenylalaninemia teratogenic {...
# 264502  ['Prolonged labor {SNOMEDCT:161810005,53443007...
# 264555  ['Uncomplicated pregnancy {UMLS C4314562};\nUn...
#
# [40056 rows x 9 columns]

# %%
l = list()
for gene in tqdm(omim.Name.unique()):

    gene_omim = omim.loc[omim['Name'] == gene]
    if gene_omim.Pheno_OMIM.nunique() > 1:
#         print(gene, gene_omim.shape[0])
        gene_omim_bp = gene_omim[['Name', 'Pheno_OMIM', 'OMIM_BP']].groupby(['Name', 'Pheno_OMIM'])['OMIM_BP'].apply(set).reset_index()
        counter_pheno = collections.Counter([sub_e for e in gene_omim_bp['OMIM_BP'].values.tolist() for sub_e in e])
        counter_pheno_rare = [k for k,v in counter_pheno.items() if v == 1]
        l.append(gene_omim.loc[gene_omim['OMIM_BP'].isin(counter_pheno_rare)])
        
#         for pheno_rare in counter_pheno_rare:
#             print(gene_omim.loc[gene_omim['OMIM_BP'] == pheno_rare, ['Pheno_OMIM', 'Pheno_prefered_title', 'OMIM_BP', 'OMIM_BP_phenotypes']].values.tolist())
omim_multi_pheno_filterred = pd.concat(l)

omim_multi_pheno_filterred
# Out:
# 100%|██████████| 2570/2570 [00:07<00:00, 326.97it/s]
#                    ensg   Name    OMIM  Pheno_OMIM  \
# 66248   ENSG00000281289    LSS  600909      618840
# 66251   ENSG00000160285    LSS  600909      618840
# 78668   ENSG00000281289    LSS  600909      618840
# 78671   ENSG00000160285    LSS  600909      618840
# 82809   ENSG00000281289    LSS  600909      616509
# ...                 ...    ...     ...         ...
# 111767  ENSG00000077522  ACTN2  102573      618654
# 231827  ENSG00000077522  ACTN2  102573      618654
# 8275    ENSG00000162711  NLRP3  606416      607115
# 82795   ENSG00000162711  NLRP3  606416      607115
# 198715  ENSG00000162711  NLRP3  606416      607115
#
#                                                Pheno_Name  \
# 66248              Alopecia-mental retardation syndrome 4
# 66251              Alopecia-mental retardation syndrome 4
# 78668              Alopecia-mental retardation syndrome 4
# 78671              Alopecia-mental retardation syndrome 4
# 82809                                         Cataract 44
# ...                                                   ...
# 111767  Myopathy, congenital with structured cores and...
# 231827  Myopathy, congenital with structured cores and...
# 8275                                       CINCA syndrome
# 82795                                      CINCA syndrome
# 198715                                     CINCA syndrome
#
#                                      Pheno_prefered_title  \
# 66248       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 66251       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 78668       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 78671       ALOPECIA-MENTAL RETARDATION SYNDROME 4; APMR4
# 82809                                CATARACT 44; CTRCT44
# ...                                                   ...
# 111767  MYOPATHY, CONGENITAL, WITH STRUCTURED CORES AN...
# 231827  MYOPATHY, CONGENITAL, WITH STRUCTURED CORES AN...
# 8275                                CINCA SYNDROME; CINCA
# 82795                               CINCA SYNDROME; CINCA
# 198715                              CINCA SYNDROME; CINCA
#
#                                                      PMID  \
# 66248                                [30723320, 30401459]
# 66251                                [30723320, 30401459]
# 78668                                [30723320, 30401459]
# 78671                                [30723320, 30401459]
# 82809            [29016354, 16440058, 30401459, 26200341]
# ...                                                   ...
# 111767                                         [30701273]
# 231827                                         [30701273]
# 8275    [12483741, 16532456, 12032915, 6847730, 129288...
# 82795   [12483741, 16532456, 12032915, 6847730, 129288...
# 198715  [12483741, 16532456, 12032915, 6847730, 129288...
#
#                                   OMIM_BP  \
# 66248             laboratoryAbnormalities
# 66251             laboratoryAbnormalities
# 78668                     headAndNeckHead
# 78671                     headAndNeckHead
# 82809                     headAndNeckEyes
# ...                                   ...
# 111767                   headAndNeckMouth
# 231827  neurologicPeripheralNervousSystem
# 8275                          growthOther
# 82795                     headAndNeckHead
# 198715         skinNailsHairSkinHistology
#
#                                        OMIM_BP_phenotypes
# 66248                       ['Normal or low cholesterol']
# 66251                       ['Normal or low cholesterol']
# 78668   ['Microcephaly (in some patients) {UMLS C18491...
# 78671   ['Microcephaly (in some patients) {UMLS C18491...
# 82809   ['Cataract, congenital, severe {UMLS C4228509}...
# ...                                                   ...
# 111767  ['High-arched palate {SNOMEDCT:27272007} {ICD1...
# 231827  ['Hyporeflexia {SNOMEDCT:22994000,405946002} {...
# 8275    ['Growth retardation {SNOMEDCT:444896005,59576...
# 82795   ['Frontal bossing {SNOMEDCT:90145001} {UMLS C0...
# 198715  ['Perivascular polymorphonuclear infiltrates {...
#
# [5936 rows x 9 columns]

# %%
list_bp_phenos_diff = omim_multi_pheno_filterred.groupby('Pheno_OMIM')['OMIM_BP'].apply(set).reset_index()
list_bp_phenos_diff.columns = ['PHENOS_OMIM', 'BP_DIFF']

# %%
omim_pheno_diff = omim_multi_pheno_filterred.Pheno_OMIM.unique().tolist()

# %%
# aexotic_clinvar_complete.loc[exotic_clinvar_complete['PHENOS_OMIM'].isna() == False]
exotic_clinvar_complete = exotic_clinvar_complete.explode('PHENOS_OMIM')
exotic_clinvar_complete['PHENOS_DIFF'] = exotic_clinvar_complete['PHENOS_OMIM'].apply(lambda r: r in omim_pheno_diff)
exotic_clinvar_complete = pd.merge(exotic_clinvar_complete, list_bp_phenos_diff, on='PHENOS_OMIM', how='left')
exotic_clinvar_complete
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 13228  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13229  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13230  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13231  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 13232  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 13228        1              2  ZNF462_109686414-109689445          0.54621
# 13229        1              2  ZNF462_109686414-109689445          0.54621
# 13230        1              2  ZNF462_109686414-109689445          0.54621
# 13231        1              3    ZNF644_91403829-91406866          0.33853
# 13232        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...                           CLNREVSTAT  \
# 0                    0.578349  ...  criteria_provided,_single_submitter
# 1                    0.510498  ...       no_assertion_criteria_provided
# 2                    0.495250  ...       no_assertion_criteria_provided
# 3                    0.495250  ...  criteria_provided,_single_submitter
# 4                    0.495250  ...  criteria_provided,_single_submitter
# ...                       ...  ...                                  ...
# 13228                0.496500  ...  criteria_provided,_single_submitter
# 13229                0.496500  ...       no_assertion_criteria_provided
# 13230                0.496500  ...  criteria_provided,_single_submitter
# 13231                0.500250  ...       no_assertion_criteria_provided
# 13232                0.500250  ...       no_assertion_criteria_provided
#
#                                                      HPO            rs  \
# 0                                         ['HP:0000388']  1.409945e+09
# 1                                                     []  1.567027e+09
# 2                                                     []  1.567028e+09
# 3                                                     []           NaN
# 4                                                     []  1.567038e+09
# ...                                                  ...           ...
# 13228                                                 []  1.588063e+09
# 13229                                                 []  1.588067e+09
# 13230  ['HP:0001363' 'HP:0001365' 'HP:0004494' 'HP:00...  1.060500e+09
# 13231                                                 []  1.469364e+08
# 13232                                                 []  3.879071e+08
#
#        OMIM_VARIANT_ID      OMIM  OMIM_variant_nb            PMIDS_OMIM  \
# 0                  NaN       NaN              NaN                   NaN
# 1          614888.0003  614888.0              3.0  [20417359, 23064416]
# 2          614888.0005  614888.0              5.0            [23064416]
# 3                  NaN       NaN              NaN                   NaN
# 4                  NaN       NaN              NaN                   NaN
# ...                ...       ...              ...                   ...
# 13228      617371.0006  617371.0              6.0            [31361404]
# 13229      617371.0004  617371.0              4.0            [31361404]
# 13230      617371.0002  617371.0              2.0            [28513610]
# 13231      614159.0002  614159.0              2.0            [21695231]
# 13232      614159.0001  614159.0              1.0            [21695231]
#
#        PHENOS_OMIM  PHENOS_DIFF  BP_DIFF
# 0              NaN        False      NaN
# 1           148600        False      NaN
# 2           148600        False      NaN
# 3              NaN        False      NaN
# 4              NaN        False      NaN
# ...            ...          ...      ...
# 13228       618619        False      NaN
# 13229       618619        False      NaN
# 13230       618619        False      NaN
# 13231       614167        False      NaN
# 13232       614167        False      NaN
#
# [13233 rows x 91 columns]

# %%
dicts = json.load(open("/home/weber/PycharmProjects/EXOTIC/src/EXOTIC_config.json"))
mapping_omim_gtex = dicts["mapping_omim_gtex_neurologic"]

# %%
tissues = ['Adipose - Subcutaneous', 'Adipose - Visceral (Omentum)', 'Adrenal Gland', 'Artery - Aorta', 'Artery - Coronary', 'Artery - Tibial', 'Bladder', 'Brain - Amygdala', 'Brain - Anterior cingulate cortex (BA24)', 'Brain - Caudate (basal ganglia)', 'Brain - Cerebellar Hemisphere', 'Brain - Cerebellum', 'Brain - Cortex', 'Brain - Frontal Cortex (BA9)', 'Brain - Hippocampus', 'Brain - Hypothalamus', 'Brain - Nucleus accumbens (basal ganglia)', 'Brain - Putamen (basal ganglia)', 'Brain - Spinal cord (cervical c-1)', 'Brain - Substantia nigra', 'Breast - Mammary Tissue', 'Cells - Cultured fibroblasts', 'Cells - EBV-transformed lymphocytes', 'Cervix - Ectocervix', 'Cervix - Endocervix', 'Colon - Sigmoid', 'Colon - Transverse', 'Esophagus - Gastroesophageal Junction', 'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Fallopian Tube', 'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Kidney - Cortex', 'Liver', 'Lung', 'Minor Salivary Gland', 'Muscle - Skeletal', 'Nerve - Tibial', 'Ovary', 'Pancreas', 'Pituitary', 'Prostate', 'Skin - Not Sun Exposed (Suprapubic)', 'Skin - Sun Exposed (Lower leg)', 'Small Intestine - Terminal Ileum', 'Spleen', 'Stomach', 'Testis', 'Thyroid', 'Uterus', 'Vagina', 'Whole Blood']
exotic_clinvar_complete['Up_above_cutoff'] = exotic_clinvar_complete[tissues].apply(lambda r: [tissues[j] for j, e in enumerate(r) if e > 0.6], axis=1)
exotic_clinvar_complete['Up_tissues_EXOTIC_values'] = exotic_clinvar_complete.apply(lambda r: [round(r[e], 3) for e in r['Up_above_cutoff']], axis=1)
exotic_clinvar_complete['BP_Up'] = exotic_clinvar_complete['Up_above_cutoff'].apply(lambda r : [bp for e in r if e in mapping_omim_gtex for bp in mapping_omim_gtex[e] ])
exotic_clinvar_complete['Down_above_cutoff'] = exotic_clinvar_complete[tissues].apply(lambda r: [tissues[j] for j, e in enumerate(r) if e < 0.4], axis=1)
exotic_clinvar_complete['Down_tissues_EXOTIC_values'] = exotic_clinvar_complete.apply(lambda r: [round(float(1 - r[e]), 3) for e in r['Down_above_cutoff']], axis=1)

exotic_clinvar_complete['BP_Down'] = exotic_clinvar_complete['Down_above_cutoff'].apply(lambda r : [bp for e in r if e in mapping_omim_gtex for bp in mapping_omim_gtex[e] ])
exotic_clinvar_complete.loc[(exotic_clinvar_complete['BP_Up'].isna() == False) & (exotic_clinvar_complete['BP_DIFF'].isna() == False), 'Check_BP_up'] = exotic_clinvar_complete.loc[(exotic_clinvar_complete['BP_Up'].isna() == False) & (exotic_clinvar_complete['BP_DIFF'].isna() == False)].apply(lambda r: [e  for e in r['BP_Up'] if e  and e in  r['BP_DIFF']], axis=1)
exotic_clinvar_complete.loc[(exotic_clinvar_complete['BP_Down'].isna() == False) & (exotic_clinvar_complete['BP_DIFF'].isna() == False), 'Check_BP_down'] = exotic_clinvar_complete.loc[(exotic_clinvar_complete['BP_Down'].isna() == False) & (exotic_clinvar_complete['BP_DIFF'].isna() == False)].apply(lambda r: [e  for e in r['BP_Down'] if e  and e in  r['BP_DIFF']], axis=1)

exotic_clinvar_complete
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 13228  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13229  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13230  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13231  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 13232  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 13228        1              2  ZNF462_109686414-109689445          0.54621
# 13229        1              2  ZNF462_109686414-109689445          0.54621
# 13230        1              2  ZNF462_109686414-109689445          0.54621
# 13231        1              3    ZNF644_91403829-91406866          0.33853
# 13232        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...  PHENOS_DIFF  BP_DIFF  \
# 0                    0.578349  ...        False      NaN
# 1                    0.510498  ...        False      NaN
# 2                    0.495250  ...        False      NaN
# 3                    0.495250  ...        False      NaN
# 4                    0.495250  ...        False      NaN
# ...                       ...  ...          ...      ...
# 13228                0.496500  ...        False      NaN
# 13229                0.496500  ...        False      NaN
# 13230                0.496500  ...        False      NaN
# 13231                0.500250  ...        False      NaN
# 13232                0.500250  ...        False      NaN
#
#                                          Up_above_cutoff  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13229  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13230  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13231  [Cells - Cultured fibroblasts, Muscle - Skeletal]
# 13232  [Cells - Cultured fibroblasts, Muscle - Skeletal]
#
#                                        Down_above_cutoff  \
# 0      [Brain - Anterior cingulate cortex (BA24), Bra...
# 1                                        [Liver, Spleen]
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228                                           [Testis]
# 13229                                           [Testis]
# 13230                                           [Testis]
# 13231                                      [Whole Blood]
# 13232                                      [Whole Blood]
#
#                                                    BP_Up  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228  [headAndNeckHead, neurologicCentralNervousSyst...
# 13229  [headAndNeckHead, neurologicCentralNervousSyst...
# 13230  [headAndNeckHead, neurologicCentralNervousSyst...
# 13231                                 [muscleSoftTissue]
# 13232                                 [muscleSoftTissue]
#
#                                                  BP_Down  Check_BP_up  \
# 0      [headAndNeckHead, neurologicCentralNervousSyst...          NaN
# 1                          [abdomenLiver, abdomenSpleen]          NaN
# 2                                                     []          NaN
# 3                                                     []          NaN
# 4                                                     []          NaN
# ...                                                  ...          ...
# 13228               [genitourinaryExternalGenitaliaMale]          NaN
# 13229               [genitourinaryExternalGenitaliaMale]          NaN
# 13230               [genitourinaryExternalGenitaliaMale]          NaN
# 13231                                       [hematology]          NaN
# 13232                                       [hematology]          NaN
#
#        Check_BP_down      Up_tissues_EXOTIC_values  \
# 0                NaN                            []
# 1                NaN                            []
# 2                NaN                            []
# 3                NaN                            []
# 4                NaN                            []
# ...              ...                           ...
# 13228            NaN  [0.602, 0.603, 0.607, 0.843]
# 13229            NaN  [0.602, 0.603, 0.607, 0.843]
# 13230            NaN  [0.602, 0.603, 0.607, 0.843]
# 13231            NaN                 [0.63, 0.655]
# 13232            NaN                 [0.63, 0.655]
#
#                               Down_tissues_EXOTIC_values
# 0      [0.604, 0.604, 0.713, 0.675, 0.606, 0.601, 0.6...
# 1                                         [0.733, 0.622]
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228                                             [0.68]
# 13229                                             [0.68]
# 13230                                             [0.68]
# 13231                                            [0.661]
# 13232                                            [0.661]
#
# [13233 rows x 99 columns]

# %%
exotic_clinvar_complete.to_csv('/gstock/EXOTIC/data/VARIATIONS/EXOTIC_clinvar_OMIM.csv.gz', compression='gzip', sep='\t', index=False)
exotic_clinvar_complete.to_excel('/gstock/EXOTIC/data/VARIATIONS/EXOTIC_clinvar_OMIM.xlsx', index=False)
exotic_clinvar_complete
# Out:
#        symbol             ensg   HGNC                 Exon  Ratio_num  \
# 0       A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000
# 1       AAGAB  ENSG00000103591  25662    67528746-67528779   0.666667
# 2       AAGAB  ENSG00000103591  25662    67528968-67529158   0.333333
# 3       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# 4       AAGAB  ENSG00000103591  25662    67546897-67546969   0.333333
# ...       ...              ...    ...                  ...        ...
# 13228  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13229  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13230  ZNF462  ENSG00000148143  21684  109686414-109689445   0.500000
# 13231  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
# 13232  ZNF644  ENSG00000122482  29222    91403829-91406866   0.333333
#
#        mRNA_nb  mRNA_nb_total                         MAP  mean_proportion  \
# 0            1              2       A2ML1_8975248-8975309          0.69514
# 1            2              3     AAGAB_67528746-67528779          0.84897
# 2            1              3     AAGAB_67528968-67529158          0.54491
# 3            1              3     AAGAB_67546897-67546969          0.54491
# 4            1              3     AAGAB_67546897-67546969          0.54491
# ...        ...            ...                         ...              ...
# 13228        1              2  ZNF462_109686414-109689445          0.54621
# 13229        1              2  ZNF462_109686414-109689445          0.54621
# 13230        1              2  ZNF462_109686414-109689445          0.54621
# 13231        1              3    ZNF644_91403829-91406866          0.33853
# 13232        1              3    ZNF644_91403829-91406866          0.33853
#
#        Adipose - Subcutaneous  ...  PHENOS_DIFF  BP_DIFF  \
# 0                    0.578349  ...        False      NaN
# 1                    0.510498  ...        False      NaN
# 2                    0.495250  ...        False      NaN
# 3                    0.495250  ...        False      NaN
# 4                    0.495250  ...        False      NaN
# ...                       ...  ...          ...      ...
# 13228                0.496500  ...        False      NaN
# 13229                0.496500  ...        False      NaN
# 13230                0.496500  ...        False      NaN
# 13231                0.500250  ...        False      NaN
# 13232                0.500250  ...        False      NaN
#
#                                          Up_above_cutoff  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13229  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13230  [Brain - Frontal Cortex (BA9), Brain - Nucleus...
# 13231  [Cells - Cultured fibroblasts, Muscle - Skeletal]
# 13232  [Cells - Cultured fibroblasts, Muscle - Skeletal]
#
#                                        Down_above_cutoff  \
# 0      [Brain - Anterior cingulate cortex (BA24), Bra...
# 1                                        [Liver, Spleen]
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228                                           [Testis]
# 13229                                           [Testis]
# 13230                                           [Testis]
# 13231                                      [Whole Blood]
# 13232                                      [Whole Blood]
#
#                                                    BP_Up  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228  [headAndNeckHead, neurologicCentralNervousSyst...
# 13229  [headAndNeckHead, neurologicCentralNervousSyst...
# 13230  [headAndNeckHead, neurologicCentralNervousSyst...
# 13231                                 [muscleSoftTissue]
# 13232                                 [muscleSoftTissue]
#
#                                                  BP_Down  Check_BP_up  \
# 0      [headAndNeckHead, neurologicCentralNervousSyst...          NaN
# 1                          [abdomenLiver, abdomenSpleen]          NaN
# 2                                                     []          NaN
# 3                                                     []          NaN
# 4                                                     []          NaN
# ...                                                  ...          ...
# 13228               [genitourinaryExternalGenitaliaMale]          NaN
# 13229               [genitourinaryExternalGenitaliaMale]          NaN
# 13230               [genitourinaryExternalGenitaliaMale]          NaN
# 13231                                       [hematology]          NaN
# 13232                                       [hematology]          NaN
#
#        Check_BP_down      Up_tissues_EXOTIC_values  \
# 0                NaN                            []
# 1                NaN                            []
# 2                NaN                            []
# 3                NaN                            []
# 4                NaN                            []
# ...              ...                           ...
# 13228            NaN  [0.602, 0.603, 0.607, 0.843]
# 13229            NaN  [0.602, 0.603, 0.607, 0.843]
# 13230            NaN  [0.602, 0.603, 0.607, 0.843]
# 13231            NaN                 [0.63, 0.655]
# 13232            NaN                 [0.63, 0.655]
#
#                               Down_tissues_EXOTIC_values
# 0      [0.604, 0.604, 0.713, 0.675, 0.606, 0.601, 0.6...
# 1                                         [0.733, 0.622]
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 13228                                             [0.68]
# 13229                                             [0.68]
# 13230                                             [0.68]
# 13231                                            [0.661]
# 13232                                            [0.661]
#
# [13233 rows x 99 columns]

# %%
exotic_clinvar_complete.columns
# Out:
# Index(['symbol', 'ensg', 'HGNC', 'Exon', 'Ratio_num', 'mRNA_nb',
#        'mRNA_nb_total', 'MAP', 'mean_proportion', 'Adipose - Subcutaneous',
#        'Adipose - Visceral (Omentum)', 'Adrenal Gland', 'Artery - Aorta',
#        'Artery - Coronary', 'Artery - Tibial', 'Bladder', 'Brain - Amygdala',
#        'Brain - Anterior cingulate cortex (BA24)',
#        'Brain - Caudate (basal ganglia)', 'Brain - Cerebellar Hemisphere',
#        'Brain - Cerebellum', 'Brain - Cortex', 'Brain - Frontal Cortex (BA9)',
#        'Brain - Hippocampus', 'Brain - Hypothalamus',
#        'Brain - Nucleus accumbens (basal ganglia)',
#        'Brain - Putamen (basal ganglia)', 'Brain - Spinal cord (cervical c-1)',
#        'Brain - Substantia nigra', 'Breast - Mammary Tissue',
#        'Cells - Cultured fibroblasts', 'Cells - EBV-transformed lymphocytes',
#        'Cervix - Ectocervix', 'Cervix - Endocervix', 'Colon - Sigmoid',
#        'Colon - Transverse', 'Esophagus - Gastroesophageal Junction',
#        'Esophagus - Mucosa', 'Esophagus - Muscularis', 'Fallopian Tube',
#        'Heart - Atrial Appendage', 'Heart - Left Ventricle', 'Kidney - Cortex',
#        'Liver', 'Lung', 'Minor Salivary Gland', 'Muscle - Skeletal',
#        'Nerve - Tibial', 'Ovary', 'Pancreas', 'Pituitary', 'Prostate',
#        'Skin - Not Sun Exposed (Suprapubic)', 'Skin - Sun Exposed (Lower leg)',
#        'Small Intestine - Terminal Ileum', 'Spleen', 'Stomach', 'Testis',
#        'Thyroid', 'Uterus', 'Vagina', 'Whole Blood', 'EXOTIC_down',
#        'EXOTIC_bins_down', 'EXOTIC_tissues_down', 'EXOTIC_up',
#        'EXOTIC_bins_up', 'EXOTIC_tissues_up', 'Exon_start', 'Exon_stop',
#        'alleleid', 'GENE', 'VAR_ID', 'CHROM', 'POS', 'REF', 'ALT', 'MC',
#        'Status', 'Real_Status', 'RS_STARS', 'CLNREVSTAT', 'HPO', 'rs',
#        'OMIM_VARIANT_ID', 'OMIM', 'OMIM_variant_nb', 'PMIDS_OMIM',
#        'PHENOS_OMIM', 'PHENOS_DIFF', 'BP_DIFF', 'Up_above_cutoff',
#        'Down_above_cutoff', 'BP_Up', 'BP_Down', 'Check_BP_up', 'Check_BP_down',
#        'Up_tissues_EXOTIC_values', 'Down_tissues_EXOTIC_values'],
#       dtype='object')

# %% [markdown]
# ## Stats

# %%
list_cols = ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM']
for j, col in enumerate(list_cols):
    included_cols = list_cols[:j+1]
    tmp_exotic = exotic_clinvar_complete[['symbol'] + included_cols]
    if 'PHENOS_DIFF' in included_cols:
        tmp_exotic = tmp_exotic.loc[tmp_exotic['PHENOS_DIFF'] == True]
    print(j, col, included_cols, tmp_exotic.dropna()['symbol'].nunique())
# Out:
# 0 OMIM_VARIANT_ID ['OMIM_VARIANT_ID'] 675
# 1 PHENOS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM'] 659
# 2 PHENOS_DIFF ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF'] 196
# 3 PMIDS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM'] 196

# %%
list_cols = ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Up_above_cutoff', 'BP_Up', 'Up_tissues_EXOTIC_values', 'Check_BP_up', ]
for j, col in enumerate(list_cols):
    included_cols = list_cols[:j+1]
    tmp_exotic = exotic_clinvar_complete[['symbol'] + included_cols].dropna()
    if 'PHENOS_DIFF' in included_cols:
        tmp_exotic = tmp_exotic.loc[tmp_exotic['PHENOS_DIFF'] == True]
    if 'up' in col.lower():
        tmp_exotic = tmp_exotic.loc[tmp_exotic[col].str.len() > 0]

    print(j, col, included_cols, tmp_exotic['symbol'].nunique())
    
tmp_exotic
# Out:
# 0 OMIM_VARIANT_ID ['OMIM_VARIANT_ID'] 675
# 1 PHENOS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM'] 659
# 2 PHENOS_DIFF ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF'] 196
# 3 PMIDS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM'] 196
# 4 Up_above_cutoff ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Up_above_cutoff'] 74
# 5 BP_Up ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Up_above_cutoff', 'BP_Up'] 63
# 6 Up_tissues_EXOTIC_values ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Up_above_cutoff', 'BP_Up', 'Up_tissues_EXOTIC_values'] 74
# 7 Check_BP_up ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Up_above_cutoff', 'BP_Up', 'Up_tissues_EXOTIC_values', 'Check_BP_up'] 13
#           symbol  OMIM_VARIANT_ID PHENOS_OMIM  PHENOS_DIFF  \
# 364        ACOX1      609751.0006      264470         True
# 1464     CACNA1D      114206.0002      615474         True
# 2749       DGUOK      601465.0014      617070         True
# 2759       DGUOK      601465.0004      251880         True
# 2762       DGUOK      601465.0006      251880         True
# 2763       DGUOK      601465.0011      251880         True
# 2996       DNM1L      603850.0004      614388         True
# 2997       DNM1L      603850.0005      614388         True
# 2998       DNM1L      603850.0005      614388         True
# 3376       ERBB3      190151.0002      133180         True
# 4047       FGFR2      176943.0039      101200         True
# 4096       FGFR2      176943.0011      101200         True
# 4099       FGFR2      176943.0017      101200         True
# 4101       FGFR2      176943.0010      101200         True
# 4552       GNAO1      139311.0007      617493         True
# 4553       GNAO1      139311.0009      617493         True
# 5664       KIF1B      605995.0005      256700         True
# 7528       NAA10      300013.0005      300855         True
# 9042      NUP214      114350.0002      618426         True
# 9516       POLD1      174761.0003      615381         True
# 11437  TNFRSF11A      603499.0006      612301         True
# 11582       TPM2      190990.0008      609285         True
#
#                                               PMIDS_OMIM  \
# 364                                           [17458872]
# 1464                                          [23913001]
# 2749                                          [23043144]
# 2759                                          [12205643]
# 2762                                          [12205643]
# 2763                                          [23043144]
# 2996                                          [26825290]
# 2997                                [26825290, 27328748]
# 2998                                [26825290, 27328748]
# 3376                                          [27416908]
# 4047                        [9586546, 7719333, 15282208]
# 4096     [7719344, 8651276, 8651276, 11390973, 16969861]
# 4099                                 [9002682, 10067911]
# 4101   [7719344, 8651276, 8651276, 9719378, 16440883,...
# 4552                                [25966631, 27068059]
# 4553                                          [28357411]
# 5664            [18334619, 18726616, 18334619, 18726616]
# 7528                                          [26522270]
# 9042                                          [31178128]
# 9516                                          [23770608]
# 11437                                         [18606301]
# 11582                                         [19047562]
#
#                                          Up_above_cutoff  \
# 364                                 [Brain - Cerebellum]
# 1464   [Adipose - Visceral (Omentum), Artery - Aorta,...
# 2749                         [Muscle - Skeletal, Testis]
# 2759              [Brain - Frontal Cortex (BA9), Testis]
# 2762              [Brain - Frontal Cortex (BA9), Testis]
# 2763              [Brain - Frontal Cortex (BA9), Testis]
# 2996   [Brain - Amygdala, Brain - Anterior cingulate ...
# 2997                                 [Muscle - Skeletal]
# 2998                                 [Muscle - Skeletal]
# 3376   [Cells - EBV-transformed lymphocytes, Spleen, ...
# 4047   [Adrenal Gland, Artery - Aorta, Artery - Tibia...
# 4096   [Adrenal Gland, Artery - Aorta, Artery - Tibia...
# 4099   [Adrenal Gland, Artery - Aorta, Artery - Tibia...
# 4101   [Adrenal Gland, Artery - Aorta, Artery - Tibia...
# 4552   [Brain - Anterior cingulate cortex (BA24), Bra...
# 4553   [Brain - Anterior cingulate cortex (BA24), Bra...
# 5664   [Brain - Cerebellar Hemisphere, Brain - Fronta...
# 7528   [Cells - Cultured fibroblasts, Cells - EBV-tra...
# 9042   [Brain - Cerebellar Hemisphere, Cells - Cultur...
# 9516                                 [Muscle - Skeletal]
# 11437  [Brain - Cortex, Brain - Frontal Cortex (BA9),...
# 11582  [Heart - Atrial Appendage, Heart - Left Ventri...
#
#                                                    BP_Up  \
# 364    [headAndNeckHead, neurologicCentralNervousSystem]
# 1464   [growthWeight, cardiovascularVascular, cardiov...
# 2749   [muscleSoftTissue, genitourinaryExternalGenita...
# 2759   [headAndNeckHead, neurologicCentralNervousSyst...
# 2762   [headAndNeckHead, neurologicCentralNervousSyst...
# 2763   [headAndNeckHead, neurologicCentralNervousSyst...
# 2996   [headAndNeckHead, neurologicCentralNervousSyst...
# 2997                                  [muscleSoftTissue]
# 2998                                  [muscleSoftTissue]
# 3376             [immunology, abdomenSpleen, hematology]
# 4047   [endocrineFeatures, cardiovascularVascular, ab...
# 4096   [endocrineFeatures, cardiovascularVascular, ab...
# 4099   [endocrineFeatures, cardiovascularVascular, ab...
# 4101   [endocrineFeatures, cardiovascularVascular, ab...
# 4552   [headAndNeckHead, neurologicCentralNervousSyst...
# 4553   [headAndNeckHead, neurologicCentralNervousSyst...
# 5664   [headAndNeckHead, neurologicCentralNervousSyst...
# 7528                                        [immunology]
# 9042   [headAndNeckHead, neurologicCentralNervousSyst...
# 9516                                  [muscleSoftTissue]
# 11437  [headAndNeckHead, neurologicCentralNervousSyst...
# 11582  [cardiovascularHeart, cardiovascularHeart, mus...
#
#                                 Up_tissues_EXOTIC_values  \
# 364                                              [0.601]
# 1464   [0.668, 0.668, 0.668, 0.668, 0.668, 0.668, 0.668]
# 2749                                      [0.664, 0.718]
# 2759                                      [0.602, 0.625]
# 2762                                      [0.602, 0.625]
# 2763                                      [0.602, 0.625]
# 2996           [0.608, 0.669, 0.668, 0.69, 0.779, 0.669]
# 2997                                             [0.624]
# 2998                                             [0.624]
# 3376                               [0.632, 0.632, 0.632]
# 4047                         [0.612, 0.626, 0.67, 0.615]
# 4096                        [0.609, 0.613, 0.662, 0.607]
# 4099                        [0.609, 0.613, 0.662, 0.607]
# 4101                        [0.609, 0.613, 0.662, 0.607]
# 4552   [0.665, 0.621, 0.763, 0.722, 0.651, 0.708, 0.6...
# 4553   [0.665, 0.621, 0.763, 0.722, 0.651, 0.708, 0.6...
# 5664                                        [0.609, 0.6]
# 7528                                       [0.611, 0.64]
# 9042                               [0.622, 0.751, 0.647]
# 9516                                             [0.624]
# 11437                              [0.604, 0.605, 0.697]
# 11582                              [0.628, 0.708, 0.814]
#
#                                              Check_BP_up
# 364                                    [headAndNeckHead]
# 1464    [cardiovascularVascular, cardiovascularVascular]
# 2749                                  [muscleSoftTissue]
# 2759                                   [headAndNeckHead]
# 2762                                   [headAndNeckHead]
# 2763                                   [headAndNeckHead]
# 2996   [headAndNeckHead, neurologicCentralNervousSyst...
# 2997                                  [muscleSoftTissue]
# 2998                                  [muscleSoftTissue]
# 3376                         [abdomenSpleen, hematology]
# 4047                           [abdomenGastrointestinal]
# 4096                           [abdomenGastrointestinal]
# 4099                           [abdomenGastrointestinal]
# 4101                           [abdomenGastrointestinal]
# 4552   [headAndNeckHead, headAndNeckHead, headAndNeck...
# 4553   [headAndNeckHead, headAndNeckHead, headAndNeck...
# 5664   [neurologicCentralNervousSystem, neurologicCen...
# 7528                                        [immunology]
# 9042   [headAndNeckHead, neurologicCentralNervousSystem]
# 9516                                  [muscleSoftTissue]
# 11437  [neurologicCentralNervousSystem, neurologicCen...
# 11582         [cardiovascularHeart, cardiovascularHeart]

# %%
list_cols = ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Down_above_cutoff', 'BP_Down', 'Down_tissues_EXOTIC_values', 'Check_BP_down', ]
for j, col in enumerate(list_cols):
    included_cols = list_cols[:j+1]
    tmp_exotic = exotic_clinvar_complete[['symbol'] + included_cols].dropna()
    if 'PHENOS_DIFF' in included_cols:
        tmp_exotic = tmp_exotic.loc[tmp_exotic['PHENOS_DIFF'] == True]
    if 'down' in col.lower():
        tmp_exotic = tmp_exotic.loc[tmp_exotic[col].str.len() > 0]

    print(j, col, included_cols, tmp_exotic['symbol'].nunique())
pd.options.display.max_rows = 70
tmp_exotic
# Out:
# 0 OMIM_VARIANT_ID ['OMIM_VARIANT_ID'] 675
# 1 PHENOS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM'] 659
# 2 PHENOS_DIFF ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF'] 196
# 3 PMIDS_OMIM ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM'] 196
# 4 Down_above_cutoff ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Down_above_cutoff'] 107
# 5 BP_Down ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Down_above_cutoff', 'BP_Down'] 105
# 6 Down_tissues_EXOTIC_values ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Down_above_cutoff', 'BP_Down', 'Down_tissues_EXOTIC_values'] 107
# 7 Check_BP_down ['OMIM_VARIANT_ID', 'PHENOS_OMIM', 'PHENOS_DIFF', 'PMIDS_OMIM', 'Down_above_cutoff', 'BP_Down', 'Down_tissues_EXOTIC_values', 'Check_BP_down'] 24
#        symbol  OMIM_VARIANT_ID PHENOS_OMIM  PHENOS_DIFF  \
# 3092     DOK7      610285.0003      254300         True
# 3093     DOK7      610285.0006      254300         True
# 3094     DOK7      610285.0007      254300         True
# 4418    GATA2      137295.0012      614038         True
# 4420    GATA2      137295.0013      614038         True
# 4435    GATA4      600576.0018      615542         True
# 4588     GNAS      139320.0013      174800         True
# 4590     GNAS      139320.0008      174800         True
# 4591     GNAS      139320.0008      174800         True
# 4595     GNAS      139320.0009      174800         True
# 4599     GNAS      139320.0021      174800         True
# 4636      GNE      603824.0017      605820         True
# 4637      GNE      603824.0010      605820         True
# 5105    IFT43      614068.0003      617866         True
# 5202     IRF6      607199.0014      119500         True
# 5693    KLHL7      611119.0011      617055         True
# 5694    KLHL7      611119.0005      617055         True
# 5695    KLHL7      611119.0009      617055         True
# 5696    KLHL7      611119.0007      617055         True
# 5700    KLHL7      611119.0004      617055         True
# 5702    KLHL7      611119.0006      617055         True
# 6382     LRP5      603506.0036      617875         True
# 6772     MLH1      120436.0010      276300         True
# 7493      MVK      251170.0012      610377         True
# 7520     MYRF      608329.0003      618280         True
# 7528    NAA10      300013.0005      300855         True
# 7884      NF1      613113.0015      151100         True
# 8018      NF1      613113.0037      256700         True
# 8170      NF1      613113.0019      607785         True
# 8900    NLRC4      606831.0001      616050         True
# 8908    NLRC4      606831.0002      616050         True
# 9703      PRX      605725.0008      614895         True
# 9712      PRX      605725.0005      614895         True
# 9714      PRX      605725.0006      614895         True
# 9786     PTEN      601728.0022      158350         True
# 9823     PTEN      601728.0011      158350         True
# 9847     PTEN      601728.0012      158350         True
# 9849     PTEN      601728.0036      158350         True
# 9906     PTEN      601728.0007      158350         True
# 9910     PTEN      601728.0020      158350         True
# 9911     PTEN      601728.0028      158350         True
# 9912     PTEN      601728.0005      158350         True
# 9913     PTEN      601728.0006      158350         True
# 9914     PTEN      601728.0001      158350         True
# 9917     PTEN      601728.0017      158350         True
# 9919     PTEN      601728.0041      158350         True
# 9921     PTEN      601728.0003      158350         True
# 10227   RAD51      179617.0004      614508         True
# 10228   RAD51      179617.0005      617244         True
# 10262   REEP1      609139.0001      610250         True
# 10533   SCN1B      600235.0011      617350         True
# 10534   SCN1B      600235.0009      617350         True
# 10538   SCN1B      600235.0008      617350         True
# 11302  TGFBR1      190181.0008      609192         True
# 11548    TP63      603273.0018      106260         True
# 11550    TP63      603273.0009      106260         True
# 11552    TP63      603273.0010      106260         True
# 11720    TTC8      608132.0001      615985         True
# 13072    WWOX      605131.0009      616211         True
# 13074    WWOX      605131.0010      616211         True
# 13079    WWOX      605131.0004      616211         True
# 13094    WWOX      605131.0008      616211         True
#
#                                               PMIDS_OMIM  \
# 3092                                          [16917026]
# 3093                                          [16917026]
# 3094                                          [16917026]
# 4418                                [21892158, 20803646]
# 4420                                          [21892158]
# 4435                                          [21220346]
# 4588                        [8766942, 9267696, 12727968]
# 4590   [1944469, 1944469, 7739708, 2549426, 8766942, ...
# 4591   [1944469, 1944469, 7739708, 2549426, 8766942, ...
# 4595   [1944469, 1944469, 1594625, 3720010, 12970318,...
# 4599                                 [10571700, 7751320]
# 4636                                          [12473769]
# 4637                                          [11528398]
# 5105                                          [28400947]
# 5202                                [14757865, 14757865]
# 5693                                          [30300710]
# 5694                                          [27392078]
# 5695                                          [29074562]
# 5696                                          [27392078]
# 5700                                          [27392078]
# 5702                                          [27392078]
# 6382                                          [24706814]
# 6772                                 [9927033, 11343035]
# 7493                                [16835861, 22983302]
# 7520                                          [29446546]
# 7528                                          [26522270]
# 7884                                           [8807336]
# 8018                      [12438263, 15338462, 12438263]
# 8170                                           [9639526]
# 8900                                          [25217960]
# 8908                                          [25217959]
# 9703   [15197604, 16770524, 15197604, 22847150, 22847...
# 9712                                [10848494, 11157804]
# 9714                                          [12112076]
# 9786                                          [10777358]
# 9823               [9425889, 9662392, 8673088, 11875759]
# 9847                                           [9832031]
# 9849                                [12833416, 12833416]
# 9906     [9259288, 9856571, 9856571, 17286265, 17286265]
# 9910                                          [10051160]
# 9911                                          [11238682]
# 9912                                           [9259288]
# 9913                                           [9259288]
# 9914                        [9140396, 9140396, 10051603]
# 9917                                 [9915974, 11875759]
# 9919                                [16752378, 12471211]
# 9921                                           [9140396]
# 10227                               [21242494, 22305526]
# 10228                                         [26681308]
# 10262                                         [16826527]
# 10533                                         [28218389]
# 10534                               [23148524, 23148524]
# 10538                                         [19710327]
# 11302                                         [18070134]
# 11548                     [10886756, 15200513, 15200513]
# 11550                      [11159940, 9774969, 19353588]
# 11552                                [11159940, 9774969]
# 11720                                         [14520415]
# 13072                               [25411445, 25411445]
# 13074                                         [25411445]
# 13079                                         [24456803]
# 13094                                         [25411445]
#
#                                        Down_above_cutoff  \
# 3092   [Adipose - Subcutaneous, Adipose - Visceral (O...
# 3093   [Adipose - Subcutaneous, Adipose - Visceral (O...
# 3094   [Adipose - Subcutaneous, Adipose - Visceral (O...
# 4418                                            [Testis]
# 4420                                            [Testis]
# 4435                                            [Testis]
# 4588           [Brain - Hypothalamus, Pituitary, Testis]
# 4590           [Brain - Hypothalamus, Pituitary, Testis]
# 4591           [Brain - Hypothalamus, Pituitary, Testis]
# 4595           [Brain - Hypothalamus, Pituitary, Testis]
# 4599           [Brain - Hypothalamus, Pituitary, Testis]
# 4636                                 [Muscle - Skeletal]
# 4637                                 [Muscle - Skeletal]
# 5105                                [Brain - Cerebellum]
# 5202   [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 5693   [Cells - EBV-transformed lymphocytes, Testis, ...
# 5694   [Cells - EBV-transformed lymphocytes, Testis, ...
# 5695   [Cells - EBV-transformed lymphocytes, Testis, ...
# 5696   [Cells - EBV-transformed lymphocytes, Testis, ...
# 5700   [Cells - EBV-transformed lymphocytes, Testis, ...
# 5702   [Cells - EBV-transformed lymphocytes, Testis, ...
# 6382                                             [Liver]
# 6772                                [Brain - Cerebellum]
# 7493                                [Brain - Cerebellum]
# 7520                   [Artery - Aorta, Artery - Tibial]
# 7528                                [Brain - Cerebellum]
# 7884                               [Testis, Whole Blood]
# 8018                               [Testis, Whole Blood]
# 8170                               [Testis, Whole Blood]
# 8900                                            [Spleen]
# 8908                                            [Spleen]
# 9703   [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 9712   [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 9714   [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 9786       [Cells - EBV-transformed lymphocytes, Testis]
# 9823       [Cells - EBV-transformed lymphocytes, Testis]
# 9847       [Cells - EBV-transformed lymphocytes, Testis]
# 9849       [Cells - EBV-transformed lymphocytes, Testis]
# 9906       [Cells - EBV-transformed lymphocytes, Testis]
# 9910       [Cells - EBV-transformed lymphocytes, Testis]
# 9911       [Cells - EBV-transformed lymphocytes, Testis]
# 9912       [Cells - EBV-transformed lymphocytes, Testis]
# 9913       [Cells - EBV-transformed lymphocytes, Testis]
# 9914       [Cells - EBV-transformed lymphocytes, Testis]
# 9917       [Cells - EBV-transformed lymphocytes, Testis]
# 9919       [Cells - EBV-transformed lymphocytes, Testis]
# 9921       [Cells - EBV-transformed lymphocytes, Testis]
# 10227  [Adipose - Subcutaneous, Cells - Cultured fibr...
# 10228  [Adipose - Subcutaneous, Cells - Cultured fibr...
# 10262   [Kidney - Cortex, Minor Salivary Gland, Stomach]
# 10533  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 10534  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 10538  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 11302  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 11548      [Heart - Atrial Appendage, Muscle - Skeletal]
# 11550      [Heart - Atrial Appendage, Muscle - Skeletal]
# 11552      [Heart - Atrial Appendage, Muscle - Skeletal]
# 11720  [Brain - Amygdala, Brain - Putamen (basal gang...
# 13072  [Cells - EBV-transformed lymphocytes, Muscle -...
# 13074  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 13079  [Brain - Cerebellar Hemisphere, Brain - Cerebe...
# 13094  [Cells - Cultured fibroblasts, Cells - EBV-tra...
#
#                                                  BP_Down  \
# 3092   [growthWeight, growthWeight, genitourinaryBlad...
# 3093   [growthWeight, growthWeight, genitourinaryBlad...
# 3094   [growthWeight, growthWeight, genitourinaryBlad...
# 4418                [genitourinaryExternalGenitaliaMale]
# 4420                [genitourinaryExternalGenitaliaMale]
# 4435                [genitourinaryExternalGenitaliaMale]
# 4588   [headAndNeckHead, neurologicCentralNervousSyst...
# 4590   [headAndNeckHead, neurologicCentralNervousSyst...
# 4591   [headAndNeckHead, neurologicCentralNervousSyst...
# 4595   [headAndNeckHead, neurologicCentralNervousSyst...
# 4599   [headAndNeckHead, neurologicCentralNervousSyst...
# 4636                                  [muscleSoftTissue]
# 4637                                  [muscleSoftTissue]
# 5105   [headAndNeckHead, neurologicCentralNervousSystem]
# 5202   [headAndNeckHead, neurologicCentralNervousSyst...
# 5693   [immunology, genitourinaryExternalGenitaliaMal...
# 5694   [immunology, genitourinaryExternalGenitaliaMal...
# 5695   [immunology, genitourinaryExternalGenitaliaMal...
# 5696   [immunology, genitourinaryExternalGenitaliaMal...
# 5700   [immunology, genitourinaryExternalGenitaliaMal...
# 5702   [immunology, genitourinaryExternalGenitaliaMal...
# 6382                                      [abdomenLiver]
# 6772   [headAndNeckHead, neurologicCentralNervousSystem]
# 7493   [headAndNeckHead, neurologicCentralNervousSystem]
# 7520                            [cardiovascularVascular]
# 7528   [headAndNeckHead, neurologicCentralNervousSystem]
# 7884    [genitourinaryExternalGenitaliaMale, hematology]
# 8018    [genitourinaryExternalGenitaliaMale, hematology]
# 8170    [genitourinaryExternalGenitaliaMale, hematology]
# 8900                                     [abdomenSpleen]
# 8908                                     [abdomenSpleen]
# 9703   [headAndNeckHead, neurologicCentralNervousSyst...
# 9712   [headAndNeckHead, neurologicCentralNervousSyst...
# 9714   [headAndNeckHead, neurologicCentralNervousSyst...
# 9786    [immunology, genitourinaryExternalGenitaliaMale]
# 9823    [immunology, genitourinaryExternalGenitaliaMale]
# 9847    [immunology, genitourinaryExternalGenitaliaMale]
# 9849    [immunology, genitourinaryExternalGenitaliaMale]
# 9906    [immunology, genitourinaryExternalGenitaliaMale]
# 9910    [immunology, genitourinaryExternalGenitaliaMale]
# 9911    [immunology, genitourinaryExternalGenitaliaMale]
# 9912    [immunology, genitourinaryExternalGenitaliaMale]
# 9913    [immunology, genitourinaryExternalGenitaliaMale]
# 9914    [immunology, genitourinaryExternalGenitaliaMale]
# 9917    [immunology, genitourinaryExternalGenitaliaMale]
# 9919    [immunology, genitourinaryExternalGenitaliaMale]
# 9921    [immunology, genitourinaryExternalGenitaliaMale]
# 10227  [growthWeight, immunology, genitourinaryExtern...
# 10228  [growthWeight, immunology, genitourinaryExtern...
# 10262  [genitourinaryKidneys, headAndNeckMouth, headA...
# 10533  [headAndNeckHead, neurologicCentralNervousSyst...
# 10534  [headAndNeckHead, neurologicCentralNervousSyst...
# 10538  [headAndNeckHead, neurologicCentralNervousSyst...
# 11302  [headAndNeckHead, neurologicCentralNervousSyst...
# 11548            [cardiovascularHeart, muscleSoftTissue]
# 11550            [cardiovascularHeart, muscleSoftTissue]
# 11552            [cardiovascularHeart, muscleSoftTissue]
# 11720  [headAndNeckHead, neurologicCentralNervousSyst...
# 13072                     [immunology, muscleSoftTissue]
# 13074  [headAndNeckHead, neurologicCentralNervousSyst...
# 13079  [headAndNeckHead, neurologicCentralNervousSyst...
# 13094  [immunology, muscleSoftTissue, genitourinaryEx...
#
#                               Down_tissues_EXOTIC_values  \
# 3092   [0.602, 0.602, 0.602, 0.602, 0.602, 0.602, 0.6...
# 3093   [0.602, 0.602, 0.602, 0.602, 0.602, 0.602, 0.6...
# 3094   [0.602, 0.602, 0.602, 0.602, 0.602, 0.602, 0.6...
# 4418                                              [0.67]
# 4420                                              [0.67]
# 4435                                              [0.61]
# 4588                                [0.62, 0.638, 0.858]
# 4590                                [0.62, 0.638, 0.858]
# 4591                                [0.62, 0.638, 0.858]
# 4595                                [0.62, 0.638, 0.858]
# 4599                                [0.62, 0.638, 0.858]
# 4636                                             [0.659]
# 4637                                             [0.659]
# 5105                                             [0.633]
# 5202                                [0.68, 0.668, 0.694]
# 5693                               [0.777, 0.799, 0.637]
# 5694                               [0.777, 0.799, 0.637]
# 5695                               [0.777, 0.799, 0.637]
# 5696                               [0.777, 0.799, 0.637]
# 5700                               [0.777, 0.799, 0.637]
# 5702                               [0.777, 0.799, 0.637]
# 6382                                             [0.702]
# 6772                                             [0.612]
# 7493                                             [0.604]
# 7520                                      [0.629, 0.675]
# 7528                                             [0.619]
# 7884                                      [0.923, 0.644]
# 8018                                      [0.923, 0.644]
# 8170                                      [0.923, 0.644]
# 8900                                             [0.621]
# 8908                                             [0.621]
# 9703                                      [0.751, 0.712]
# 9712                                      [0.751, 0.712]
# 9714                                      [0.751, 0.712]
# 9786                                      [0.617, 0.669]
# 9823                                      [0.617, 0.669]
# 9847                                      [0.617, 0.669]
# 9849                                      [0.617, 0.669]
# 9906                                      [0.617, 0.669]
# 9910                                      [0.617, 0.669]
# 9911                                      [0.617, 0.669]
# 9912                                      [0.617, 0.669]
# 9913                                      [0.617, 0.669]
# 9914                                      [0.617, 0.669]
# 9917                                      [0.617, 0.669]
# 9919                                      [0.617, 0.669]
# 9921                                      [0.617, 0.669]
# 10227  [0.654, 0.654, 0.62, 0.832, 0.886, 0.661, 0.65...
# 10228  [0.654, 0.654, 0.62, 0.832, 0.886, 0.661, 0.65...
# 10262                               [0.75, 0.713, 0.734]
# 10533                                     [0.647, 0.639]
# 10534                                     [0.647, 0.639]
# 10538                                     [0.647, 0.639]
# 11302                              [0.803, 0.729, 0.686]
# 11548                                     [0.945, 0.927]
# 11550                                     [0.945, 0.927]
# 11552                                     [0.945, 0.927]
# 11720                                      [0.628, 0.62]
# 13072                                     [0.717, 0.863]
# 13074                       [0.662, 0.628, 0.606, 0.867]
# 13079                       [0.662, 0.628, 0.606, 0.867]
# 13094                       [0.618, 0.642, 0.756, 0.689]
#
#                                            Check_BP_down
# 3092                                        [immunology]
# 3093                                        [immunology]
# 3094                                        [immunology]
# 4418                [genitourinaryExternalGenitaliaMale]
# 4420                [genitourinaryExternalGenitaliaMale]
# 4435                [genitourinaryExternalGenitaliaMale]
# 4588                                   [headAndNeckHead]
# 4590                                   [headAndNeckHead]
# 4591                                   [headAndNeckHead]
# 4595                                   [headAndNeckHead]
# 4599                                   [headAndNeckHead]
# 4636                                  [muscleSoftTissue]
# 4637                                  [muscleSoftTissue]
# 5105                    [neurologicCentralNervousSystem]
# 5202                [genitourinaryExternalGenitaliaMale]
# 5693                [genitourinaryExternalGenitaliaMale]
# 5694                [genitourinaryExternalGenitaliaMale]
# 5695                [genitourinaryExternalGenitaliaMale]
# 5696                [genitourinaryExternalGenitaliaMale]
# 5700                [genitourinaryExternalGenitaliaMale]
# 5702                [genitourinaryExternalGenitaliaMale]
# 6382                                      [abdomenLiver]
# 6772                    [neurologicCentralNervousSystem]
# 7493                                   [headAndNeckHead]
# 7520                            [cardiovascularVascular]
# 7528                                   [headAndNeckHead]
# 7884                [genitourinaryExternalGenitaliaMale]
# 8018                                        [hematology]
# 8170                                        [hematology]
# 8900                                     [abdomenSpleen]
# 8908                                     [abdomenSpleen]
# 9703   [neurologicCentralNervousSystem, neurologicCen...
# 9712   [neurologicCentralNervousSystem, neurologicCen...
# 9714   [neurologicCentralNervousSystem, neurologicCen...
# 9786                [genitourinaryExternalGenitaliaMale]
# 9823                [genitourinaryExternalGenitaliaMale]
# 9847                [genitourinaryExternalGenitaliaMale]
# 9849                [genitourinaryExternalGenitaliaMale]
# 9906                [genitourinaryExternalGenitaliaMale]
# 9910                [genitourinaryExternalGenitaliaMale]
# 9911                [genitourinaryExternalGenitaliaMale]
# 9912                [genitourinaryExternalGenitaliaMale]
# 9913                [genitourinaryExternalGenitaliaMale]
# 9914                [genitourinaryExternalGenitaliaMale]
# 9917                [genitourinaryExternalGenitaliaMale]
# 9919                [genitourinaryExternalGenitaliaMale]
# 9921                [genitourinaryExternalGenitaliaMale]
# 10227                                 [muscleSoftTissue]
# 10228  [abdomenGastrointestinal, genitourinaryExterna...
# 10262                          [abdomenGastrointestinal]
# 10533                 [headAndNeckHead, headAndNeckHead]
# 10534                 [headAndNeckHead, headAndNeckHead]
# 10538                 [headAndNeckHead, headAndNeckHead]
# 11302  [neurologicCentralNervousSystem, neurologicCen...
# 11548                              [cardiovascularHeart]
# 11550                              [cardiovascularHeart]
# 11552                              [cardiovascularHeart]
# 11720  [headAndNeckHead, neurologicCentralNervousSyst...
# 13072                                 [muscleSoftTissue]
# 13074  [headAndNeckHead, headAndNeckHead, muscleSoftT...
# 13079  [headAndNeckHead, headAndNeckHead, muscleSoftT...
# 13094                                 [muscleSoftTissue]
