# %%
import math
import os
import sys
import pandas as pd
sys.path.append("/home/weber/PycharmProjects/EXOTIC/src")
from statannot import add_stat_annotation

pd.options.mode.chained_assignment = None  # default='warn'
import multiprocessing
import parmap
import numpy as np
import collections
from tqdm import tqdm
import pandarallel
from pandarallel import pandarallel

pandarallel.initialize(nb_workers=20, progress_bar=True)
# tqdm.pandas()
from pprint import pprint
from scipy.stats import zscore
from scipy import stats

import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as mc
from matplotlib.colors import LogNorm
import json
import matplotlib.ticker as mtick
from utils.utils import load_config_file

## YAML FILES CONFIG
yaml = load_config_file(config_file="/home/weber/PycharmProjects/EXOTIC/src/config.yaml")
exotic_files = yaml

import matplotlib.font_manager as font_manager

font_dirs = ['/home/weber/Fonts', ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rcParams['font.weight'] = 'light'
# Out:
# INFO: Pandarallel will run on 20 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/ipykernel_launcher.py:42: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.

# %%
drugbank_kirsley = pd.read_excel('/gstock/biolo_datasets/DrugBank/drugbank_kirsley.xlsx')
drugbank_kirsley
# Out:
#      drug_id              drug_name       effect_type    gene        rsid  \
# 0    DB00002              Cetuximab        snp_effect  FCGR2A   rs1801274
# 1    DB00002              Cetuximab        snp_effect  FCGR3A    rs396991
# 2    DB00008  Peginterferon alfa-2a        snp_effect   IFNL3  rs12979860
# 3    DB00022  Peginterferon alfa-2b        snp_effect   IFNL3  rs12979860
# 4    DB00065             Infliximab        snp_effect  FCGR3A   rs1801274
# ..       ...                    ...               ...     ...         ...
# 319  DB09256                Tegafur  adverse_reaction    DPYD  rs67376798
# 320  DB09256                Tegafur  adverse_reaction    DPYD   rs1801158
# 321  DB09256                Tegafur  adverse_reaction    DPYD   rs1801159
# 322  DB09256                Tegafur  adverse_reaction    DPYD   rs1801160
# 323  DB09256                Tegafur  adverse_reaction    DPYD   rs1801265
#
#     uniprot_acc        pmid                  change  \
# 0        P12318  17704420.0               H allelle
# 1        P08637  17704420.0                   G > T
# 2        Q8IZI9  24096968.0                   C > T
# 3        Q8IZI9  24096968.0                   C > T
# 4        P08637  18930989.0  CC Allele (homozygous)
# ..          ...         ...                     ...
# 319      Q12882  23988873.0                   T > A
# 320      Q12882  23988873.0                   G > A
# 321      Q12882  23988873.0                   A > G
# 322      Q12882  23988873.0                   G > A
# 323      Q12882  23988873.0                   T > C
#
#                                                   desc             ensg  \
# 0    Patients with this genotype may have increased...  ENST00000367972
# 1    Patients with this genotype have increased pro...  ENST00000443193
# 2    Patients with this genotype in IFNL3 have a re...  ENST00000413851
# 3    Patients with this genotype in IFNL3 have a re...  ENST00000413851
# 4    Patients with this genotype have increased ACR...  ENST00000443193
# ..                                                 ...              ...
# 319  The presence of this genotype in DPYD may be a...  ENST00000370192
# 320  The presence of this genotype in DPYD may be a...  ENST00000370192
# 321  The presence of this genotype in DPYD may be a...  ENST00000370192
# 322  The presence of this genotype in DPYD may be a...  ENST00000370192
# 323  The presence of this genotype in DPYD may be a...  ENST00000370192
#
#                    varid
# 0    chr1:g.161479745A>T
# 1    chr1:g.161514542A>T
# 2    chr19:g.39738787C>T
# 3    chr19:g.39738787C>T
# 4    chr1:g.161479745A>T
# ..                   ...
# 319   chr1:g.97547947T>A
# 320   chr1:g.97981421C>T
# 321   chr1:g.97981395T>C
# 322   chr1:g.97770920C>T
# 323   chr1:g.98348885T>C
#
# [324 rows x 11 columns]

# %%
exotic = pd.read_parquet('/gstock/EXOTIC/data/EXOTIC/EXOTIC_modified_zscore_mean_prop_corrected.parquet')
exotic
# Out:
#       symbol             ensg   HGNC                 Exon  Ratio_num  mRNA_nb  \
# 0      A2ML1  ENSG00000166535  23336      8975248-8975309   0.500000        1
# 1      A2ML1  ENSG00000166535  23336      8975778-8975961   0.500000        1
# 2      A2ML1  ENSG00000166535  23336      8976316-8976478   0.500000        1
# 3      A2ML1  ENSG00000166535  23336      8982323-8982375   0.500000        1
# 4      A2ML1  ENSG00000166535  23336      8987258-8987278   0.500000        1
# ...      ...              ...    ...                  ...        ...      ...
# 27547   ZXDC  ENSG00000070476  28160  126158475-126158570   0.500000        1
# 27548   ZXDC  ENSG00000070476  28160  126160608-126160789   0.500000        1
# 27549   ZXDC  ENSG00000070476  28160  126178496-126178580   0.500000        1
# 27550   ZXDC  ENSG00000070476  28160  126180378-126181063   0.500000        1
# 27551    ZYX  ENSG00000159840  13200  143079686-143079778   0.666667        2
#
#        mRNA_nb_total                       MAP  mean_proportion  \
# 0                  2     A2ML1_8975248-8975309          0.69514
# 1                  2     A2ML1_8975778-8975961          0.69514
# 2                  2     A2ML1_8976316-8976478          0.69514
# 3                  2     A2ML1_8982323-8982375          0.69514
# 4                  2     A2ML1_8987258-8987278          0.69514
# ...              ...                       ...              ...
# 27547              2  ZXDC_126158475-126158570          0.20989
# 27548              2  ZXDC_126160608-126160789          0.20989
# 27549              2  ZXDC_126178496-126178580          0.20989
# 27550              2  ZXDC_126180378-126181063          0.34803
# 27551              3   ZYX_143079686-143079778          0.26888
#
#        Adipose - Subcutaneous  ...    Vagina  Whole Blood  EXOTIC_down  \
# 0                    0.578349  ...  0.500000     0.578349     0.713205
# 1                    0.578349  ...  0.500000     0.578349     0.713205
# 2                    0.578349  ...  0.500000     0.578349     0.713205
# 3                    0.578349  ...  0.500000     0.578349     0.713205
# 4                    0.578349  ...  0.500000     0.578349     0.713205
# ...                       ...  ...       ...          ...          ...
# 27547                0.500250  ...  0.508499     0.495250     0.542398
# 27548                0.500250  ...  0.508499     0.495250     0.542398
# 27549                0.500250  ...  0.508499     0.495250     0.542398
# 27550                0.515245  ...  0.505750     0.441272     0.558728
# 27551                0.504750  ...  0.500000     0.455865     0.559960
#
#        EXOTIC_bins_down  EXOTIC_bins_lite_down  \
# 0            0.7 - 0.75              0.7 - 0.8
# 1            0.7 - 0.75              0.7 - 0.8
# 2            0.7 - 0.75              0.7 - 0.8
# 3            0.7 - 0.75              0.7 - 0.8
# 4            0.7 - 0.75              0.7 - 0.8
# ...                 ...                    ...
# 27547        0.5 - 0.55              0.5 - 0.6
# 27548        0.5 - 0.55              0.5 - 0.6
# 27549        0.5 - 0.55              0.5 - 0.6
# 27550        0.55 - 0.6              0.5 - 0.6
# 27551        0.55 - 0.6              0.5 - 0.6
#
#                                EXOTIC_tissues_down  EXOTIC_up  EXOTIC_bins_up  \
# 0                  [Brain - Cerebellar Hemisphere]   0.578349      0.55 - 0.6
# 1                  [Brain - Cerebellar Hemisphere]   0.578349      0.55 - 0.6
# 2                  [Brain - Cerebellar Hemisphere]   0.578349      0.55 - 0.6
# 3                  [Brain - Cerebellar Hemisphere]   0.578349      0.55 - 0.6
# 4                  [Brain - Cerebellar Hemisphere]   0.578349      0.55 - 0.6
# ...                                            ...        ...             ...
# 27547  [Brain - Nucleus accumbens (basal ganglia)]   0.574443      0.55 - 0.6
# 27548  [Brain - Nucleus accumbens (basal ganglia)]   0.574443      0.55 - 0.6
# 27549  [Brain - Nucleus accumbens (basal ganglia)]   0.574443      0.55 - 0.6
# 27550                                [Whole Blood]   0.606828      0.6 - 0.65
# 27551                                      [Liver]   0.557248      0.55 - 0.6
#
#        EXOTIC_bins_lite_up                                  EXOTIC_tissues_up
# 0                0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 1                0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 2                0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 3                0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# 4                0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
# ...                    ...                                                ...
# 27547            0.5 - 0.6                                [Muscle - Skeletal]
# 27548            0.5 - 0.6                                [Muscle - Skeletal]
# 27549            0.5 - 0.6                                [Muscle - Skeletal]
# 27550            0.6 - 0.7                                  [Artery - Tibial]
# 27551            0.5 - 0.6                                  [Artery - Tibial]
#
# [27552 rows x 70 columns]

# %%
l = list()
import re
for gene in exotic.symbol.unique().tolist():
    exotic_gene = exotic.loc[exotic['symbol'] == gene]
    drug_gene = drugbank_kirsley.loc[drugbank_kirsley['gene'] == gene]
    drug_gene = drug_gene.loc[drug_gene['varid'].isna() == False]
    
    if drug_gene.empty is False:
        print(gene)
        drug_gene['var_pos'] = drug_gene['varid'].apply(lambda r: re.search('\d{3,}', r).group(0))
        drug_gene['var_pos'] = drug_gene['var_pos'].astype(int)
        for exon in exotic_gene.Exon.values:
            between = drug_gene.var_pos.between(int(exon.split('-')[0]), int(exon.split('-')[1]))
            if True in between.values.tolist():
                drug_gene_filter = drug_gene.loc[list(between.index)]
                drug_gene_filter['Exon'] = exon
                l.append(drug_gene_filter)
drug_df_filter = pd.concat(l)
drug_df_filter
# Out:
# ABCB1
# ABCG2
# ACE
# COMT
# CREB1
# DPYD
# EGFR
# ERBB2
# FCGR2A
# FCGR3A
# FLOT1
# GRIK2
# GRIK4
# HMGCR
# HNRNPD
# KCNH2
# MTHFR
# RARG
# RRM1
# SERPINC1
# TYMS
# VKORC1
#      drug_id       drug_name       effect_type      gene         rsid  \
# 123  DB00544    Fluorouracil  adverse_reaction      DPYD    rs1801265
# 125  DB00544    Fluorouracil  adverse_reaction      DPYD    rs3918290
# 126  DB00544    Fluorouracil  adverse_reaction      DPYD   rs67376798
# 127  DB00544    Fluorouracil  adverse_reaction      DPYD    rs3918290
# 128  DB00544    Fluorouracil  adverse_reaction      DPYD   rs55886062
# ..       ...             ...               ...       ...          ...
# 312  DB08916        Afatinib        snp_effect      EGFR   rs28929495
# 5    DB00072     Trastuzumab  adverse_reaction     ERBB2    rs1136201
# 274  DB01233  Metoclopramide        snp_effect     KCNH2    rs1805123
# 280  DB01233  Metoclopramide  adverse_reaction     KCNH2    rs3815459
# 306  DB06210     Eltrombopag  adverse_reaction  SERPINC1  rs121909567
#
#     uniprot_acc        pmid                  change  \
# 123      Q12882  17848752.0                C allele
# 125      Q12882  18299612.0                A allele
# 126      Q12882  23603345.0                   T > A
# 127      Q12882  23988873.0                   G > A
# 128      Q12882  23988873.0                   A > C
# ..          ...         ...                     ...
# 312      P00533  15118073.0         G > A or C or T
# 5        P04626  17693647.0  G Allele, heterozygote
# 274      Q12809  22688145.0                   A > C
# 280      Q12809  22688145.0                   G > A
# 306      P01008  27214036.0                   C > T
#
#                                                   desc             ensg  \
# 123  Patients with this genotype have reduced metab...  ENST00000370192
# 125  Patients with this genotype have reduced metab...  ENST00000370192
# 126  Patients with this genotype have reduced metab...  ENST00000370192
# 127  The presence of this genotype in DPYD is assoc...  ENST00000370192
# 128  The presence of this genotype in DPYD is assoc...  ENST00000370192
# ..                                                 ...              ...
# 312  The presence of this polymorphism in EGFR is a...  ENST00000420316
# 5    Patients with this genotype have increased ris...  ENST00000584601
# 274  The presence of this polymorphism in KCNH2 may...  ENST00000330883
# 280  The presence of this polymorphism in KCNH2 is ...  ENST00000330883
# 306  Patients who carry this polymorphism in SERPIN...  ENST00000367698
#
#                    varid    var_pos                 Exon
# 123   chr1:g.98348885T>C   98348885    97547886-97548026
# 125   chr1:g.97915614C>G   97915614    97547886-97548026
# 126   chr1:g.97547947T>A   97547947    97547886-97548026
# 127   chr1:g.97915614C>G   97915614    97547886-97548026
# 128   chr1:g.97981343A>T   97981343    97547886-97548026
# ..                   ...        ...                  ...
# 312   chr7:g.55241707G>A   55241707    55259412-55259567
# 5    chr17:g.37879588A>C   37879588    37879572-37879710
# 274  chr7:g.150645534T>C  150645534  150645532-150645631
# 280  chr7:g.150644394C>A  150644394  150645532-150645631
# 306  chr1:g.173883708G>A  173883708  173883691-173883954
#
# [94 rows x 13 columns]

# %%
map_dict = {
    "se_blood" : ["Whole Blood"],
    "se_heart" : ["Heart - Atrial Appendage", "Heart - Left Ventricle"],
    "se_congenital" : [""],
    "se_ear" : [""],
    "se_endocrine" : ["Thyroid", "Pituitary", "Adrenal Gland"],
    "se_eye" : [""],
    "se_gi" : [""],
    "se_hepatobiliary" : [""],
    "se_immune" : ["Cells - EBV-transformed lymphocytes"],
    "se_infection" : ["Cells - EBV-transformed lymphocytes"],
    "se_metabolism" : [""],
    "se_musculoskeletal" : ["Muscle - Skeletal"],
    "se_neoplasm" : [""],
    "se_nervous" : ["Nerve - Tibial"],
    "se_pregnancy" : [""],
    "se_mental" : ["Brain - Amygdala", "Brain - Anterior cingulate cortex (BA24)", "Brain - Caudate (basal ganglia)", "Brain - Cerebellar Hemisphere", "Brain - Cerebellum", "Brain - Cortex", "Brain - Frontal Cortex (BA9)", "Brain - Hippocampus", "Brain - Hypothalamus", "Brain - Nucleus accumbens (basal ganglia)", "Brain - Putamen (basal ganglia)", "Brain - Spinal cord (cervical c-1)", "Brain - Substantia nigra"],
    "se_urologic" : ["Prostate", "Uterus", "Vagina", "Bladder"],
    "se_repro" : ["Cervix - Ectocervix", "Cervix - Endocervix", "Fallopian Tube", "Ovary", "Testis"],
    "se_respiratory" : ["Lung"],
    "se_skin" : ["Skin - Sun Exposed (Lower leg)", "Skin - Not Sun Exposed (Suprapubic)"],
    "se_vascular" : ["Artery - Aorta", "Artery - Coronary"],

}

# %%
drugbank_se = pd.read_excel('/gstock/biolo_datasets/DrugBank/publi_SE_drugs.xlsx')
drugbank_se = drugbank_se.loc[drugbank_se['has_se'] == True]
drugbank_se = drugbank_se.filter(regex='myDrugName|se_').melt(id_vars='myDrugName', value_vars=['se_blood', 'se_heart', 'se_congenital', 'se_ear',
       'se_endocrine', 'se_eye', 'se_gi', 'se_hepatobiliary', 'se_immune',
       'se_infection', 'se_metabolism', 'se_musculoskeletal', 'se_neoplasm',
       'se_nervous', 'se_pregnancy', 'se_mental', 'se_urologic', 'se_repro',
       'se_respiratory', 'se_skin', 'se_vascular'])
drugbank_se = drugbank_se.loc[drugbank_se['value'] == 1]
drugbank_se['Tissues'] = drugbank_se['variable'].map(map_dict)
drugbank_se = drugbank_se.explode('Tissues')
drugbank_se = drugbank_se.rename({'myDrugName' : 'drug_name'}, axis=1)
drugbank_se = pd.merge(drugbank_se,  drugbank_kirsley[['drug_name', 'gene']].drop_duplicates().groupby('drug_name')['gene'].apply(list).reset_index(), on='drug_name')
drugbank_se
# Out:
# Empty DataFrame
# Columns: [drug_name, variable, value, Tissues, gene]
# Index: []

# %%
drugbank_kirsley_to_merge = drugbank_kirsley[['drug_name', 'gene']].drop_duplicates().groupby('drug_name')['gene'].apply(list).reset_index()
drugbank_kirsley_to_merge['drug_bank'] = drugbank_kirsley_to_merge['drug_bank'].str.lower()
# Out:
#                 drug_name                     gene
# 0                Abacavir                   [HCP5]
# 1           Acenocoumarol         [CYP2C9, VKORC1]
# 2    Acetylsalicylic acid   [CYP2C9, ITGB3, LTC4S]
# 3                Afatinib                   [EGFR]
# 4             Allopurinol                   [HCP5]
# ..                    ...                      ...
# 107           Venlafaxine          [CYP2D6, ABCB1]
# 108             Verapamil                  [ADRB1]
# 109          Voriconazole                [CYP2C19]
# 110              Warfarin  [CYP2C9, VKORC1, CP4F2]
# 111          Zolmitriptan                   [GNB3]
#
# [112 rows x 2 columns]

# %%
pd.merge(drug_df_filter, exotic, on='Exon')
# Out:
#     drug_id       drug_name       effect_type      gene         rsid  \
# 0   DB00544    Fluorouracil  adverse_reaction      DPYD    rs1801265
# 1   DB00544    Fluorouracil  adverse_reaction      DPYD    rs3918290
# 2   DB00544    Fluorouracil  adverse_reaction      DPYD   rs67376798
# 3   DB00544    Fluorouracil  adverse_reaction      DPYD    rs3918290
# 4   DB00544    Fluorouracil  adverse_reaction      DPYD   rs55886062
# ..      ...             ...               ...       ...          ...
# 89  DB08916        Afatinib        snp_effect      EGFR   rs28929495
# 90  DB00072     Trastuzumab  adverse_reaction     ERBB2    rs1136201
# 91  DB01233  Metoclopramide        snp_effect     KCNH2    rs1805123
# 92  DB01233  Metoclopramide  adverse_reaction     KCNH2    rs3815459
# 93  DB06210     Eltrombopag  adverse_reaction  SERPINC1  rs121909567
#
#    uniprot_acc        pmid                  change  \
# 0       Q12882  17848752.0                C allele
# 1       Q12882  18299612.0                A allele
# 2       Q12882  23603345.0                   T > A
# 3       Q12882  23988873.0                   G > A
# 4       Q12882  23988873.0                   A > C
# ..         ...         ...                     ...
# 89      P00533  15118073.0         G > A or C or T
# 90      P04626  17693647.0  G Allele, heterozygote
# 91      Q12809  22688145.0                   A > C
# 92      Q12809  22688145.0                   G > A
# 93      P01008  27214036.0                   C > T
#
#                                                  desc           ensg_x  ...  \
# 0   Patients with this genotype have reduced metab...  ENST00000370192  ...
# 1   Patients with this genotype have reduced metab...  ENST00000370192  ...
# 2   Patients with this genotype have reduced metab...  ENST00000370192  ...
# 3   The presence of this genotype in DPYD is assoc...  ENST00000370192  ...
# 4   The presence of this genotype in DPYD is assoc...  ENST00000370192  ...
# ..                                                ...              ...  ...
# 89  The presence of this polymorphism in EGFR is a...  ENST00000420316  ...
# 90  Patients with this genotype have increased ris...  ENST00000584601  ...
# 91  The presence of this polymorphism in KCNH2 may...  ENST00000330883  ...
# 92  The presence of this polymorphism in KCNH2 is ...  ENST00000330883  ...
# 93  Patients who carry this polymorphism in SERPIN...  ENST00000367698  ...
#
#       Vagina  Whole Blood EXOTIC_down EXOTIC_bins_down EXOTIC_bins_lite_down  \
# 0   0.499500     0.500750    0.597245       0.55 - 0.6             0.5 - 0.6
# 1   0.499500     0.500750    0.597245       0.55 - 0.6             0.5 - 0.6
# 2   0.499500     0.500750    0.597245       0.55 - 0.6             0.5 - 0.6
# 3   0.499500     0.500750    0.597245       0.55 - 0.6             0.5 - 0.6
# 4   0.499500     0.500750    0.597245       0.55 - 0.6             0.5 - 0.6
# ..       ...          ...         ...              ...                   ...
# 89  0.463067     0.536187    0.557741       0.55 - 0.6             0.5 - 0.6
# 90  0.493500     0.501750    0.755470       0.75 - 0.8             0.7 - 0.8
# 91  0.503250     0.246011    0.753989       0.75 - 0.8             0.7 - 0.8
# 92  0.503250     0.246011    0.753989       0.75 - 0.8             0.7 - 0.8
# 93  0.500000     0.500000    0.537430       0.5 - 0.55             0.5 - 0.6
#
#                       EXOTIC_tissues_down  EXOTIC_up  EXOTIC_bins_up  \
# 0    [Brain - Spinal cord (cervical c-1)]   0.529715      0.5 - 0.55
# 1    [Brain - Spinal cord (cervical c-1)]   0.529715      0.5 - 0.55
# 2    [Brain - Spinal cord (cervical c-1)]   0.529715      0.5 - 0.55
# 3    [Brain - Spinal cord (cervical c-1)]   0.529715      0.5 - 0.55
# 4    [Brain - Spinal cord (cervical c-1)]   0.529715      0.5 - 0.55
# ..                                    ...        ...             ...
# 89       [Skin - Sun Exposed (Lower leg)]   0.536187      0.5 - 0.55
# 90  [Cells - EBV-transformed lymphocytes]   0.521986      0.5 - 0.55
# 91                          [Whole Blood]   0.613251      0.6 - 0.65
# 92                          [Whole Blood]   0.613251      0.6 - 0.65
# 93                                [Liver]   0.500000      0.5 - 0.55
#
#     EXOTIC_bins_lite_up                                  EXOTIC_tissues_up
# 0             0.5 - 0.6                                    [Adrenal Gland]
# 1             0.5 - 0.6                                    [Adrenal Gland]
# 2             0.5 - 0.6                                    [Adrenal Gland]
# 3             0.5 - 0.6                                    [Adrenal Gland]
# 4             0.5 - 0.6                                    [Adrenal Gland]
# ..                  ...                                                ...
# 89            0.5 - 0.6  [Brain - Cerebellar Hemisphere, Brain - Spinal...
# 90            0.5 - 0.6                         [Brain - Substantia nigra]
# 91            0.6 - 0.7              [Cells - EBV-transformed lymphocytes]
# 92            0.6 - 0.7              [Cells - EBV-transformed lymphocytes]
# 93            0.5 - 0.6  [Adipose - Subcutaneous, Adipose - Visceral (O...
#
# [94 rows x 82 columns]
