# %%
import os
import sys
import pandas as pd
import numpy as np
sys.path.append("/home/weber/PycharmProjects/EXOTIC/src")
from statannot import add_stat_annotation

from tqdm import tqdm
tqdm.pandas()

pd.options.mode.chained_assignment = None  # default='warn'

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.colors as mc
from matplotlib.colors import LogNorm
import json
import matplotlib.ticker as mtick
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D   
from utils.utils import load_config_file

## YAML FILES CONFIG
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

# JSON
dicts = json.load(open("../../clean/src/config/EXOTIC_config.json"))


import matplotlib.font_manager as font_manager

font_dirs = ['/home/weber/Fonts', ]
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)
font_list = font_manager.createFontList(font_files)
font_manager.fontManager.ttflist.extend(font_list)

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
rcParams['font.weight'] = 'light'
# Out:
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/tqdm/std.py:668: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/weber/.conda/envs/ExoCarto/lib/python3.7/site-packages/ipykernel_launcher.py:36: MatplotlibDeprecationWarning:
# The createFontList function was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use FontManager.addfont instead.

# %%
def output_figure(f, name):
    print(name)
    for ext in ['png', 'jpg']:
        for res in [150, 300]:
            f.savefig(name + '_{}_DPI.{}'.format(res, ext), dpi=res)

# %%
def show_values_on_bars(axs, i=0, fontsize=13, rotation=0):
    def _show_on_single_plot(ax):
        for p in ax.patches:
            print(p)
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + (p.get_height()) + 20
            if i == 0:
                value = "{:.0f}".format(p.get_height())
            if i == 2:
                value = "{:.2f}".format(p.get_height())

            if i == 3:
                value = "{:.3f}".format(p.get_height())
            ax.text(_x, _y, str(round(int(value), 0)), ha="center", fontsize=fontsize, rotation=rotation, color='black')

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %%
def convert_bins_into_labels(bins):
    return [" - ".join([str(round(bins[j],2)) + " - " + str(round(bins[j+1],2))]) for j, e in enumerate(bins) if j <len(bins)-1]

# %%
dext
# Out:
#         Gene               ranges                 mRNA_exons  mRNA_nb  Share  \
# 0      A2ML1      8975248-8975309                [NM_144670]        1  False
# 1      A2ML1      8975778-8975961                [NM_144670]        1  False
# 2      A2ML1      8976316-8976478                [NM_144670]        1  False
# 3      A2ML1      8982323-8982375                [NM_144670]        1  False
# 4      A2ML1      8987258-8987278                [NM_144670]        1  False
# ...      ...                  ...                        ...      ...    ...
# 31601   ZXDC  126178496-126178580                [NM_025112]        1  False
# 31602   ZXDC  126180372-126181063             [NM_001040653]        1  False
# 31603    ZYX  143079686-143079778  [NM_001010972, NM_003461]        2  False
# 31604   ZZZ3    78097535-78099039                [NM_015534]        1  False
# 31605   ZZZ3    78105134-78105156             [NM_001308237]        1  False
#
#        Strand                                mRNA_gene  mRNA_nb_total Ratio  \
# 0           1                [NM_001282424, NM_144670]              2   1/2
# 1           1                [NM_001282424, NM_144670]              2   1/2
# 2           1                [NM_001282424, NM_144670]              2   1/2
# 3           1                [NM_001282424, NM_144670]              2   1/2
# 4           1                [NM_001282424, NM_144670]              2   1/2
# ...       ...                                      ...            ...   ...
# 31601       0                [NM_001040653, NM_025112]              2   1/2
# 31602       0                [NM_001040653, NM_025112]              2   1/2
# 31603       1  [NM_001010972, NM_001362783, NM_003461]              3   2/3
# 31604       0                [NM_001308237, NM_015534]              2   1/2
# 31605       0                [NM_001308237, NM_015534]              2   1/2
#
#        Ratio_num  ...    Testis   Thyroid    Uterus    Vagina  Whole Blood  \
# 0       0.500000  ... -0.384865  0.156704 -0.116497 -0.000084     0.156704
# 1       0.500000  ... -0.384865  0.156704 -0.116497 -0.000084     0.156704
# 2       0.500000  ... -0.384865  0.156704 -0.116497 -0.000084     0.156704
# 3       0.500000  ... -0.384865  0.156704 -0.116497 -0.000084     0.156704
# 4       0.500000  ... -0.384865  0.156704 -0.116497 -0.000084     0.156704
# ...          ...  ...       ...       ...       ...       ...          ...
# 31601   0.500000  ...  0.081368  0.003594  0.001167  0.017122    -0.009282
# 31602   0.500000  ...  0.028248 -0.005509  0.010463  0.011462    -0.117839
# 31603   0.666667  ... -0.004742  0.001020  0.020353  0.000293    -0.058430
# 31604   0.500000  ...  0.003540  0.004995  0.013714  0.010458    -0.085454
# 31605   0.500000  ... -0.002404 -0.009181 -0.009017 -0.008740    -0.127211
#
#        dext_down   dext_up  dext_down_reversed dext_bins_down dext_bins_up
# 0      -0.426334  0.156704            0.426334      0.4 - 0.5    0.1 - 0.2
# 1      -0.426334  0.156704            0.426334      0.4 - 0.5    0.1 - 0.2
# 2      -0.426334  0.156704            0.426334      0.4 - 0.5    0.1 - 0.2
# 3      -0.426334  0.156704            0.426334      0.4 - 0.5    0.1 - 0.2
# 4      -0.426334  0.156704            0.426334      0.4 - 0.5    0.1 - 0.2
# ...          ...       ...                 ...            ...          ...
# 31601  -0.084878  0.149057            0.084878      0.0 - 0.1    0.1 - 0.2
# 31602  -0.117839  0.213527            0.117839      0.1 - 0.2    0.2 - 0.3
# 31603  -0.101818  0.109739            0.101818      0.1 - 0.2    0.1 - 0.2
# 31604  -0.126634  0.115016            0.126634      0.1 - 0.2    0.1 - 0.2
# 31605  -0.127211  0.099984            0.127211      0.1 - 0.2    0.0 - 0.1
#
# [31606 rows x 80 columns]

# %%
dext = pd.read_parquet(yaml['4_DEXT']['Final']['dext'])

bins = [round(e, 2) for e in list(np.arange(0,1.1,0.1))]
labels = convert_bins_into_labels(bins)

dext['dext_down_reversed'] = dext['dext_down'] * (- 1)
dext['dext_bins_down'] = pd.cut(dext['dext_down_reversed'], bins=bins, labels=labels)
dext['dext_bins_up'] = pd.cut(dext['dext_up'], bins=bins, labels=labels)
dext['dext_tissues_up'] = dext[dicts['GTEx_tissues_list'] + ['dext_up']].progress_apply(lambda r: [dicts['GTEx_tissues_list'][j] for j, e in enumerate(r) if e == r['dext_up'] and j < len(dicts['GTEx_tissues_list']) - 1], axis=1)
dext['dext_tissues_down'] = dext[dicts['GTEx_tissues_list'] + ['dext_down']].progress_apply(lambda r: [dicts['GTEx_tissues_list'][j] for j, e in enumerate(r) if e == r['dext_down'] and j < len(dicts['GTEx_tissues_list']) - 1], axis=1)


cutoff_down = dext['dext_down_reversed'].quantile(0.95)
cutoff_up = dext['dext_up'].quantile(0.95)

dext.loc[(dext['dext_down_reversed'] >= cutoff_down) | (dext['dext_up'] >= cutoff_up)]

# dext
# Out:
# 100%|██████████| 31606/31606 [00:09<00:00, 3401.23it/s]
# 100%|██████████| 31606/31606 [00:09<00:00, 3414.92it/s]
#          Gene               ranges              mRNA_exons  mRNA_nb  Share  \
# 61      ABCB9  123425354-123425542  [NM_019625, NM_019624]        2  False
# 67      ABCC3    48745224-48745370             [NM_003786]        1  False
# 68      ABCC3    48745791-48745878             [NM_003786]        1  False
# 69      ABCC3    48746214-48746280             [NM_003786]        1  False
# 70      ABCC3    48746501-48746627             [NM_003786]        1  False
# ...       ...                  ...                     ...      ...    ...
# 31592  ZWILCH    66801179-66801230             [NM_017975]        1  False
# 31593  ZWILCH    66806326-66806421             [NM_017975]        1  False
# 31594  ZWILCH    66807864-66807982             [NM_017975]        1  False
# 31596   ZWINT    58118448-58118485  [NM_007057, NM_032997]        2   True
# 31597   ZWINT    58118566-58118670          [NM_001005413]        1   True
#
#        Strand                             mRNA_gene  mRNA_nb_total Ratio  \
# 61          0  [NM_001243013, NM_019625, NM_019624]              3   2/3
# 67          1             [NM_003786, NM_001144070]              2   1/2
# 68          1             [NM_003786, NM_001144070]              2   1/2
# 69          1             [NM_003786, NM_001144070]              2   1/2
# 70          1             [NM_003786, NM_001144070]              2   1/2
# ...       ...                                   ...            ...   ...
# 31592       1             [NM_017975, NM_001287821]              2   1/2
# 31593       1             [NM_017975, NM_001287821]              2   1/2
# 31594       1             [NM_017975, NM_001287821]              2   1/2
# 31596       0  [NM_007057, NM_032997, NM_001005413]              3   2/3
# 31597       0  [NM_007057, NM_032997, NM_001005413]              3   1/3
#
#        Ratio_num  ...    Uterus    Vagina Whole Blood dext_down   dext_up  \
# 61      0.666667  ...  0.000528 -0.003483   -0.949628 -0.949628  0.179332
# 67      0.500000  ... -0.000122 -0.001795    0.757613 -0.051745  0.757613
# 68      0.500000  ... -0.000122 -0.001795    0.757613 -0.051745  0.757613
# 69      0.500000  ... -0.000122 -0.001795    0.757613 -0.051745  0.757613
# 70      0.500000  ... -0.000122 -0.001795    0.757613 -0.051745  0.757613
# ...          ...  ...       ...       ...         ...       ...       ...
# 31592   0.500000  ... -0.030492  0.000018    0.695758 -0.222942  0.695758
# 31593   0.500000  ... -0.030492  0.000018    0.695758 -0.222942  0.695758
# 31594   0.500000  ... -0.030492  0.000018    0.695758 -0.222942  0.695758
# 31596   0.666667  ... -0.001654  0.002159    0.327792 -0.782071  0.327792
# 31597   0.333333  ... -0.001299  0.002105    0.326503 -0.776965  0.326503
#
#        dext_down_reversed  dext_bins_down  dext_bins_up dext_tissues_up  \
# 61               0.949628       0.9 - 1.0     0.1 - 0.2         [Liver]
# 67               0.051745       0.0 - 0.1     0.7 - 0.8              []
# 68               0.051745       0.0 - 0.1     0.7 - 0.8              []
# 69               0.051745       0.0 - 0.1     0.7 - 0.8              []
# 70               0.051745       0.0 - 0.1     0.7 - 0.8              []
# ...                   ...             ...           ...             ...
# 31592            0.222942       0.2 - 0.3     0.6 - 0.7      [Pancreas]
# 31593            0.222942       0.2 - 0.3     0.6 - 0.7      [Pancreas]
# 31594            0.222942       0.2 - 0.3     0.6 - 0.7      [Pancreas]
# 31596            0.782071       0.7 - 0.8     0.3 - 0.4              []
# 31597            0.776965       0.7 - 0.8     0.3 - 0.4              []
#
#                                        dext_tissues_down
# 61                                                    []
# 67     [Brain - Amygdala, Brain - Anterior cingulate ...
# 68     [Brain - Amygdala, Brain - Anterior cingulate ...
# 69     [Brain - Amygdala, Brain - Anterior cingulate ...
# 70     [Brain - Amygdala, Brain - Anterior cingulate ...
# ...                                                  ...
# 31592                    [Brain - Cerebellar Hemisphere]
# 31593                    [Brain - Cerebellar Hemisphere]
# 31594                    [Brain - Cerebellar Hemisphere]
# 31596                               [Brain - Cerebellum]
# 31597                               [Brain - Cerebellum]
#
# [3157 rows x 82 columns]

# %%
dext.loc[(dext['dext_down_reversed'] >= cutoff_down), 'Down'] = True
dext.loc[(dext['dext_up'] >= cutoff_up), 'Up'] = True
dext.loc[(dext['dext_up'] >= cutoff_up) & (dext['dext_down_reversed'] >= cutoff_down), ['Down', 'Up']] = True
dext[['Down', 'Up']] = dext[['Down', 'Up']].fillna(False)

dext.loc[(dext['Down'] == True) | (dext['Up'] == True)]['Gene'].nunique()
dext[['Down', 'Up', 'ranges']].groupby(['Down', 'Up'])['ranges'].count()
# Out:
# Down   Up
# False  False    28449
#        True      1578
# True   False     1579
# Name: ranges, dtype: int64

# %%
gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors']).set_index('Tissue')
# gtex_colors['Color'].to_dict()

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors']).set_index('Tissue')


output_path = yaml['4_DEXT']['Figures_data']['dext_stats_complete']

up = dext[['dext_tissues_up', 'dext_bins_up']].explode('dext_tissues_up').groupby('dext_tissues_up')['dext_bins_up'].value_counts()
up.name = 'Up'
up = up.reset_index().sort_values(by=['dext_tissues_up', 'dext_bins_up'])
up.columns = ['Tissue', 'dext bins (up)', 'values']
up = up.pivot(columns='dext bins (up)', index='Tissue', values='values').fillna(0).astype(int)


down = dext[['dext_tissues_down', 'dext_bins_down']].explode('dext_tissues_down').groupby('dext_tissues_down')['dext_bins_down'].value_counts()
down.name = 'Down'
down = down.reset_index().sort_values(by=['dext_tissues_down', 'dext_bins_down'])
down.columns = ['Tissue', 'dext bins (down)', 'values']
down = down.pivot(columns='dext bins (down)', index='Tissue', values='values').fillna(0).astype(int)

concat_up_down_stats = pd.concat([up, down], axis=1)

concat_up_down_stats.columns = pd.MultiIndex.from_product([['dext-up','| dext-down |'], list(up.columns)])
# concat_up_down_stats = concat_up_down_stats[['Square'] + [c for c in concat_up_down_stats.columns if c != 'Square']]

writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
concat_up_down_stats.to_excel(writer, sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']

my_formats = gtex_colors['Color'].to_dict()
my_formats = {'"{}"'.format(k):v for k,v in my_formats.items()}

for val, color in my_formats.items():
    fmt = workbook.add_format({'font_color': color})
    worksheet.conditional_format('A3:A55', {'type': 'cell',
                                           'criteria': '=',
                                           'value': val,
                                           'format': fmt})
writer.save()
# concat_up_down_stats['Square'] = concat_up_down_stats['Square'].apply(lambda r: r.split('_')[1])


concat_up_down_stats
# Out:
#                                             dext-up                      \
#                                           0.0 - 0.1 0.1 - 0.2 0.2 - 0.3
# Tissue
# Adipose - Subcutaneous                          283        57        43
# Adipose - Visceral (Omentum)                    262        43        28
# Adrenal Gland                                   447       180        59
# Artery - Aorta                                  435       156       112
# Artery - Coronary                               226        52        16
# Artery - Tibial                                 495       367       150
# Bladder                                         368       283        97
# Brain - Amygdala                                790       356       215
# Brain - Anterior cingulate cortex (BA24)        619       273        88
# Brain - Caudate (basal ganglia)                 484       121        40
# Brain - Cerebellar Hemisphere                   891       412       334
# Brain - Cerebellum                              672       249       110
# Brain - Cortex                                  546       122        51
# Brain - Frontal Cortex (BA9)                    769       469       245
# Brain - Hippocampus                             668       145        66
# Brain - Hypothalamus                            451       123        65
# Brain - Nucleus accumbens (basal ganglia)       623       192        91
# Brain - Putamen (basal ganglia)                 704       319       141
# Brain - Spinal cord (cervical c-1)              591       166       101
# Brain - Substantia nigra                        638       177        69
# Breast - Mammary Tissue                         148        34         4
# Cells - Cultured fibroblasts                    984      1243      1061
# Cells - EBV-transformed lymphocytes             852       639       537
# Cervix - Ectocervix                             377       121        96
# Cervix - Endocervix                             387       169        61
# Colon - Sigmoid                                 308        71        15
# Colon - Transverse                              256        47        39
# Esophagus - Gastroesophageal Junction           279        54        42
# Esophagus - Mucosa                              469        72        59
# Esophagus - Muscularis                          371       147        74
# Fallopian Tube                                  346       129        62
# Heart - Atrial Appendage                        373        84        48
# Heart - Left Ventricle                          831       308       166
# Kidney - Cortex                                 388        95        77
# Liver                                           897       388       225
# Lung                                            199        63        46
# Minor Salivary Gland                            209        23        29
# Muscle - Skeletal                              1368      1198       794
# Nerve - Tibial                                  209        43        18
# Ovary                                           370        66        26
# Pancreas                                        784       216       133
# Pituitary                                       225        53        30
# Prostate                                        164        25        37
# Skin - Not Sun Exposed (Suprapubic)             270        67        58
# Skin - Sun Exposed (Lower leg)                  380        68        87
# Small Intestine - Terminal Ileum                233        51        44
# Spleen                                          500        95        87
# Stomach                                         413        78        45
# Testis                                          402       342       284
# Thyroid                                         173        41        58
# Uterus                                          225        45        16
# Vagina                                          155        23        38
#
#                                                                          \
#                                           0.3 - 0.4 0.4 - 0.5 0.5 - 0.6
# Tissue
# Adipose - Subcutaneous                            6         3         1
# Adipose - Visceral (Omentum)                     14        12         1
# Adrenal Gland                                    13        17         5
# Artery - Aorta                                    9        18         6
# Artery - Coronary                                12         3         5
# Artery - Tibial                                  26        22         4
# Bladder                                          30        39        19
# Brain - Amygdala                                 88        15        16
# Brain - Anterior cingulate cortex (BA24)         48         9        18
# Brain - Caudate (basal ganglia)                  23         7        14
# Brain - Cerebellar Hemisphere                   167       160        90
# Brain - Cerebellum                               57        31        29
# Brain - Cortex                                   23        26        20
# Brain - Frontal Cortex (BA9)                    116        58        72
# Brain - Hippocampus                              32        56         9
# Brain - Hypothalamus                             21         7         8
# Brain - Nucleus accumbens (basal ganglia)        73        14        19
# Brain - Putamen (basal ganglia)                  49        48        17
# Brain - Spinal cord (cervical c-1)               63        43        13
# Brain - Substantia nigra                         17         8        12
# Breast - Mammary Tissue                           3         1         1
# Cells - Cultured fibroblasts                    770       445       251
# Cells - EBV-transformed lymphocytes             334       271       110
# Cervix - Ectocervix                              31         8         7
# Cervix - Endocervix                              21        23        18
# Colon - Sigmoid                                   5         2         8
# Colon - Transverse                                7         3         1
# Esophagus - Gastroesophageal Junction             6         5         4
# Esophagus - Mucosa                               36        34        23
# Esophagus - Muscularis                            5         9         9
# Fallopian Tube                                   13        16        14
# Heart - Atrial Appendage                         32         8         4
# Heart - Left Ventricle                           43        21         8
# Kidney - Cortex                                  13         8         1
# Liver                                            76        48        27
# Lung                                              7         2         0
# Minor Salivary Gland                             20         6        10
# Muscle - Skeletal                               542       288       143
# Nerve - Tibial                                    9         6         2
# Ovary                                             6         3         3
# Pancreas                                         71        22        12
# Pituitary                                        12         3         0
# Prostate                                          1         4         3
# Skin - Not Sun Exposed (Suprapubic)              10         8         6
# Skin - Sun Exposed (Lower leg)                   10         8         7
# Small Intestine - Terminal Ileum                  6        10        16
# Spleen                                           10        45         8
# Stomach                                           9        11         0
# Testis                                          292       170       134
# Thyroid                                           6         6         4
# Uterus                                            8         6         4
# Vagina                                            1         1         0
#
#                                                                          \
#                                           0.6 - 0.7 0.7 - 0.8 0.8 - 0.9
# Tissue
# Adipose - Subcutaneous                           24         0         1
# Adipose - Visceral (Omentum)                      3         0         1
# Adrenal Gland                                     3         3         4
# Artery - Aorta                                   24         1         3
# Artery - Coronary                                18         0         2
# Artery - Tibial                                  38         1         8
# Bladder                                           6         9         7
# Brain - Amygdala                                 12         0         0
# Brain - Anterior cingulate cortex (BA24)          2        22         0
# Brain - Caudate (basal ganglia)                   1         2         6
# Brain - Cerebellar Hemisphere                    77        99        38
# Brain - Cerebellum                               26        44         1
# Brain - Cortex                                   10         3         0
# Brain - Frontal Cortex (BA9)                     30        25         2
# Brain - Hippocampus                              17         3         0
# Brain - Hypothalamus                              2         0         0
# Brain - Nucleus accumbens (basal ganglia)         4         1         4
# Brain - Putamen (basal ganglia)                   4         2         0
# Brain - Spinal cord (cervical c-1)               10         7         0
# Brain - Substantia nigra                          5         1         1
# Breast - Mammary Tissue                           1         0         0
# Cells - Cultured fibroblasts                    116       164        32
# Cells - EBV-transformed lymphocytes              93        64        86
# Cervix - Ectocervix                              13         5        11
# Cervix - Endocervix                              17         5         8
# Colon - Sigmoid                                   1         2         0
# Colon - Transverse                                4         4         1
# Esophagus - Gastroesophageal Junction             9         4         3
# Esophagus - Mucosa                                6         2         2
# Esophagus - Muscularis                            4         4         3
# Fallopian Tube                                    5         3         9
# Heart - Atrial Appendage                         10         2         4
# Heart - Left Ventricle                           13        14         4
# Kidney - Cortex                                   3         6         2
# Liver                                            35        19         6
# Lung                                              3         0         2
# Minor Salivary Gland                              2         0         0
# Muscle - Skeletal                                83        80        56
# Nerve - Tibial                                    1        13         1
# Ovary                                             6         2         3
# Pancreas                                         13         6        10
# Pituitary                                         2         0         0
# Prostate                                          1         0         0
# Skin - Not Sun Exposed (Suprapubic)               4         4         2
# Skin - Sun Exposed (Lower leg)                    5         2         1
# Small Intestine - Terminal Ileum                  3         3        18
# Spleen                                            2         2        11
# Stomach                                           0         1         3
# Testis                                           90       104        92
# Thyroid                                           4         1         0
# Uterus                                            5         2         4
# Vagina                                            0         0         0
#
#                                                     | dext-down |            \
#                                           0.9 - 1.0     0.0 - 0.1 0.1 - 0.2
# Tissue
# Adipose - Subcutaneous                            3           287        70
# Adipose - Visceral (Omentum)                      0           261        69
# Adrenal Gland                                     0           345        91
# Artery - Aorta                                    3           347       101
# Artery - Coronary                                 1           191        40
# Artery - Tibial                                   3           409       126
# Bladder                                           2           353       161
# Brain - Amygdala                                  1           552       138
# Brain - Anterior cingulate cortex (BA24)          1           460       144
# Brain - Caudate (basal ganglia)                   0           406        55
# Brain - Cerebellar Hemisphere                     1           839       411
# Brain - Cerebellum                                1           829       762
# Brain - Cortex                                    0           452       111
# Brain - Frontal Cortex (BA9)                      1           503       167
# Brain - Hippocampus                               0           543       155
# Brain - Hypothalamus                              0           392        74
# Brain - Nucleus accumbens (basal ganglia)         0           482       142
# Brain - Putamen (basal ganglia)                   0           551       242
# Brain - Spinal cord (cervical c-1)                2           466       176
# Brain - Substantia nigra                          1           495       206
# Breast - Mammary Tissue                           0           180        23
# Cells - Cultured fibroblasts                     49           920       550
# Cells - EBV-transformed lymphocytes              45          1311       613
# Cervix - Ectocervix                               8           421       171
# Cervix - Endocervix                              12           457       202
# Colon - Sigmoid                                   0           285        72
# Colon - Transverse                                5           199        59
# Esophagus - Gastroesophageal Junction             1           247        51
# Esophagus - Mucosa                                0           400        87
# Esophagus - Muscularis                            0           288        57
# Fallopian Tube                                    8           371       144
# Heart - Atrial Appendage                          1           402       117
# Heart - Left Ventricle                            6           707       219
# Kidney - Cortex                                   2           445        81
# Liver                                            17          1507      1024
# Lung                                              8           317        66
# Minor Salivary Gland                              0           291        53
# Muscle - Skeletal                               131           914       400
# Nerve - Tibial                                    5           398       208
# Ovary                                             1           618       244
# Pancreas                                          6           897       225
# Pituitary                                         0           465       205
# Prostate                                          0           232        73
# Skin - Not Sun Exposed (Suprapubic)               0           481       170
# Skin - Sun Exposed (Lower leg)                    0           505       213
# Small Intestine - Terminal Ileum                  2           253        64
# Spleen                                            7           713       271
# Stomach                                           0           327        59
# Testis                                           50           735       644
# Thyroid                                           0           300        79
# Uterus                                            5           284        75
# Vagina                                            0           251        52
#
#                                                                          \
#                                           0.2 - 0.3 0.3 - 0.4 0.4 - 0.5
# Tissue
# Adipose - Subcutaneous                          130        15         4
# Adipose - Visceral (Omentum)                     35         8         2
# Adrenal Gland                                    65        25         8
# Artery - Aorta                                   42        32         9
# Artery - Coronary                                29        14         1
# Artery - Tibial                                 123        19         9
# Bladder                                         126        45        12
# Brain - Amygdala                                 97        57        12
# Brain - Anterior cingulate cortex (BA24)         52        46        14
# Brain - Caudate (basal ganglia)                  51        23         2
# Brain - Cerebellar Hemisphere                   216       178       129
# Brain - Cerebellum                              533       303       114
# Brain - Cortex                                   53        26        19
# Brain - Frontal Cortex (BA9)                     93        60        64
# Brain - Hippocampus                              49        41        10
# Brain - Hypothalamus                             58        11         6
# Brain - Nucleus accumbens (basal ganglia)        66        42         8
# Brain - Putamen (basal ganglia)                 171        84        13
# Brain - Spinal cord (cervical c-1)               89        67        36
# Brain - Substantia nigra                         76        28        19
# Breast - Mammary Tissue                          28        12         2
# Cells - Cultured fibroblasts                    399       253       114
# Cells - EBV-transformed lymphocytes             452       334       141
# Cervix - Ectocervix                              58        81        15
# Cervix - Endocervix                             116        88        16
# Colon - Sigmoid                                  94        15         2
# Colon - Transverse                               90        13         4
# Esophagus - Gastroesophageal Junction            86        24        14
# Esophagus - Mucosa                               99        25        16
# Esophagus - Muscularis                           97        15         1
# Fallopian Tube                                   42        46        35
# Heart - Atrial Appendage                         84        12         3
# Heart - Left Ventricle                          109        65        37
# Kidney - Cortex                                  42        42        13
# Liver                                           520       207       119
# Lung                                             24        15         7
# Minor Salivary Gland                             36        18         7
# Muscle - Skeletal                               266       148        74
# Nerve - Tibial                                   62        29        11
# Ovary                                            66        27        18
# Pancreas                                        179        33        24
# Pituitary                                        89        44        10
# Prostate                                         38        10         4
# Skin - Not Sun Exposed (Suprapubic)              98        29        13
# Skin - Sun Exposed (Lower leg)                  136        18        14
# Small Intestine - Terminal Ileum                 31         5         5
# Spleen                                          137        64        23
# Stomach                                          89        15         3
# Testis                                          573       462       424
# Thyroid                                          21        25         6
# Uterus                                           33        10         6
# Vagina                                           14        27         4
#
#                                                                          \
#                                           0.5 - 0.6 0.6 - 0.7 0.7 - 0.8
# Tissue
# Adipose - Subcutaneous                           13         2         9
# Adipose - Visceral (Omentum)                      2         6         0
# Adrenal Gland                                    13         9         0
# Artery - Aorta                                    7        14         2
# Artery - Coronary                                 1         1         4
# Artery - Tibial                                   8         7         6
# Bladder                                           7         4         4
# Brain - Amygdala                                  6         4         8
# Brain - Anterior cingulate cortex (BA24)          7         2         8
# Brain - Caudate (basal ganglia)                   7         4         6
# Brain - Cerebellar Hemisphere                    91        34        26
# Brain - Cerebellum                               76        29        25
# Brain - Cortex                                   11         0         3
# Brain - Frontal Cortex (BA9)                     26       165         4
# Brain - Hippocampus                               3         4         7
# Brain - Hypothalamus                              1         0         3
# Brain - Nucleus accumbens (basal ganglia)         4         2         4
# Brain - Putamen (basal ganglia)                  18         5         8
# Brain - Spinal cord (cervical c-1)               16        15        21
# Brain - Substantia nigra                          4         3         4
# Breast - Mammary Tissue                           2         1         1
# Cells - Cultured fibroblasts                     94        59        42
# Cells - EBV-transformed lymphocytes             224        85        88
# Cervix - Ectocervix                               9         6        15
# Cervix - Endocervix                              19        14         7
# Colon - Sigmoid                                   2         1         0
# Colon - Transverse                                4         1         4
# Esophagus - Gastroesophageal Junction             2         3         3
# Esophagus - Mucosa                               18        14         2
# Esophagus - Muscularis                            2         2         3
# Fallopian Tube                                   11        12         7
# Heart - Atrial Appendage                         10         5         4
# Heart - Left Ventricle                           42        19        13
# Kidney - Cortex                                  15        11        13
# Liver                                           110        39        33
# Lung                                              3        10         3
# Minor Salivary Gland                              7         3         2
# Muscle - Skeletal                                90        37        35
# Nerve - Tibial                                    7         6        13
# Ovary                                            14         7        20
# Pancreas                                         30        17        11
# Pituitary                                        16         3         5
# Prostate                                          6         0         0
# Skin - Not Sun Exposed (Suprapubic)               8         2        12
# Skin - Sun Exposed (Lower leg)                    6         6        12
# Small Intestine - Terminal Ileum                 11         9         0
# Spleen                                           16        19         5
# Stomach                                          10         3         0
# Testis                                          282       224       251
# Thyroid                                           4         1         9
# Uterus                                            5         4         2
# Vagina                                            1         1         0
#
#
#                                           0.8 - 0.9 0.9 - 1.0
# Tissue
# Adipose - Subcutaneous                            0         4
# Adipose - Visceral (Omentum)                      0         4
# Adrenal Gland                                     0         0
# Artery - Aorta                                    3         0
# Artery - Coronary                                 1         0
# Artery - Tibial                                   3         5
# Bladder                                          10         1
# Brain - Amygdala                                  1         3
# Brain - Anterior cingulate cortex (BA24)          1         0
# Brain - Caudate (basal ganglia)                   1         0
# Brain - Cerebellar Hemisphere                    12         2
# Brain - Cerebellum                                9        11
# Brain - Cortex                                    2         0
# Brain - Frontal Cortex (BA9)                      1         0
# Brain - Hippocampus                               1         0
# Brain - Hypothalamus                              1         0
# Brain - Nucleus accumbens (basal ganglia)         1         0
# Brain - Putamen (basal ganglia)                   5         0
# Brain - Spinal cord (cervical c-1)                3         4
# Brain - Substantia nigra                          2         0
# Breast - Mammary Tissue                           0         0
# Cells - Cultured fibroblasts                     29        20
# Cells - EBV-transformed lymphocytes              85       154
# Cervix - Ectocervix                               9         4
# Cervix - Endocervix                              10        15
# Colon - Sigmoid                                   1         0
# Colon - Transverse                                0         0
# Esophagus - Gastroesophageal Junction             1         0
# Esophagus - Mucosa                                3         0
# Esophagus - Muscularis                            1         0
# Fallopian Tube                                    8        17
# Heart - Atrial Appendage                          5         0
# Heart - Left Ventricle                            7         9
# Kidney - Cortex                                   1         0
# Liver                                            25         9
# Lung                                              0         4
# Minor Salivary Gland                              0         0
# Muscle - Skeletal                                28        38
# Nerve - Tibial                                    3         1
# Ovary                                             8         1
# Pancreas                                          1         1
# Pituitary                                         3         6
# Prostate                                          0         2
# Skin - Not Sun Exposed (Suprapubic)               2         0
# Skin - Sun Exposed (Lower leg)                    3         0
# Small Intestine - Terminal Ileum                  3         0
# Spleen                                            8         5
# Stomach                                           1         0
# Testis                                          266       209
# Thyroid                                           3         0
# Uterus                                            0         5
# Vagina                                            0         0

# %%
up = dext[['dext_tissues_up', 'dext_bins_up', 'Gene']].explode('dext_tissues_up').groupby(['dext_tissues_up', 'dext_bins_up'])['Gene'].nunique()
up.name = 'Up'
up = pd.DataFrame(up).reset_index()
up.columns = ['Tissue', 'dext bins (up)', 'values']

up = pd.pivot(data=pd.DataFrame(up).reset_index(), index='Tissue', columns='dext bins (up)', values='values')
# up = up.sort_values(by=['Tissue', 'dext bins (up)'])
up
# Out:
# dext bins (up)                             0.0 - 0.1  0.1 - 0.2  0.2 - 0.3  \
# Tissue
# Adipose - Subcutaneous                           123         26         16
# Adipose - Visceral (Omentum)                     116         19          8
# Adrenal Gland                                    172         67         22
# Artery - Aorta                                   158         70         27
# Artery - Coronary                                 99         24         11
# Artery - Tibial                                  243        150         72
# Bladder                                          194        121         58
# Brain - Amygdala                                 372        167         84
# Brain - Anterior cingulate cortex (BA24)         269        115         51
# Brain - Caudate (basal ganglia)                  193         58         22
# Brain - Cerebellar Hemisphere                    354        219        130
# Brain - Cerebellum                               260        112         70
# Brain - Cortex                                   222         58         31
# Brain - Frontal Cortex (BA9)                     310        190        122
# Brain - Hippocampus                              276         70         36
# Brain - Hypothalamus                             198         64         33
# Brain - Nucleus accumbens (basal ganglia)        240         84         47
# Brain - Putamen (basal ganglia)                  282        126         80
# Brain - Spinal cord (cervical c-1)               251        106         59
# Brain - Substantia nigra                         250         80         40
# Breast - Mammary Tissue                           72         17          4
# Cells - Cultured fibroblasts                     479        494        436
# Cells - EBV-transformed lymphocytes              387        303        227
# Cervix - Ectocervix                              134         74         37
# Cervix - Endocervix                              210         94         48
# Colon - Sigmoid                                  130         32         13
# Colon - Transverse                               112         19          9
# Esophagus - Gastroesophageal Junction            111         28         11
# Esophagus - Mucosa                               198         47         33
# Esophagus - Muscularis                           148         45         16
# Fallopian Tube                                   200         81         28
# Heart - Atrial Appendage                         152         51         25
# Heart - Left Ventricle                           380        137         65
# Kidney - Cortex                                  181         46         30
# Liver                                            408        181        104
# Lung                                              93         24         12
# Minor Salivary Gland                             110         19         12
# Muscle - Skeletal                                662        511        334
# Nerve - Tibial                                   105         31         10
# Ovary                                            158         45         20
# Pancreas                                         347        116         61
# Pituitary                                        118         41         17
# Prostate                                          86         20          6
# Skin - Not Sun Exposed (Suprapubic)              140         36         14
# Skin - Sun Exposed (Lower leg)                   187         49         27
# Small Intestine - Terminal Ileum                 114         27         12
# Spleen                                           195         48         37
# Stomach                                          157         33         13
# Testis                                           261        221        169
# Thyroid                                           80         23         15
# Uterus                                            93         27         13
# Vagina                                            80         16          7
#
# dext bins (up)                             0.3 - 0.4  0.4 - 0.5  0.5 - 0.6  \
# Tissue
# Adipose - Subcutaneous                             6          3          1
# Adipose - Visceral (Omentum)                       9          5          1
# Adrenal Gland                                      9          6          4
# Artery - Aorta                                     6         11          6
# Artery - Coronary                                  9          3          4
# Artery - Tibial                                   14         13          4
# Bladder                                           20         18         15
# Brain - Amygdala                                  39         10          9
# Brain - Anterior cingulate cortex (BA24)          25          7          7
# Brain - Caudate (basal ganglia)                   13          5          4
# Brain - Cerebellar Hemisphere                     94         91         56
# Brain - Cerebellum                                32         21         19
# Brain - Cortex                                    13         11          7
# Brain - Frontal Cortex (BA9)                      62         36         30
# Brain - Hippocampus                               18         14          3
# Brain - Hypothalamus                              13          5          3
# Brain - Nucleus accumbens (basal ganglia)         27         12          8
# Brain - Putamen (basal ganglia)                   26         20          7
# Brain - Spinal cord (cervical c-1)                34         23          9
# Brain - Substantia nigra                          12          8          7
# Breast - Mammary Tissue                            3          1          1
# Cells - Cultured fibroblasts                     235        142         85
# Cells - EBV-transformed lymphocytes              131        108         62
# Cervix - Ectocervix                               15          8          7
# Cervix - Endocervix                               16         18         15
# Colon - Sigmoid                                    5          2          3
# Colon - Transverse                                 4          3          1
# Esophagus - Gastroesophageal Junction              6          4          4
# Esophagus - Mucosa                                14         12         11
# Esophagus - Muscularis                             4          7          5
# Fallopian Tube                                    10          9         10
# Heart - Atrial Appendage                           8          8          3
# Heart - Left Ventricle                            24         15          7
# Kidney - Cortex                                    9          6          1
# Liver                                             46         32         18
# Lung                                               6          2          0
# Minor Salivary Gland                              14          4          4
# Muscle - Skeletal                                242        117         62
# Nerve - Tibial                                     7          6          1
# Ovary                                              6          3          3
# Pancreas                                          33         19         11
# Pituitary                                         10          3          0
# Prostate                                           1          4          2
# Skin - Not Sun Exposed (Suprapubic)                8          8          3
# Skin - Sun Exposed (Lower leg)                     9          7          5
# Small Intestine - Terminal Ileum                   6          5          6
# Spleen                                             6          7          7
# Stomach                                            6          6          0
# Testis                                           122         71         76
# Thyroid                                            5          6          4
# Uterus                                             4          1          4
# Vagina                                             1          1          0
#
# dext bins (up)                             0.6 - 0.7  0.7 - 0.8  0.8 - 0.9  \
# Tissue
# Adipose - Subcutaneous                             5          0          1
# Adipose - Visceral (Omentum)                       1          0          1
# Adrenal Gland                                      2          2          3
# Artery - Aorta                                     5          1          2
# Artery - Coronary                                  1          0          2
# Artery - Tibial                                    8          1          4
# Bladder                                            5          5          4
# Brain - Amygdala                                   5          0          0
# Brain - Anterior cingulate cortex (BA24)           2          2          0
# Brain - Caudate (basal ganglia)                    1          2          2
# Brain - Cerebellar Hemisphere                     38         38         15
# Brain - Cerebellum                                 9          4          1
# Brain - Cortex                                     5          2          0
# Brain - Frontal Cortex (BA9)                      22          4          2
# Brain - Hippocampus                                3          2          0
# Brain - Hypothalamus                               2          0          0
# Brain - Nucleus accumbens (basal ganglia)          3          1          2
# Brain - Putamen (basal ganglia)                    4          1          0
# Brain - Spinal cord (cervical c-1)                 6          6          0
# Brain - Substantia nigra                           5          1          1
# Breast - Mammary Tissue                            1          0          0
# Cells - Cultured fibroblasts                      49         32         20
# Cells - EBV-transformed lymphocytes               45         46         23
# Cervix - Ectocervix                                6          4          7
# Cervix - Endocervix                                8          3          7
# Colon - Sigmoid                                    1          1          0
# Colon - Transverse                                 4          3          1
# Esophagus - Gastroesophageal Junction              2          2          2
# Esophagus - Mucosa                                 4          2          2
# Esophagus - Muscularis                             2          2          2
# Fallopian Tube                                     2          3          5
# Heart - Atrial Appendage                           3          2          3
# Heart - Left Ventricle                             7         10          3
# Kidney - Cortex                                    3          3          1
# Liver                                             15          9          6
# Lung                                               1          0          2
# Minor Salivary Gland                               2          0          0
# Muscle - Skeletal                                 52         40         35
# Nerve - Tibial                                     1          2          1
# Ovary                                              3          1          3
# Pancreas                                           6          4          6
# Pituitary                                          2          0          0
# Prostate                                           1          0          0
# Skin - Not Sun Exposed (Suprapubic)                1          2          2
# Skin - Sun Exposed (Lower leg)                     2          2          1
# Small Intestine - Terminal Ileum                   3          2          2
# Spleen                                             2          2          7
# Stomach                                            0          1          2
# Testis                                            63         61         49
# Thyroid                                            2          1          0
# Uterus                                             4          1          4
# Vagina                                             0          0          0
#
# dext bins (up)                             0.9 - 1.0
# Tissue
# Adipose - Subcutaneous                             1
# Adipose - Visceral (Omentum)                       0
# Adrenal Gland                                      0
# Artery - Aorta                                     2
# Artery - Coronary                                  1
# Artery - Tibial                                    2
# Bladder                                            1
# Brain - Amygdala                                   1
# Brain - Anterior cingulate cortex (BA24)           1
# Brain - Caudate (basal ganglia)                    0
# Brain - Cerebellar Hemisphere                      1
# Brain - Cerebellum                                 1
# Brain - Cortex                                     0
# Brain - Frontal Cortex (BA9)                       1
# Brain - Hippocampus                                0
# Brain - Hypothalamus                               0
# Brain - Nucleus accumbens (basal ganglia)          0
# Brain - Putamen (basal ganglia)                    0
# Brain - Spinal cord (cervical c-1)                 2
# Brain - Substantia nigra                           1
# Breast - Mammary Tissue                            0
# Cells - Cultured fibroblasts                      15
# Cells - EBV-transformed lymphocytes               22
# Cervix - Ectocervix                                6
# Cervix - Endocervix                                8
# Colon - Sigmoid                                    0
# Colon - Transverse                                 1
# Esophagus - Gastroesophageal Junction              1
# Esophagus - Mucosa                                 0
# Esophagus - Muscularis                             0
# Fallopian Tube                                     6
# Heart - Atrial Appendage                           1
# Heart - Left Ventricle                             6
# Kidney - Cortex                                    1
# Liver                                              5
# Lung                                               2
# Minor Salivary Gland                               0
# Muscle - Skeletal                                 29
# Nerve - Tibial                                     2
# Ovary                                              1
# Pancreas                                           1
# Pituitary                                          0
# Prostate                                           0
# Skin - Not Sun Exposed (Suprapubic)                0
# Skin - Sun Exposed (Lower leg)                     0
# Small Intestine - Terminal Ileum                   1
# Spleen                                             2
# Stomach                                            0
# Testis                                            35
# Thyroid                                            0
# Uterus                                             3
# Vagina                                             0

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors']).set_index('Tissue')

output_path = yaml['4_DEXT']['Figures_data']['dext_stats_complete_genes']


up = dext[['dext_tissues_up', 'dext_bins_up', 'Gene']].explode('dext_tissues_up').groupby(['dext_tissues_up', 'dext_bins_up'])['Gene'].nunique()
up.name = 'Up'
up = pd.DataFrame(up).reset_index()
up.columns = ['Tissue', 'dext bins (up)', 'values']
up = pd.pivot(data=pd.DataFrame(up).reset_index(), index='Tissue', columns='dext bins (up)', values='values')


down = dext[['dext_tissues_down', 'dext_bins_down', 'Gene']].explode('dext_tissues_down').groupby(['dext_tissues_down', 'dext_bins_down'])['Gene'].nunique()
down.name = 'Down'
down = pd.DataFrame(up).reset_index()
down.columns = ['Tissue', 'dext bins (down)', 'values']
down = pd.pivot(data=pd.DataFrame(down).reset_index(), index='Tissue', columns='dext bins (down)', values='values')


concat_up_down_stats = pd.concat([up, down], axis=1)

concat_up_down_stats.columns = pd.MultiIndex.from_product([['dext-up','| dext-down |'], list(up.columns)])
# concat_up_down_stats = concat_up_down_stats[['Square'] + [c for c in concat_up_down_stats.columns if c != 'Square']]

writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
concat_up_down_stats.to_excel(writer, sheet_name='Sheet1')

workbook = writer.book
worksheet = writer.sheets['Sheet1']

my_formats = gtex_colors['Color'].to_dict()
my_formats = {'"{}"'.format(k):v for k,v in my_formats.items()}

for val, color in my_formats.items():
    fmt = workbook.add_format({'font_color': color})
    worksheet.conditional_format('A3:A55', {'type': 'cell',
                                           'criteria': '=',
                                           'value': val,
                                           'format': fmt})
writer.save()
# concat_up_down_stats['Square'] = concat_up_down_stats['Square'].apply(lambda r: r.split('_')[1])


concat_up_down_stats
# Out:
#                                             dext-up                      \
#                                           0.0 - 0.1 0.1 - 0.2 0.2 - 0.3
# Tissue
# Adipose - Subcutaneous                          283        57        43
# Adipose - Visceral (Omentum)                    262        43        28
# Adrenal Gland                                   447       180        59
# Artery - Aorta                                  435       156       112
# Artery - Coronary                               226        52        16
# Artery - Tibial                                 495       367       150
# Bladder                                         368       283        97
# Brain - Amygdala                                790       356       215
# Brain - Anterior cingulate cortex (BA24)        619       273        88
# Brain - Caudate (basal ganglia)                 484       121        40
# Brain - Cerebellar Hemisphere                   891       412       334
# Brain - Cerebellum                              672       249       110
# Brain - Cortex                                  546       122        51
# Brain - Frontal Cortex (BA9)                    769       469       245
# Brain - Hippocampus                             668       145        66
# Brain - Hypothalamus                            451       123        65
# Brain - Nucleus accumbens (basal ganglia)       623       192        91
# Brain - Putamen (basal ganglia)                 704       319       141
# Brain - Spinal cord (cervical c-1)              591       166       101
# Brain - Substantia nigra                        638       177        69
# Breast - Mammary Tissue                         148        34         4
# Cells - Cultured fibroblasts                    984      1243      1061
# Cells - EBV-transformed lymphocytes             852       639       537
# Cervix - Ectocervix                             377       121        96
# Cervix - Endocervix                             387       169        61
# Colon - Sigmoid                                 308        71        15
# Colon - Transverse                              256        47        39
# Esophagus - Gastroesophageal Junction           279        54        42
# Esophagus - Mucosa                              469        72        59
# Esophagus - Muscularis                          371       147        74
# Fallopian Tube                                  346       129        62
# Heart - Atrial Appendage                        373        84        48
# Heart - Left Ventricle                          831       308       166
# Kidney - Cortex                                 388        95        77
# Liver                                           897       388       225
# Lung                                            199        63        46
# Minor Salivary Gland                            209        23        29
# Muscle - Skeletal                              1368      1198       794
# Nerve - Tibial                                  209        43        18
# Ovary                                           370        66        26
# Pancreas                                        784       216       133
# Pituitary                                       225        53        30
# Prostate                                        164        25        37
# Skin - Not Sun Exposed (Suprapubic)             270        67        58
# Skin - Sun Exposed (Lower leg)                  380        68        87
# Small Intestine - Terminal Ileum                233        51        44
# Spleen                                          500        95        87
# Stomach                                         413        78        45
# Testis                                          402       342       284
# Thyroid                                         173        41        58
# Uterus                                          225        45        16
# Vagina                                          155        23        38
#
#                                                                          \
#                                           0.3 - 0.4 0.4 - 0.5 0.5 - 0.6
# Tissue
# Adipose - Subcutaneous                            6         3         1
# Adipose - Visceral (Omentum)                     14        12         1
# Adrenal Gland                                    13        17         5
# Artery - Aorta                                    9        18         6
# Artery - Coronary                                12         3         5
# Artery - Tibial                                  26        22         4
# Bladder                                          30        39        19
# Brain - Amygdala                                 88        15        16
# Brain - Anterior cingulate cortex (BA24)         48         9        18
# Brain - Caudate (basal ganglia)                  23         7        14
# Brain - Cerebellar Hemisphere                   167       160        90
# Brain - Cerebellum                               57        31        29
# Brain - Cortex                                   23        26        20
# Brain - Frontal Cortex (BA9)                    116        58        72
# Brain - Hippocampus                              32        56         9
# Brain - Hypothalamus                             21         7         8
# Brain - Nucleus accumbens (basal ganglia)        73        14        19
# Brain - Putamen (basal ganglia)                  49        48        17
# Brain - Spinal cord (cervical c-1)               63        43        13
# Brain - Substantia nigra                         17         8        12
# Breast - Mammary Tissue                           3         1         1
# Cells - Cultured fibroblasts                    770       445       251
# Cells - EBV-transformed lymphocytes             334       271       110
# Cervix - Ectocervix                              31         8         7
# Cervix - Endocervix                              21        23        18
# Colon - Sigmoid                                   5         2         8
# Colon - Transverse                                7         3         1
# Esophagus - Gastroesophageal Junction             6         5         4
# Esophagus - Mucosa                               36        34        23
# Esophagus - Muscularis                            5         9         9
# Fallopian Tube                                   13        16        14
# Heart - Atrial Appendage                         32         8         4
# Heart - Left Ventricle                           43        21         8
# Kidney - Cortex                                  13         8         1
# Liver                                            76        48        27
# Lung                                              7         2         0
# Minor Salivary Gland                             20         6        10
# Muscle - Skeletal                               542       288       143
# Nerve - Tibial                                    9         6         2
# Ovary                                             6         3         3
# Pancreas                                         71        22        12
# Pituitary                                        12         3         0
# Prostate                                          1         4         3
# Skin - Not Sun Exposed (Suprapubic)              10         8         6
# Skin - Sun Exposed (Lower leg)                   10         8         7
# Small Intestine - Terminal Ileum                  6        10        16
# Spleen                                           10        45         8
# Stomach                                           9        11         0
# Testis                                          292       170       134
# Thyroid                                           6         6         4
# Uterus                                            8         6         4
# Vagina                                            1         1         0
#
#                                                                          \
#                                           0.6 - 0.7 0.7 - 0.8 0.8 - 0.9
# Tissue
# Adipose - Subcutaneous                           24         0         1
# Adipose - Visceral (Omentum)                      3         0         1
# Adrenal Gland                                     3         3         4
# Artery - Aorta                                   24         1         3
# Artery - Coronary                                18         0         2
# Artery - Tibial                                  38         1         8
# Bladder                                           6         9         7
# Brain - Amygdala                                 12         0         0
# Brain - Anterior cingulate cortex (BA24)          2        22         0
# Brain - Caudate (basal ganglia)                   1         2         6
# Brain - Cerebellar Hemisphere                    77        99        38
# Brain - Cerebellum                               26        44         1
# Brain - Cortex                                   10         3         0
# Brain - Frontal Cortex (BA9)                     30        25         2
# Brain - Hippocampus                              17         3         0
# Brain - Hypothalamus                              2         0         0
# Brain - Nucleus accumbens (basal ganglia)         4         1         4
# Brain - Putamen (basal ganglia)                   4         2         0
# Brain - Spinal cord (cervical c-1)               10         7         0
# Brain - Substantia nigra                          5         1         1
# Breast - Mammary Tissue                           1         0         0
# Cells - Cultured fibroblasts                    116       164        32
# Cells - EBV-transformed lymphocytes              93        64        86
# Cervix - Ectocervix                              13         5        11
# Cervix - Endocervix                              17         5         8
# Colon - Sigmoid                                   1         2         0
# Colon - Transverse                                4         4         1
# Esophagus - Gastroesophageal Junction             9         4         3
# Esophagus - Mucosa                                6         2         2
# Esophagus - Muscularis                            4         4         3
# Fallopian Tube                                    5         3         9
# Heart - Atrial Appendage                         10         2         4
# Heart - Left Ventricle                           13        14         4
# Kidney - Cortex                                   3         6         2
# Liver                                            35        19         6
# Lung                                              3         0         2
# Minor Salivary Gland                              2         0         0
# Muscle - Skeletal                                83        80        56
# Nerve - Tibial                                    1        13         1
# Ovary                                             6         2         3
# Pancreas                                         13         6        10
# Pituitary                                         2         0         0
# Prostate                                          1         0         0
# Skin - Not Sun Exposed (Suprapubic)               4         4         2
# Skin - Sun Exposed (Lower leg)                    5         2         1
# Small Intestine - Terminal Ileum                  3         3        18
# Spleen                                            2         2        11
# Stomach                                           0         1         3
# Testis                                           90       104        92
# Thyroid                                           4         1         0
# Uterus                                            5         2         4
# Vagina                                            0         0         0
#
#                                                     | dext-down |            \
#                                           0.9 - 1.0     0.0 - 0.1 0.1 - 0.2
# Tissue
# Adipose - Subcutaneous                            3           287        70
# Adipose - Visceral (Omentum)                      0           261        69
# Adrenal Gland                                     0           345        91
# Artery - Aorta                                    3           347       101
# Artery - Coronary                                 1           191        40
# Artery - Tibial                                   3           409       126
# Bladder                                           2           353       161
# Brain - Amygdala                                  1           552       138
# Brain - Anterior cingulate cortex (BA24)          1           460       144
# Brain - Caudate (basal ganglia)                   0           406        55
# Brain - Cerebellar Hemisphere                     1           839       411
# Brain - Cerebellum                                1           829       762
# Brain - Cortex                                    0           452       111
# Brain - Frontal Cortex (BA9)                      1           503       167
# Brain - Hippocampus                               0           543       155
# Brain - Hypothalamus                              0           392        74
# Brain - Nucleus accumbens (basal ganglia)         0           482       142
# Brain - Putamen (basal ganglia)                   0           551       242
# Brain - Spinal cord (cervical c-1)                2           466       176
# Brain - Substantia nigra                          1           495       206
# Breast - Mammary Tissue                           0           180        23
# Cells - Cultured fibroblasts                     49           920       550
# Cells - EBV-transformed lymphocytes              45          1311       613
# Cervix - Ectocervix                               8           421       171
# Cervix - Endocervix                              12           457       202
# Colon - Sigmoid                                   0           285        72
# Colon - Transverse                                5           199        59
# Esophagus - Gastroesophageal Junction             1           247        51
# Esophagus - Mucosa                                0           400        87
# Esophagus - Muscularis                            0           288        57
# Fallopian Tube                                    8           371       144
# Heart - Atrial Appendage                          1           402       117
# Heart - Left Ventricle                            6           707       219
# Kidney - Cortex                                   2           445        81
# Liver                                            17          1507      1024
# Lung                                              8           317        66
# Minor Salivary Gland                              0           291        53
# Muscle - Skeletal                               131           914       400
# Nerve - Tibial                                    5           398       208
# Ovary                                             1           618       244
# Pancreas                                          6           897       225
# Pituitary                                         0           465       205
# Prostate                                          0           232        73
# Skin - Not Sun Exposed (Suprapubic)               0           481       170
# Skin - Sun Exposed (Lower leg)                    0           505       213
# Small Intestine - Terminal Ileum                  2           253        64
# Spleen                                            7           713       271
# Stomach                                           0           327        59
# Testis                                           50           735       644
# Thyroid                                           0           300        79
# Uterus                                            5           284        75
# Vagina                                            0           251        52
#
#                                                                          \
#                                           0.2 - 0.3 0.3 - 0.4 0.4 - 0.5
# Tissue
# Adipose - Subcutaneous                          130        15         4
# Adipose - Visceral (Omentum)                     35         8         2
# Adrenal Gland                                    65        25         8
# Artery - Aorta                                   42        32         9
# Artery - Coronary                                29        14         1
# Artery - Tibial                                 123        19         9
# Bladder                                         126        45        12
# Brain - Amygdala                                 97        57        12
# Brain - Anterior cingulate cortex (BA24)         52        46        14
# Brain - Caudate (basal ganglia)                  51        23         2
# Brain - Cerebellar Hemisphere                   216       178       129
# Brain - Cerebellum                              533       303       114
# Brain - Cortex                                   53        26        19
# Brain - Frontal Cortex (BA9)                     93        60        64
# Brain - Hippocampus                              49        41        10
# Brain - Hypothalamus                             58        11         6
# Brain - Nucleus accumbens (basal ganglia)        66        42         8
# Brain - Putamen (basal ganglia)                 171        84        13
# Brain - Spinal cord (cervical c-1)               89        67        36
# Brain - Substantia nigra                         76        28        19
# Breast - Mammary Tissue                          28        12         2
# Cells - Cultured fibroblasts                    399       253       114
# Cells - EBV-transformed lymphocytes             452       334       141
# Cervix - Ectocervix                              58        81        15
# Cervix - Endocervix                             116        88        16
# Colon - Sigmoid                                  94        15         2
# Colon - Transverse                               90        13         4
# Esophagus - Gastroesophageal Junction            86        24        14
# Esophagus - Mucosa                               99        25        16
# Esophagus - Muscularis                           97        15         1
# Fallopian Tube                                   42        46        35
# Heart - Atrial Appendage                         84        12         3
# Heart - Left Ventricle                          109        65        37
# Kidney - Cortex                                  42        42        13
# Liver                                           520       207       119
# Lung                                             24        15         7
# Minor Salivary Gland                             36        18         7
# Muscle - Skeletal                               266       148        74
# Nerve - Tibial                                   62        29        11
# Ovary                                            66        27        18
# Pancreas                                        179        33        24
# Pituitary                                        89        44        10
# Prostate                                         38        10         4
# Skin - Not Sun Exposed (Suprapubic)              98        29        13
# Skin - Sun Exposed (Lower leg)                  136        18        14
# Small Intestine - Terminal Ileum                 31         5         5
# Spleen                                          137        64        23
# Stomach                                          89        15         3
# Testis                                          573       462       424
# Thyroid                                          21        25         6
# Uterus                                           33        10         6
# Vagina                                           14        27         4
#
#                                                                          \
#                                           0.5 - 0.6 0.6 - 0.7 0.7 - 0.8
# Tissue
# Adipose - Subcutaneous                           13         2         9
# Adipose - Visceral (Omentum)                      2         6         0
# Adrenal Gland                                    13         9         0
# Artery - Aorta                                    7        14         2
# Artery - Coronary                                 1         1         4
# Artery - Tibial                                   8         7         6
# Bladder                                           7         4         4
# Brain - Amygdala                                  6         4         8
# Brain - Anterior cingulate cortex (BA24)          7         2         8
# Brain - Caudate (basal ganglia)                   7         4         6
# Brain - Cerebellar Hemisphere                    91        34        26
# Brain - Cerebellum                               76        29        25
# Brain - Cortex                                   11         0         3
# Brain - Frontal Cortex (BA9)                     26       165         4
# Brain - Hippocampus                               3         4         7
# Brain - Hypothalamus                              1         0         3
# Brain - Nucleus accumbens (basal ganglia)         4         2         4
# Brain - Putamen (basal ganglia)                  18         5         8
# Brain - Spinal cord (cervical c-1)               16        15        21
# Brain - Substantia nigra                          4         3         4
# Breast - Mammary Tissue                           2         1         1
# Cells - Cultured fibroblasts                     94        59        42
# Cells - EBV-transformed lymphocytes             224        85        88
# Cervix - Ectocervix                               9         6        15
# Cervix - Endocervix                              19        14         7
# Colon - Sigmoid                                   2         1         0
# Colon - Transverse                                4         1         4
# Esophagus - Gastroesophageal Junction             2         3         3
# Esophagus - Mucosa                               18        14         2
# Esophagus - Muscularis                            2         2         3
# Fallopian Tube                                   11        12         7
# Heart - Atrial Appendage                         10         5         4
# Heart - Left Ventricle                           42        19        13
# Kidney - Cortex                                  15        11        13
# Liver                                           110        39        33
# Lung                                              3        10         3
# Minor Salivary Gland                              7         3         2
# Muscle - Skeletal                                90        37        35
# Nerve - Tibial                                    7         6        13
# Ovary                                            14         7        20
# Pancreas                                         30        17        11
# Pituitary                                        16         3         5
# Prostate                                          6         0         0
# Skin - Not Sun Exposed (Suprapubic)               8         2        12
# Skin - Sun Exposed (Lower leg)                    6         6        12
# Small Intestine - Terminal Ileum                 11         9         0
# Spleen                                           16        19         5
# Stomach                                          10         3         0
# Testis                                          282       224       251
# Thyroid                                           4         1         9
# Uterus                                            5         4         2
# Vagina                                            1         1         0
#
#
#                                           0.8 - 0.9 0.9 - 1.0
# Tissue
# Adipose - Subcutaneous                            0         4
# Adipose - Visceral (Omentum)                      0         4
# Adrenal Gland                                     0         0
# Artery - Aorta                                    3         0
# Artery - Coronary                                 1         0
# Artery - Tibial                                   3         5
# Bladder                                          10         1
# Brain - Amygdala                                  1         3
# Brain - Anterior cingulate cortex (BA24)          1         0
# Brain - Caudate (basal ganglia)                   1         0
# Brain - Cerebellar Hemisphere                    12         2
# Brain - Cerebellum                                9        11
# Brain - Cortex                                    2         0
# Brain - Frontal Cortex (BA9)                      1         0
# Brain - Hippocampus                               1         0
# Brain - Hypothalamus                              1         0
# Brain - Nucleus accumbens (basal ganglia)         1         0
# Brain - Putamen (basal ganglia)                   5         0
# Brain - Spinal cord (cervical c-1)                3         4
# Brain - Substantia nigra                          2         0
# Breast - Mammary Tissue                           0         0
# Cells - Cultured fibroblasts                     29        20
# Cells - EBV-transformed lymphocytes              85       154
# Cervix - Ectocervix                               9         4
# Cervix - Endocervix                              10        15
# Colon - Sigmoid                                   1         0
# Colon - Transverse                                0         0
# Esophagus - Gastroesophageal Junction             1         0
# Esophagus - Mucosa                                3         0
# Esophagus - Muscularis                            1         0
# Fallopian Tube                                    8        17
# Heart - Atrial Appendage                          5         0
# Heart - Left Ventricle                            7         9
# Kidney - Cortex                                   1         0
# Liver                                            25         9
# Lung                                              0         4
# Minor Salivary Gland                              0         0
# Muscle - Skeletal                                28        38
# Nerve - Tibial                                    3         1
# Ovary                                             8         1
# Pancreas                                          1         1
# Pituitary                                         3         6
# Prostate                                          0         2
# Skin - Not Sun Exposed (Suprapubic)               2         0
# Skin - Sun Exposed (Lower leg)                    3         0
# Small Intestine - Terminal Ileum                  3         0
# Spleen                                            8         5
# Stomach                                           1         0
# Testis                                          266       209
# Thyroid                                           3         0
# Uterus                                            0         5
# Vagina                                            0         0

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

output_path = yaml['4_DEXT']['Figures_data']['dext_distribution']
        
        
plt.rcParams.update({'font.size': 20})

f, ax = plt.subplots(figsize=(16,12))        
dext['dext_bins_down'].value_counts().sort_index().plot.bar(alpha=1, color='#E64B35FF', width=-0.4, align='edge')
# dext.dext_median.plot.hist(alpha=0.3, color='g', rwidth=0.8)
dext['dext_bins_up'].value_counts().sort_index().plot.bar(alpha=1, width=0.4, color='#3C5488FF', align='edge')


plt.legend()
# ax2.set_ylim(ax.get_ylim())
ax.set_xlim(-0.5,9.65)

show_values_on_bars(ax)
# plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9)
plt.tight_layout()

ax.set_xlabel('dext-up & down (abs)', labelpad=20)
ax.set_ylabel('Exons count', labelpad=20)
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)
L=plt.legend()
L.get_texts()[0].set_text('dext-down')
L.get_texts()[1].set_text('dext-up')
# ax.set_xticks(np.arange(0.5,1,0.05))
print(list(ax.get_xticklabels()))
# ax.set_xticklabels([str(e) for e in np.arange(0.5,1.05,0.05)])

ax2 = ax.twinx()

tmp_cumsum_df = pd.concat([pd.DataFrame(dext['dext_bins_down'].value_counts().sort_index()), pd.DataFrame(dext['dext_bins_up'].value_counts().sort_index())], axis=1)
tmp_cumsum_df['Cumsum_down'] = (tmp_cumsum_df['dext_bins_down'].sum() - tmp_cumsum_df['dext_bins_down'].cumsum()) / tmp_cumsum_df['dext_bins_down'].sum()
tmp_cumsum_df['Cumsum_up'] = (tmp_cumsum_df['dext_bins_up'].sum() - tmp_cumsum_df['dext_bins_up'].cumsum()) / tmp_cumsum_df['dext_bins_up'].sum()
tmp_cumsum_df.Cumsum_down.plot.line(color='#E64B35FF', alpha=0.5, ax=ax2)
tmp_cumsum_df.Cumsum_up.plot.line(color='#3C5488FF', alpha=0.5, ax=ax2)
# ax2.spines['right'].set_linewidth(0)
ax2.spines['top'].set_linewidth(0)
axh = ax2.axhline(0.05, color='black', linestyle='--', lw=1, alpha=0.3)
ax2.set_ylabel('Invert cumsum ratio (line)', labelpad=20)

tmp_cumsum_df.to_excel(output_path)

handles, labels = ax.get_legend_handles_labels()
ax.legend().remove()

plt.legend(handles=handles + 
           [ 
               Line2D([0], [0], color='black', lw=1, ls='--'), 
               Line2D([0], [0], color='#E64B35FF', lw=1), 
               Line2D([0], [0], color='#3C5488FF', lw=1), 
           ], 
           labels=[
               '| dext-down |', 
               'dext-up', 
               'Top 5% of most\ndifferentially expressed', 
               'Invert cumsum ratio (down)', 
               'Invert cumsum ratio (up)'
           ], 
           loc='upper center')

plt.tight_layout()
output_figure(f, output_path.replace('.xlsx', ''))
# Out:
# Rectangle(xy=(0, 0), width=-0.4, height=10254, angle=0)
# Rectangle(xy=(1, 0), width=-0.4, height=8097, angle=0)
# Rectangle(xy=(2, 0), width=-0.4, height=4507, angle=0)
# Rectangle(xy=(3, 0), width=-0.4, height=2841, angle=0)
# Rectangle(xy=(4, 0), width=-0.4, height=1616, angle=0)
# Rectangle(xy=(5, 0), width=-0.4, height=1258, angle=0)
# Rectangle(xy=(6, 0), width=-0.4, height=912, angle=0)
# Rectangle(xy=(7, 0), width=-0.4, height=647, angle=0)
# Rectangle(xy=(8, 0), width=-0.4, height=544, angle=0)
# Rectangle(xy=(9, 0), width=-0.4, height=568, angle=0)
# Rectangle(xy=(0, 0), width=0.4, height=9422, angle=0)
# Rectangle(xy=(1, 0), width=0.4, height=8022, angle=0)
# Rectangle(xy=(2, 0), width=0.4, height=5235, angle=0)
# Rectangle(xy=(3, 0), width=0.4, height=3143, angle=0)
# Rectangle(xy=(4, 0), width=0.4, height=1970, angle=0)
# Rectangle(xy=(5, 0), width=0.4, height=1122, angle=0)
# Rectangle(xy=(6, 0), width=0.4, height=758, angle=0)
# Rectangle(xy=(7, 0), width=0.4, height=680, angle=0)
# Rectangle(xy=(8, 0), width=0.4, height=432, angle=0)
# Rectangle(xy=(9, 0), width=0.4, height=398, angle=0)
# [Text(0, 0, '0.0 - 0.1'), Text(1, 0, '0.1 - 0.2'), Text(2, 0, '0.2 - 0.3'), Text(3, 0, '0.3 - 0.4'), Text(4, 0, '0.4 - 0.5'), Text(5, 0, '0.5 - 0.6'), Text(6, 0, '0.6 - 0.7'), Text(7, 0, '0.7 - 0.8'), Text(8, 0, '0.8 - 0.9'), Text(9, 0, '0.9 - 1.0')]
# /gstock/EXOTIC/clean/FIGURES/3_EXPRESSION/dext_distribution

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors']).set_index('Tissue')

l = list()
col = 'up'
l.append(dext.loc[dext['dext_{}'.format(col)] > 0.6].explode('dext_tissues_{}'.format(col))['dext_tissues_{}'.format(col)].value_counts())
col = 'down'
l.append(dext.loc[dext['dext_{}'.format(col)] < -0.6].explode('dext_tissues_{}'.format(col))['dext_tissues_{}'.format(col)].value_counts())
concat_up_down = pd.concat(l, axis=1).fillna(0).sort_index().astype(int)
concat_up_down['Total'] = concat_up_down.sum(axis=1)
concat_up_down = pd.merge(gtex_colors, concat_up_down, left_index=True, right_index=True).reset_index().rename({'index' : 'Tissue'}, axis=1)
concat_up_down['group'] = 'A'
concat_up_down['log_value'] = concat_up_down['Total'].apply(np.log10)
concat_up_down.to_excel(yaml['4_DEXT']['Figures_data']['dext_circular_barplot'], index=False)
concat_up_down
# Out:
#                                        Tissue    Abbrev    Color  Samples  \
# 0                      Adipose - Subcutaneous   ADPSBQ   #FF6600    581.0
# 1                Adipose - Visceral (Omentum)   ADPVSC   #FFAA00    469.0
# 2                               Adrenal Gland   ADRNLG   #33DD33    233.0
# 3                              Artery - Aorta  ARTAORT   #FF5555    387.0
# 4                           Artery - Coronary   ARTCRN   #FFAA99    213.0
# 5                             Artery - Tibial   ARTTBL   #FF0000    584.0
# 6                                     Bladder   BLADDER  #A90000      NaN
# 7                            Brain - Amygdala   BRNAMY   #EEEE00    129.0
# 8    Brain - Anterior cingulate cortex (BA24)   BRNACC   #EEEE00    147.0
# 9             Brain - Caudate (basal ganglia)   BRNCDT   #EEEE00    194.0
# 10              Brain - Cerebellar Hemisphere   BRNCHB   #EEEE00    175.0
# 11                         Brain - Cerebellum   BRNCHA   #EEEE00    209.0
# 12                             Brain - Cortex  BRNCTXA   #EEEE00    205.0
# 13               Brain - Frontal Cortex (BA9)  BRNCTXB   #EEEE00    175.0
# 14                        Brain - Hippocampus   BRNHPP   #EEEE00    165.0
# 15                       Brain - Hypothalamus   BRNHPT   #EEEE00    170.0
# 16  Brain - Nucleus accumbens (basal ganglia)   BRNNCC   #EEEE00    202.0
# 17            Brain - Putamen (basal ganglia)   BRNPTM   #EEEE00    170.0
# 18         Brain - Spinal cord (cervical c-1)   BRNSPC   #EEEE00    126.0
# 19                   Brain - Substantia nigra   BRNSNG   #EEEE00    114.0
# 20                    Breast - Mammary Tissue   BREAST   #33CCCC    396.0
# 21               Cells - Cultured fibroblasts  FIBRBLS   #AAEEFF    483.0
# 22        Cells - EBV-transformed lymphocytes      LCL   #CC66FF    147.0
# 23                        Cervix - Ectocervix   CERVECT  #FFCCCC      NaN
# 24                        Cervix - Endocervix   CERVEND  #CCAADD      NaN
# 25                            Colon - Sigmoid   CLNSGM   #EEBB77    318.0
# 26                         Colon - Transverse   CLNTRN   #CC9955    368.0
# 27      Esophagus - Gastroesophageal Junction   ESPGEJ   #8B7355    330.0
# 28                         Esophagus - Mucosa   ESPMCS   #552200    497.0
# 29                     Esophagus - Muscularis   ESPMSL   #BB9988    465.0
# 30                             Fallopian Tube    FALLOP  #FFCCCC      NaN
# 31                   Heart - Atrial Appendage    HRTAA   #9900FF    372.0
# 32                     Heart - Left Ventricle    HRTLV   #660099    386.0
# 33                            Kidney - Cortex   KDNCTX   #22FFDD     73.0
# 34                                      Liver    LIVER   #AABB66    208.0
# 35                                       Lung     LUNG   #99FF00    515.0
# 36                       Minor Salivary Gland   SLVRYG   #99BB88    144.0
# 37                          Muscle - Skeletal   MSCLSK   #AAAAFF    706.0
# 38                             Nerve - Tibial   NERVET   #FFD700    532.0
# 39                                      Ovary    OVARY   #FFAAFF    167.0
# 40                                   Pancreas  PNCREAS   #995522    305.0
# 41                                  Pituitary   PTTARY   #AAFF99    237.0
# 42                                   Prostate   PRSTTE   #DDDDDD    221.0
# 43        Skin - Not Sun Exposed (Suprapubic)   SKINNS   #0000FF    517.0
# 44             Skin - Sun Exposed (Lower leg)    SKINS   #7777FF    605.0
# 45           Small Intestine - Terminal Ileum   SNTTRM   #555522    174.0
# 46                                     Spleen   SPLEEN   #778855    227.0
# 47                                    Stomach   STMACH   #FFDD99    324.0
# 48                                     Testis   TESTIS   #AAAAAA    322.0
# 49                                    Thyroid  THYROID   #006600    574.0
# 50                                     Uterus   UTERUS   #FF66FF    129.0
# 51                                     Vagina   VAGINA   #FF5599    141.0
#
#     dext_tissues_up  dext_tissues_down  Total group  log_value
# 0                28                 15     43     A   1.633468
# 1                 4                 10     14     A   1.146128
# 2                10                  9     19     A   1.278754
# 3                31                 19     50     A   1.698970
# 4                21                  6     27     A   1.431364
# 5                50                 21     71     A   1.851258
# 6                24                 19     43     A   1.633468
# 7                13                 16     29     A   1.462398
# 8                25                 11     36     A   1.556303
# 9                 9                 11     20     A   1.301030
# 10              215                 74    289     A   2.460898
# 11               72                 74    146     A   2.164353
# 12               13                  5     18     A   1.255273
# 13               58                170    228     A   2.357935
# 14               20                 12     32     A   1.505150
# 15                2                  4      6     A   0.778151
# 16                9                  7     16     A   1.204120
# 17                6                 18     24     A   1.380211
# 18               19                 43     62     A   1.792392
# 19                8                  9     17     A   1.230449
# 20                1                  2      3     A   0.477121
# 21              361                150    511     A   2.708421
# 22              288                412    700     A   2.845098
# 23               37                 34     71     A   1.851258
# 24               42                 46     88     A   1.944483
# 25                3                  2      5     A   0.698970
# 26               14                  5     19     A   1.278754
# 27               17                  7     24     A   1.380211
# 28               10                 19     29     A   1.462398
# 29               11                  6     17     A   1.230449
# 30               25                 44     69     A   1.838849
# 31               17                 14     31     A   1.491362
# 32               37                 48     85     A   1.929419
# 33               13                 25     38     A   1.579784
# 34               77                106    183     A   2.262451
# 35               13                 17     30     A   1.477121
# 36                2                  5      7     A   0.845098
# 37              350                138    488     A   2.688420
# 38               20                 23     43     A   1.633468
# 39               12                 36     48     A   1.681241
# 40               35                 30     65     A   1.812913
# 41                2                 17     19     A   1.278754
# 42                1                  2      3     A   0.477121
# 43               10                 16     26     A   1.414973
# 44                8                 21     29     A   1.462398
# 45               26                 12     38     A   1.579784
# 46               22                 37     59     A   1.770852
# 47                4                  4      8     A   0.903090
# 48              336                950   1286     A   3.109241
# 49                5                 13     18     A   1.255273
# 50               16                 11     27     A   1.431364
# 51                0                  1      1     A   0.000000

# %%
col = 'up'

dext.loc[dext['dext_{}'.format(col)] > 0.6].explode('dext_tissues_{}'.format(col)).groupby('dext_tissues_{}'.format(col))['Gene'].nunique()
# Out:
# dext_tissues_up
# Adipose - Subcutaneous                         6
# Adipose - Visceral (Omentum)                   2
# Adrenal Gland                                  7
# Artery - Aorta                                10
# Artery - Coronary                              4
# Artery - Tibial                               15
# Bladder                                       15
# Brain - Amygdala                               6
# Brain - Anterior cingulate cortex (BA24)       5
# Brain - Caudate (basal ganglia)                4
# Brain - Cerebellar Hemisphere                 85
# Brain - Cerebellum                            14
# Brain - Cortex                                 7
# Brain - Frontal Cortex (BA9)                  29
# Brain - Hippocampus                            5
# Brain - Hypothalamus                           2
# Brain - Nucleus accumbens (basal ganglia)      6
# Brain - Putamen (basal ganglia)                5
# Brain - Spinal cord (cervical c-1)            14
# Brain - Substantia nigra                       7
# Breast - Mammary Tissue                        1
# Cells - Cultured fibroblasts                 100
# Cells - EBV-transformed lymphocytes          121
# Cervix - Ectocervix                           21
# Cervix - Endocervix                           24
# Colon - Sigmoid                                2
# Colon - Transverse                             7
# Esophagus - Gastroesophageal Junction          7
# Esophagus - Mucosa                             8
# Esophagus - Muscularis                         6
# Fallopian Tube                                15
# Heart - Atrial Appendage                       8
# Heart - Left Ventricle                        25
# Kidney - Cortex                                7
# Liver                                         32
# Lung                                           5
# Minor Salivary Gland                           2
# Muscle - Skeletal                            132
# Nerve - Tibial                                 5
# Ovary                                          8
# Pancreas                                      15
# Pituitary                                      2
# Prostate                                       1
# Skin - Not Sun Exposed (Suprapubic)            5
# Skin - Sun Exposed (Lower leg)                 5
# Small Intestine - Terminal Ileum               7
# Spleen                                        12
# Stomach                                        3
# Testis                                       188
# Thyroid                                        3
# Uterus                                        12
# Name: Gene, dtype: int64

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors']).set_index('Tissue')

l = list()
col = 'up'
l.append(dext.loc[dext['dext_{}'.format(col)] > 0.6].explode('dext_tissues_{}'.format(col)).groupby('dext_tissues_{}'.format(col))['Gene'].nunique())
col = 'down'
l.append(dext.loc[dext['dext_{}'.format(col)] < -0.6].explode('dext_tissues_{}'.format(col)).groupby('dext_tissues_{}'.format(col))['Gene'].nunique())
concat_up_down = pd.concat(l, axis=1).fillna(0).sort_index().astype(int)

concat_up_down['Total'] = concat_up_down.sum(axis=1)
concat_up_down = pd.merge(gtex_colors, concat_up_down, left_index=True, right_index=True).reset_index().rename({'index' : 'Tissue'}, axis=1)
concat_up_down['group'] = 'A'
concat_up_down['log_value'] = concat_up_down['Total'].apply(np.log10)
concat_up_down.to_excel(yaml['4_DEXT']['Figures_data']['dext_circular_barplot_genes'], index=False)
concat_up_down
# Out:
#                                        Tissue    Abbrev    Color  Samples  \
# 0                      Adipose - Subcutaneous   ADPSBQ   #FF6600    581.0
# 1                Adipose - Visceral (Omentum)   ADPVSC   #FFAA00    469.0
# 2                               Adrenal Gland   ADRNLG   #33DD33    233.0
# 3                              Artery - Aorta  ARTAORT   #FF5555    387.0
# 4                           Artery - Coronary   ARTCRN   #FFAA99    213.0
# 5                             Artery - Tibial   ARTTBL   #FF0000    584.0
# 6                                     Bladder   BLADDER  #A90000      NaN
# 7                            Brain - Amygdala   BRNAMY   #EEEE00    129.0
# 8    Brain - Anterior cingulate cortex (BA24)   BRNACC   #EEEE00    147.0
# 9             Brain - Caudate (basal ganglia)   BRNCDT   #EEEE00    194.0
# 10              Brain - Cerebellar Hemisphere   BRNCHB   #EEEE00    175.0
# 11                         Brain - Cerebellum   BRNCHA   #EEEE00    209.0
# 12                             Brain - Cortex  BRNCTXA   #EEEE00    205.0
# 13               Brain - Frontal Cortex (BA9)  BRNCTXB   #EEEE00    175.0
# 14                        Brain - Hippocampus   BRNHPP   #EEEE00    165.0
# 15                       Brain - Hypothalamus   BRNHPT   #EEEE00    170.0
# 16  Brain - Nucleus accumbens (basal ganglia)   BRNNCC   #EEEE00    202.0
# 17            Brain - Putamen (basal ganglia)   BRNPTM   #EEEE00    170.0
# 18         Brain - Spinal cord (cervical c-1)   BRNSPC   #EEEE00    126.0
# 19                   Brain - Substantia nigra   BRNSNG   #EEEE00    114.0
# 20                    Breast - Mammary Tissue   BREAST   #33CCCC    396.0
# 21               Cells - Cultured fibroblasts  FIBRBLS   #AAEEFF    483.0
# 22        Cells - EBV-transformed lymphocytes      LCL   #CC66FF    147.0
# 23                        Cervix - Ectocervix   CERVECT  #FFCCCC      NaN
# 24                        Cervix - Endocervix   CERVEND  #CCAADD      NaN
# 25                            Colon - Sigmoid   CLNSGM   #EEBB77    318.0
# 26                         Colon - Transverse   CLNTRN   #CC9955    368.0
# 27      Esophagus - Gastroesophageal Junction   ESPGEJ   #8B7355    330.0
# 28                         Esophagus - Mucosa   ESPMCS   #552200    497.0
# 29                     Esophagus - Muscularis   ESPMSL   #BB9988    465.0
# 30                             Fallopian Tube    FALLOP  #FFCCCC      NaN
# 31                   Heart - Atrial Appendage    HRTAA   #9900FF    372.0
# 32                     Heart - Left Ventricle    HRTLV   #660099    386.0
# 33                            Kidney - Cortex   KDNCTX   #22FFDD     73.0
# 34                                      Liver    LIVER   #AABB66    208.0
# 35                                       Lung     LUNG   #99FF00    515.0
# 36                       Minor Salivary Gland   SLVRYG   #99BB88    144.0
# 37                          Muscle - Skeletal   MSCLSK   #AAAAFF    706.0
# 38                             Nerve - Tibial   NERVET   #FFD700    532.0
# 39                                      Ovary    OVARY   #FFAAFF    167.0
# 40                                   Pancreas  PNCREAS   #995522    305.0
# 41                                  Pituitary   PTTARY   #AAFF99    237.0
# 42                                   Prostate   PRSTTE   #DDDDDD    221.0
# 43        Skin - Not Sun Exposed (Suprapubic)   SKINNS   #0000FF    517.0
# 44             Skin - Sun Exposed (Lower leg)    SKINS   #7777FF    605.0
# 45           Small Intestine - Terminal Ileum   SNTTRM   #555522    174.0
# 46                                     Spleen   SPLEEN   #778855    227.0
# 47                                    Stomach   STMACH   #FFDD99    324.0
# 48                                     Testis   TESTIS   #AAAAAA    322.0
# 49                                    Thyroid  THYROID   #006600    574.0
# 50                                     Uterus   UTERUS   #FF66FF    129.0
# 51                                     Vagina   VAGINA   #FF5599    141.0
#
#     Gene  Gene  Total group  log_value
# 0      6     6     12     A   1.079181
# 1      2     4      6     A   0.778151
# 2      7     1      8     A   0.903090
# 3     10     8     18     A   1.255273
# 4      4     3      7     A   0.845098
# 5     15     9     24     A   1.380211
# 6     15    15     30     A   1.477121
# 7      6     9     15     A   1.176091
# 8      5     6     11     A   1.041393
# 9      4     6     10     A   1.000000
# 10    85    45    130     A   2.113943
# 11    14    38     52     A   1.716003
# 12     7     4     11     A   1.041393
# 13    29     9     38     A   1.579784
# 14     5     7     12     A   1.079181
# 15     2     4      6     A   0.778151
# 16     6     3      9     A   0.954243
# 17     5     8     13     A   1.113943
# 18    14    12     26     A   1.414973
# 19     7     5     12     A   1.079181
# 20     1     2      3     A   0.477121
# 21   100    69    169     A   2.227887
# 22   121   151    272     A   2.434569
# 23    21    27     48     A   1.681241
# 24    24    26     50     A   1.698970
# 25     2     2      4     A   0.602060
# 26     7     2      9     A   0.954243
# 27     7     4     11     A   1.041393
# 28     8    14     22     A   1.342423
# 29     6     3      9     A   0.954243
# 30    15    19     34     A   1.531479
# 31     8     5     13     A   1.113943
# 32    25    22     47     A   1.672098
# 33     7    10     17     A   1.230449
# 34    32    52     84     A   1.924279
# 35     5     5     10     A   1.000000
# 36     2     4      6     A   0.778151
# 37   132    67    199     A   2.298853
# 38     5    10     15     A   1.176091
# 39     8    13     21     A   1.322219
# 40    15    16     31     A   1.491362
# 41     2     6      8     A   0.903090
# 42     1     1      2     A   0.301030
# 43     5     7     12     A   1.079181
# 44     5     9     14     A   1.146128
# 45     7     6     13     A   1.113943
# 46    12    19     31     A   1.491362
# 47     3     2      5     A   0.698970
# 48   188   333    521     A   2.716838
# 49     3     5      8     A   0.903090
# 50    12     4     16     A   1.204120
# 51     0     1      1     A   0.000000

# %%
yaml = load_config_file(config_file="../../clean/src/config_clean_clean.yaml")

gtex_colors = pd.read_excel(yaml['4_DEXT']['External']['gtex_colors'])

l = list()
col = 'up'
l.append(dext.loc[dext['dext_{}'.format(col)] > 0.6].explode('dext_tissues_{}'.format(col))['dext_tissues_{}'.format(col)].value_counts())
col = 'down'
l.append(dext.loc[dext['dext_{}'.format(col)] < -0.6].explode('dext_tissues_{}'.format(col))['dext_tissues_{}'.format(col)].value_counts())
concat_up_down = pd.concat(l, axis=1).fillna(0).sort_index().astype(int).reset_index().rename({'index' : 'Tissue'}, axis=1)
concat_up_down['total'] = (concat_up_down['dext_tissues_up'] + concat_up_down['dext_tissues_down'])
concat_up_down['diff'] = (concat_up_down['dext_tissues_up'] - concat_up_down['dext_tissues_down']) / (concat_up_down['total'])
concat_up_down = concat_up_down.loc[concat_up_down['total'] > 10]
concat_up_down = concat_up_down.sort_values(by='diff')
concat_up_down.to_excel(yaml['4_DEXT']['Figures_data']['dext_diff_barplot'], index=False)
