# %%
import sys
import pandas as pd
import numpy as np
sys.path.append("/home/weber/PycharmProjects/EXOTIC/src")
from utils.utils import load_config_file, mkdir

yaml = load_config_file(config_file="/home/weber/PycharmProjects/EXOTIC/clean/src/config_clean_clean.yaml")

# %% [markdown]
# ### Fct to compute Odds Ratio

# %%
def stats(cat_const, cat_alt, others_const, others_alt, col, cat, ratio=None):
    odd_ratio = (cat_const/others_const) / (cat_alt/others_alt)
    se = np.sqrt((1/cat_const) + (1/others_const) + (1/cat_alt) + (1/others_alt))
    lower = np.exp(np.log(odd_ratio) - 1.96 *se)
    upper = np.exp(np.log(odd_ratio) + 1.96 *se)
    print(odd_ratio, se, lower, upper)
    d = {
            'col' : col,
            'cat' : cat,
            'ratio' : ratio,
            'OR' : odd_ratio,
            'SE' : se,
            'Lower_CI' : lower,
            'Upper_CI' : upper,
        }
    return d

def compute_odds_ratio(df, cols):
    l = list()
    for col in cols:
        print(col)
        print(df[['Const_Alt', col]].pivot(columns='Const_Alt', values=col).apply(pd.Series.value_counts))
        t = df[['Const_Alt', col]].pivot(columns='Const_Alt', values=col).apply(pd.Series.value_counts).fillna(0)
        print(t)
        for cat in df[col].unique().tolist():
            print("Cat : ", cat)
            cat_const = t.loc[cat]['Const']
            cat_alt = t.loc[cat]['Alt']
            others_const = t.loc[~t.index.isin([cat])]['Const'].sum()
            others_alt = t.loc[~t.index.isin([cat])]['Alt'].sum()
            l.append(stats(cat_const, cat_alt, others_const, others_alt, col, cat, ))
    return l


def compute_odds_ratio_alt(df, cols):
    l = list()
    for col in cols:
        print(col)
        print(df[['Ratio_num_bins_update', col]].pivot(columns='Ratio_num_bins_update', values=col).apply(pd.Series.value_counts))
        t = df[['Ratio_num_bins_update', col]].pivot(columns='Ratio_num_bins_update', values=col).apply(pd.Series.value_counts).fillna(0)
        print(t)
        for ratio in df['Ratio_num_bins_update'].unique().tolist():
            print(ratio)
            others_ratio = [c for c in df['Ratio_num_bins_update'].unique().tolist() if c != ratio]
            for cat in df[col].unique().tolist():
                print("Cat : ", cat)
                cat_ratio = t.loc[cat][ratio]
                cat_others_ratio = t.loc[cat][others_ratio]
                others_ratio = t.loc[~t.index.isin([cat])][ratio].sum()
                others_others_ratio = t.loc[~t.index.isin([cat])][others_ratio].sum()
                l.append(stats(cat_const, cat_alt, others_const, others_alt, col, cat, ))
    return l

# %%
compute_odds_ratio_alt(pd.merge(phylocsf_refseq, refseq_exons, on='MAP'), ['most_severe_consequence'])
# Out:
# most_severe_consequence
# Ratio_num_bins_update    NaN  0 - 0.2  0.2 - 0.4  0.4 - 0.6  0.6 - 0.8  \
# missense_variant       180.0    29559      94338     222004     158495
# start_lost               NaN      264        799       1198        773
# stop_gained              4.0      979       3106       6725       4520
# stop_lost                1.0      112        302        514        362
# stop_retained_variant    NaN       39        104        163         98
# synonymous_variant      96.0    12548      41484     100659      72074
#
# Ratio_num_bins_update  0.8 - 0.99     1.00
# missense_variant            35066  1296892
# start_lost                    153     3105
# stop_gained                  1067    34789
# stop_lost                      61     1802
# stop_retained_variant          17      606
# synonymous_variant          15814   629551
# Ratio_num_bins_update    NaN  0 - 0.2  0.2 - 0.4  0.4 - 0.6  0.6 - 0.8  \
# missense_variant       180.0    29559      94338     222004     158495
# start_lost               0.0      264        799       1198        773
# stop_gained              4.0      979       3106       6725       4520
# stop_lost                1.0      112        302        514        362
# stop_retained_variant    0.0       39        104        163         98
# synonymous_variant      96.0    12548      41484     100659      72074
#
# Ratio_num_bins_update  0.8 - 0.99     1.00
# missense_variant            35066  1296892
# start_lost                    153     3105
# stop_gained                  1067    34789
# stop_lost                      61     1802
# stop_retained_variant          17      606
# synonymous_variant          15814   629551
# Cat :  start_lost
# ----------------------------------------------------------
# KeyError                 Traceback (most recent call last)
# ~/.conda/envs/ExoCarto/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1963640
#
# The above exception was the direct cause of the following exception:
#
# KeyError                 Traceback (most recent call last)
# <ipython-input-33-fe29af9b7895> in <module>
# ----> 1 compute_odds_ratio_alt(pd.merge(gnomad, refseq_exons, on='MAP'), ['most_severe_consequence'])
#
# <ipython-input-32-8e52ccdbc7d7> in compute_odds_ratio_alt(df, cols)
#      46                 cat_others_ratio = t.loc[cat][others_ratio]
#      47                 others_ratio = t.loc[~t.index.isin([cat])][ratio].sum()
# ---> 48                 others_others_ratio = t.loc[~t.index.isin([cat])][others_ratio].sum()
#      49                 l.append(stats(cat_const, cat_alt, others_const, others_alt, col, cat, ))
#      50     return l
#
# ~/.conda/envs/ExoCarto/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ~/.conda/envs/ExoCarto/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 1963640

# %% [markdown]
# ## RefSeq Miso exons

# %%
refseq_exons = pd.read_parquet('/gstock/EXOTIC/data/GENOMICS/refseq_37_corrected_recomputed.parquet')
refseq_exons.loc[(refseq_exons['Const_Alt'] == 'Alt') & (refseq_exons['Ratio_num_bins'] == '0.8 - 1'), 'Ratio_num_bins_update'] = '0.8 - 0.99'
refseq_exons.loc[(refseq_exons['Const_Alt'] == 'Alt') & (refseq_exons['Ratio_num_bins'] != '0.8 - 1'), 'Ratio_num_bins_update'] = refseq_exons.loc[(refseq_exons['Const_Alt'] == 'Alt') & (refseq_exons['Ratio_num_bins'] != '0.8 - 1')]['Ratio_num_bins']
refseq_exons.loc[(refseq_exons['Const_Alt'] == 'Const') & (refseq_exons['Ratio_num_bins'] == '0.8 - 1'), 'Ratio_num_bins_update'] = '1.00'
refseq_exons['MAP'] = refseq_exons['Gene'] + '_' + refseq_exons['ranges']
refseq_exons
# Out:
#         Gene             ranges  \
# 0        A2M    9220419-9220435
# 1        A2M    9220779-9220820
# 2        A2M    9221336-9221438
# 3        A2M    9222341-9222409
# 4        A2M    9223084-9223174
# ...      ...                ...
# 178476  ZZZ3  78047461-78047576
# 178477  ZZZ3  78047664-78047811
# 178478  ZZZ3  78050202-78050340
# 178479  ZZZ3  78097535-78099039
# 178480  ZZZ3  78105134-78105156
#
#                                                mRNA_exons  mRNA_nb  Share  \
# 0       [NM_001347423, NM_001347425, NM_000014, NM_001...        4  False
# 1       [NM_001347423, NM_001347425, NM_000014, NM_001...        4  False
# 2       [NM_001347423, NM_001347425, NM_000014, NM_001...        4  False
# 3       [NM_001347423, NM_001347425, NM_000014, NM_001...        4  False
# 4       [NM_001347423, NM_001347425, NM_000014, NM_001...        4  False
# ...                                                   ...      ...    ...
# 178476                          [NM_001308237, NM_015534]        2  False
# 178477                          [NM_001308237, NM_015534]        2  False
# 178478                          [NM_001308237, NM_015534]        2  False
# 178479                                        [NM_015534]        1  False
# 178480                                     [NM_001308237]        1  False
#
#         Strand                                          mRNA_gene  \
# 0            0  [NM_001347423, NM_001347424, NM_000014, NM_001...
# 1            0  [NM_001347423, NM_001347424, NM_000014, NM_001...
# 2            0  [NM_001347423, NM_001347424, NM_000014, NM_001...
# 3            0  [NM_001347423, NM_001347424, NM_000014, NM_001...
# 4            0  [NM_001347423, NM_001347424, NM_000014, NM_001...
# ...        ...                                                ...
# 178476       0                          [NM_001308237, NM_015534]
# 178477       0                          [NM_001308237, NM_015534]
# 178478       0                          [NM_001308237, NM_015534]
# 178479       0                          [NM_001308237, NM_015534]
# 178480       0                          [NM_001308237, NM_015534]
#
#         mRNA_nb_total Ratio  Ratio_num Const_Alt Ratio_num_bins     Start  \
# 0                   4   4/4        1.0     Const        0.8 - 1   9220419
# 1                   4   4/4        1.0     Const        0.8 - 1   9220779
# 2                   4   4/4        1.0     Const        0.8 - 1   9221336
# 3                   4   4/4        1.0     Const        0.8 - 1   9222341
# 4                   4   4/4        1.0     Const        0.8 - 1   9223084
# ...               ...   ...        ...       ...            ...       ...
# 178476              2   2/2        1.0     Const        0.8 - 1  78047461
# 178477              2   2/2        1.0     Const        0.8 - 1  78047664
# 178478              2   2/2        1.0     Const        0.8 - 1  78050202
# 178479              2   1/2        0.5       Alt      0.4 - 0.6  78097535
# 178480              2   1/2        0.5       Alt      0.4 - 0.6  78105134
#
#              End  Length  CDS_count Ratio_num_bins_update  \
# 0        9220435      16         38                  1.00
# 1        9220820      41         38                  1.00
# 2        9221438     102         38                  1.00
# 3        9222409      68         38                  1.00
# 4        9223174      90         38                  1.00
# ...          ...     ...        ...                   ...
# 178476  78047576     115         12                  1.00
# 178477  78047811     147         12                  1.00
# 178478  78050340     138         12                  1.00
# 178479  78099039    1504         12             0.4 - 0.6
# 178480  78105156      22         12             0.4 - 0.6
#
#                            MAP
# 0          A2M_9220419-9220435
# 1          A2M_9220779-9220820
# 2          A2M_9221336-9221438
# 3          A2M_9222341-9222409
# 4          A2M_9223084-9223174
# ...                        ...
# 178476  ZZZ3_78047461-78047576
# 178477  ZZZ3_78047664-78047811
# 178478  ZZZ3_78050202-78050340
# 178479  ZZZ3_78097535-78099039
# 178480  ZZZ3_78105134-78105156
#
# [178481 rows x 18 columns]

# %% [markdown]
# ## PhyloCSF

# %%
phylocsf_refseq = pd.read_parquet("/gstock/EXOTIC/data/EXON_PROPERTIES/refseq_phylocsf.parquet").rename({'target' : 'phyloCSF_score'}, axis=1)
phylocsf_refseq.loc[(phylocsf_refseq['phyloCSF_score'] <= -100), 'phyloCSF_cat'] = 'Unconserved'
phylocsf_refseq.loc[(phylocsf_refseq['phyloCSF_score'] > 1000), 'phyloCSF_cat'] = 'Conserved'
phylocsf_refseq.loc[(phylocsf_refseq['phyloCSF_score'] >= -100) & (phylocsf_refseq['phyloCSF_score'] < 1000), 'phyloCSF_cat'] = 'Standard'
phylocsf_refseq = phylocsf_refseq.fillna(False)
phylocsf_refseq = phylocsf_refseq.loc[phylocsf_refseq['phyloCSF_cat'] != 'Standard']
phylocsf_refseq
# Out:
#                         interval  phyloCSF_score         start           end  \
# 57660   [10:101089145-101090717)       5643.7434  10:101089145  10:101090717
# 57662   [10:101089691-101090717)       3729.0848  10:101089691  10:101090717
# 57663   [10:101090240-101090717)       2077.2201  10:101090240  10:101090717
# 57682   [10:101458291-101458615)       1293.5257  10:101458291  10:101458615
# 57694   [10:101639568-101640118)       1125.4920  10:101639568  10:101640118
# ...                          ...             ...           ...           ...
# 110044     [Y:16734000-16734471)       1757.4552    Y:16734000    Y:16734471
# 110045     [Y:16734061-16734471)       1652.5963    Y:16734061    Y:16734471
# 110049     [Y:16941610-16942399)       3028.8020    Y:16941610    Y:16942399
# 109991       [Y:2829115-2829687)       1279.9484     Y:2829115     Y:2829687
# 109992       [Y:2829132-2829687)       1290.2635     Y:2829132     Y:2829687
#
#                                MAP    Gene phyloCSF_cat
# 57660    CNNM1_101089145-101090717   CNNM1    Conserved
# 57662    CNNM1_101089145-101090717   CNNM1    Conserved
# 57663    CNNM1_101089145-101090717   CNNM1    Conserved
# 57682   ENTPD7_101458291-101458615  ENTPD7    Conserved
# 57694    DNMBP_101639568-101640118   DNMBP    Conserved
# ...                            ...     ...          ...
# 110044    NLGN4Y_16734000-16734471  NLGN4Y    Conserved
# 110045    NLGN4Y_16734000-16734471  NLGN4Y    Conserved
# 110049    NLGN4Y_16941610-16942399  NLGN4Y    Conserved
# 109991         ZFY_2829115-2829687     ZFY    Conserved
# 109992         ZFY_2829115-2829687     ZFY    Conserved
#
# [9985 rows x 7 columns]

# %% [markdown]
# ## gnomAD

# %%
gnomad = pd.read_parquet('/gstock/EXOTIC/data/EXON_PROPERTIES/refseq_miso_gnomad_variations.parquet')
bins_af = list(reversed([1/(10 ** e) for e in list(range(0,7,1))]))

def convert_bins_into_labels(bins):
    return [" - ".join([str(bins[j]), str(bins[j+1])]) for j, e in enumerate(bins) if j <len(bins)-1]

gnomad['AF'] = gnomad['AF'].str.replace(',', '.').astype(float)
gnomad['AF_bins'] = pd.cut(gnomad['AF'], bins=bins_af, labels=convert_bins_into_labels(bins_af))
mc = ["missense_variant", "start_lost", "stop_gained", "stop_lost", "stop_retained_variant", "synonymous_variant", ]
gnomad = gnomad.loc[gnomad['most_severe_consequence'].isin(mc)]
gnomad
# Out:
#               locus    alleles        AF          rsid variant_type       end  \
# 0          1:901913  ["T","G"]  0.000012   rs759148200          snv    901913
# 1          1:901916  ["G","A"]  0.000004   rs764917347          snv    901916
# 2          1:901917  ["G","A"]  0.000004   rs774961129          snv    901917
# 3          1:901919  ["A","C"]  0.000226   rs763342668          snv    901919
# 4          1:901920  ["C","G"]  0.000004  rs1408404600          snv    901920
# ...             ...        ...       ...           ...          ...       ...
# 2810848  Y:22749975  ["C","T"]  0.000017   rs746588234          snv  22749975
# 2810849  Y:22751395  ["T","C"]  0.000015  rs1382594808          snv  22751395
# 2810850  Y:22751399  ["C","G"]  0.000015   rs762602059          snv  22751399
# 2810851  Y:22751428  ["C","T"]  0.000030  rs1158365540          snv  22751428
# 2810852  Y:22751443  ["T","C"]  0.000015   rs772483555          snv  22751443
#
#                      id most_severe_consequence                       MAP  \
# 0          1_901913_T_G              start_lost     PLEKHN1_901912-901994
# 1          1_901916_G_A        missense_variant     PLEKHN1_901912-901994
# 2          1_901917_G_A      synonymous_variant     PLEKHN1_901912-901994
# 3          1_901919_A_C        missense_variant     PLEKHN1_901912-901994
# 4          1_901920_C_G        missense_variant     PLEKHN1_901912-901994
# ...                 ...                     ...                       ...
# 2810848  Y_22749975_C_T      synonymous_variant  EIF1AY_22749910-22749991
# 2810849  Y_22751395_T_C      synonymous_variant  EIF1AY_22751370-22751461
# 2810850  Y_22751399_C_G        missense_variant  EIF1AY_22751370-22751461
# 2810851  Y_22751428_C_T      synonymous_variant  EIF1AY_22751370-22751461
# 2810852  Y_22751443_T_C      synonymous_variant  EIF1AY_22751370-22751461
#
#             Gene         AF_bins
# 0        PLEKHN1  1e-05 - 0.0001
# 1        PLEKHN1   1e-06 - 1e-05
# 2        PLEKHN1   1e-06 - 1e-05
# 3        PLEKHN1  0.0001 - 0.001
# 4        PLEKHN1   1e-06 - 1e-05
# ...          ...             ...
# 2810848   EIF1AY  1e-05 - 0.0001
# 2810849   EIF1AY  1e-05 - 0.0001
# 2810850   EIF1AY  1e-05 - 0.0001
# 2810851   EIF1AY  1e-05 - 0.0001
# 2810852   EIF1AY  1e-05 - 0.0001
#
# [2770423 rows x 11 columns]

# %% [markdown]
# ## ClinVar

# %%
clinvar = pd.read_parquet('/gstock/EXOTIC/data/EXON_PROPERTIES/refseq_clinvar_pathogenic.parquet')
clinvar['id'] = clinvar['locus.contig'] + '_' + clinvar['locus.position'].astype(str) + '_' + clinvar['alleles'].apply(lambda r: "_".join(r))

# %% [markdown]
# ## CCR data

# %%
ccr = pd.read_parquet('/gstock/EXOTIC/data/EXON_PROPERTIES/refseq_ccr_start_end.parquet')
bins = [0,20,80,90,95,100]
ccr['CCR_bins'] = pd.cut(ccr['target'], bins, labels=[" - ".join([str(bins[j]), str(bins[j+1])]) for j, e in enumerate(bins) if j <len(bins)-1], include_lowest=True)
ccr
# Out:
#                          interval     target         start           end  \
# 1953387  [10:100003848-100003856)  63.055177  10:100003848  10:100003856
# 1953388  [10:100003856-100003857)   0.000000  10:100003856  10:100003857
# 1907621  [10:100003857-100003858)   0.000000  10:100003857  10:100003858
# 1953390  [10:100003858-100003874)  71.921144  10:100003858  10:100003874
# 1907623  [10:100003874-100003875)   0.000000  10:100003874  10:100003875
# ...                           ...        ...           ...           ...
# 3526305     [X:99956953-99956958)   8.932019    X:99956953    X:99956958
# 3526306     [X:99956958-99956959)   0.000000    X:99956958    X:99956959
# 3526307     [X:99956959-99957026)  90.007142    X:99956959    X:99957026
# 3611490     [X:99957026-99957027)   0.000000    X:99957026    X:99957027
# 3611491     [X:99957027-99957034)   0.514571    X:99957027    X:99957034
#
#                                  MAP     Gene CCR_bins
# 1953387  R3HCC1L_100003848-100003915  R3HCC1L  20 - 80
# 1953388  R3HCC1L_100003848-100003915  R3HCC1L   0 - 20
# 1907621  R3HCC1L_100003848-100003915  R3HCC1L   0 - 20
# 1953390  R3HCC1L_100003848-100003915  R3HCC1L  20 - 80
# 1907623  R3HCC1L_100003848-100003915  R3HCC1L   0 - 20
# ...                              ...      ...      ...
# 3526305      SYTL4_99956924-99957033    SYTL4   0 - 20
# 3526306      SYTL4_99956924-99957033    SYTL4   0 - 20
# 3526307      SYTL4_99956924-99957033    SYTL4  90 - 95
# 3611490      SYTL4_99956924-99957033    SYTL4   0 - 20
# 3611491      SYTL4_99956924-99957033    SYTL4   0 - 20
#
# [3643388 rows x 7 columns]

# %% [markdown]
# ## Merge gnomAD & ClinVar

# %%
merge_variants = pd.concat(
    [
        gnomad.loc[~gnomad['id'].isin(clinvar.id.values.tolist())],
        clinvar.loc[~clinvar['id'].isin(gnomad.id.values.tolist())]
    ]
)
merge_variants.loc[merge_variants['CLNSIG'].isna() == True, 'Status'] = 'Benign'
merge_variants['Status'] = merge_variants['Status'].fillna('Pathogenic')
merge_variants
# Out:
#            locus    alleles        AF          rsid variant_type       end  \
# 0       1:901913  ["T","G"]  0.000012   rs759148200          snv  901913.0
# 1       1:901916  ["G","A"]  0.000004   rs764917347          snv  901916.0
# 2       1:901917  ["G","A"]  0.000004   rs774961129          snv  901917.0
# 3       1:901919  ["A","C"]  0.000226   rs763342668          snv  901919.0
# 4       1:901920  ["C","G"]  0.000004  rs1408404600          snv  901920.0
# ...          ...        ...       ...           ...          ...       ...
# 256896       NaN     [C, A]       NaN         10156          NaN       NaN
# 256897       NaN     [T, C]       NaN         10352          NaN       NaN
# 256899       NaN     [T, A]       NaN         10154          NaN       NaN
# 256900       NaN     [A, C]       NaN         10153          NaN       NaN
# 256902       NaN     [G, A]       NaN         10152          NaN       NaN
#
#                      id most_severe_consequence                     MAP  \
# 0          1_901913_T_G              start_lost   PLEKHN1_901912-901994
# 1          1_901916_G_A        missense_variant   PLEKHN1_901912-901994
# 2          1_901917_G_A      synonymous_variant   PLEKHN1_901912-901994
# 3          1_901919_A_C        missense_variant   PLEKHN1_901912-901994
# 4          1_901920_C_G        missense_variant   PLEKHN1_901912-901994
# ...                 ...                     ...                     ...
# 256896  X_154250707_C_A                     NaN  F8_154250685-154250827
# 256897  X_154250724_T_C                     NaN  F8_154250685-154250827
# 256899  X_154250739_T_A                     NaN  F8_154250685-154250827
# 256900  X_154250751_A_C                     NaN  F8_154250685-154250827
# 256902  X_154250785_G_A                     NaN  F8_154250685-154250827
#
#            Gene         AF_bins locus.contig  locus.position  ALLELEID  \
# 0       PLEKHN1  1e-05 - 0.0001          NaN             NaN       NaN
# 1       PLEKHN1   1e-06 - 1e-05          NaN             NaN       NaN
# 2       PLEKHN1   1e-06 - 1e-05          NaN             NaN       NaN
# 3       PLEKHN1  0.0001 - 0.001          NaN             NaN       NaN
# 4       PLEKHN1   1e-06 - 1e-05          NaN             NaN       NaN
# ...         ...             ...          ...             ...       ...
# 256896       F8             NaN            X     154250707.0   25195.0
# 256897       F8             NaN            X     154250724.0   25391.0
# 256899       F8             NaN            X     154250739.0   25193.0
# 256900       F8             NaN            X     154250751.0   25192.0
# 256902       F8             NaN            X     154250785.0   25191.0
#
#                                  CLNREVSTAT      CLNSIG GENEINFO           RS  \
# 0                                       NaN         NaN      NaN          NaN
# 1                                       NaN         NaN      NaN          NaN
# 2                                       NaN         NaN      NaN          NaN
# 3                                       NaN         NaN      NaN          NaN
# 4                                       NaN         NaN      NaN          NaN
# ...                                     ...         ...      ...          ...
# 256896       no_assertion_criteria_provided  Pathogenic  F8:2157  [137852379]
# 256897       no_assertion_criteria_provided  Pathogenic  F8:2157  [137852476]
# 256899       no_assertion_criteria_provided  Pathogenic  F8:2157  [137852378]
# 256900       no_assertion_criteria_provided  Pathogenic  F8:2157  [137852377]
# 256902  criteria_provided,_single_submitter  Pathogenic  F8:2157  [387906432]
#
#         RS_STARS      Status
# 0            NaN      Benign
# 1            NaN      Benign
# 2            NaN      Benign
# 3            NaN      Benign
# 4            NaN      Benign
# ...          ...         ...
# 256896       0.0  Pathogenic
# 256897       0.0  Pathogenic
# 256899       0.0  Pathogenic
# 256900       0.0  Pathogenic
# 256902       1.0  Pathogenic
#
# [2789760 rows x 20 columns]

# %%
complete_list_stats = list()
list_df = [phylocsf_refseq, gnomad, merge_variants, ccr]
list_cols = [['phyloCSF_cat'], ['most_severe_consequence', 'AF_bins'], ['Status'], ['CCR_bins']]
for df, cols in zip(list_df, list_cols):
    tmp_m = pd.merge(refseq_exons, df, on='MAP')
    complete_list_stats.extend(compute_odds_ratio(tmp_m, cols))
df_or_stat = pd.DataFrame(complete_list_stats)
# Out:
# phyloCSF_cat
# Const_Alt    NaN   Alt  Const
# Conserved      2  1711   4733
# Unconserved    1  1797   1741
# Const_Alt    NaN   Alt  Const
# Conserved      2  1711   4733
# Unconserved    1  1797   1741
# Cat :  Unconserved
# 0.35023875391069537 0.043893069916154215 0.32136728494935574 0.3817040205578104
# Cat :  Conserved
# 2.855195174246714 0.043893069916154215 2.619830932193564 3.1117044168250967
# most_severe_consequence
# Const_Alt                NaN     Alt    Const
# missense_variant       180.0  539462  1296892
# start_lost               NaN    3187     3105
# stop_gained              4.0   16397    34789
# stop_lost                1.0    1351     1802
# stop_retained_variant    NaN     421      606
# synonymous_variant      96.0  242579   629551
# Const_Alt                NaN     Alt    Const
# missense_variant       180.0  539462  1296892
# start_lost               0.0    3187     3105
# stop_gained              4.0   16397    34789
# stop_lost                1.0    1351     1802
# stop_retained_variant    0.0     421      606
# synonymous_variant      96.0  242579   629551
# Cat :  synonymous_variant
# 1.0884418749234832 0.0028708441896528854 1.0823345693142068 1.0945836423182949
# Cat :  missense_variant
# 0.9472408776510061 0.002811840928364767 0.9420347950200562 0.9524757312960455
# Cat :  stop_gained
# 0.8642811671479665 0.009566595120117063 0.8482264280579159 0.8806397810510664
# Cat :  stop_lost
# 0.5444384114937965 0.036012319262259715 0.5073345662886622 0.5842558414228686
# Cat :  start_lost
# 0.397028465421028 0.025250640222816152 0.3778573428779077 0.4171722617694635
# Cat :  stop_retained_variant
# 0.5878667207459939 0.06346034909208075 0.5191111243047623 0.6657289069339214
# AF_bins
# Const_Alt       NaN     Alt    Const
# 1e-06 - 1e-05   183  520700  1294505
# 1e-05 - 0.0001   75  229079   547997
# 0.0001 - 0.001   17   37660    87940
# 0.001 - 0.01      4   10054    23381
# 0.01 - 0.1        1    3003     6725
# 0.1 - 1.0         1    2901     6197
# Const_Alt       NaN     Alt    Const
# 1e-06 - 1e-05   183  520700  1294505
# 1e-05 - 0.0001   75  229079   547997
# 0.0001 - 0.001   17   37660    87940
# 0.001 - 0.01      4   10054    23381
# 0.01 - 0.1        1    3003     6725
# 0.1 - 1.0         1    2901     6197
# Cat :  1e-06 - 1e-05
# 1.0454734390868754 0.0027781122929808203 1.0397962021539355 1.0511816734586654
# Cat :  1e-05 - 0.0001
# 0.9683671935999355 0.0029387371867377566 0.9628055041360526 0.9739610104141087
# Cat :  0.001 - 0.01
# 0.9493602457732052 0.012000322126800723 0.9272912491716346 0.9719544717581385
# Cat :  0.0001 - 0.001
# 0.9517087687698033 0.006305786746005693 0.9400186643983359 0.9635442516804332
# Cat :  0.1 - 1.0
# 0.8721987379089559 0.02253522602837476 0.8345129534347524 0.9115863753569097
# Cat :  0.01 - 0.1
# 0.9144927734789063 0.021987696589508075 0.8759190520481056 0.9547652043755439
# Status
# Const_Alt   NaN     Alt    Const
# Benign      281  802132  1962926
# Pathogenic    2    6654    17765
# Const_Alt   NaN     Alt    Const
# Benign      281  802132  1962926
# Pathogenic    2    6654    17765
# Cat :  Benign
# 0.9165911716651426 0.014433714783707441 0.8910240858112835 0.9428918806493612
# Cat :  Pathogenic
# 1.0909989436002654 0.014433714783707441 1.0605669860167943 1.1223041171659163
# CCR_bins
# Const_Alt  NaN     Alt    Const
# 0 - 20     343  825820  1980838
# 20 - 80     73  208281   530896
# 80 - 90      1   14777    42923
# 90 - 95      1    5457    17548
# 95 - 100     2    3629    12799
# Const_Alt  NaN     Alt    Const
# 0 - 20     343  825820  1980838
# 20 - 80     73  208281   530896
# 80 - 90      1   14777    42923
# 90 - 95      1    5457    17548
# 95 - 100     2    3629    12799
# Cat :  90 - 95
# 1.3182435507075838 0.015542748298482092 1.2786903888190908 1.3590201929859016
# Cat :  0 - 20
# 0.9216472770607997 0.002771028656663815 0.9166551803190102 0.9266665607213068
# Cat :  20 - 80
# 1.0543710046285748 0.0028893862631653488 1.0484167697546907 1.0603590551700026
# Cat :  95 - 100
# 1.4456465245939014 0.018842142808086198 1.3932317429632792 1.5000332031090595
# Cat :  80 - 90
# 1.1920008817965122 0.00960844664059193 1.1697625189950471 1.214662018256783

# %%
df_or_stat
# Out:
#                         col                    cat        OR        SE  \
# 0              phyloCSF_cat            Unconserved  0.350239  0.043893
# 1              phyloCSF_cat              Conserved  2.855195  0.043893
# 2   most_severe_consequence     synonymous_variant  1.088442  0.002871
# 3   most_severe_consequence       missense_variant  0.947241  0.002812
# 4   most_severe_consequence            stop_gained  0.864281  0.009567
# 5   most_severe_consequence              stop_lost  0.544438  0.036012
# 6   most_severe_consequence             start_lost  0.397028  0.025251
# 7   most_severe_consequence  stop_retained_variant  0.587867  0.063460
# 8                   AF_bins          1e-06 - 1e-05  1.045473  0.002778
# 9                   AF_bins         1e-05 - 0.0001  0.968367  0.002939
# 10                  AF_bins           0.001 - 0.01  0.949360  0.012000
# 11                  AF_bins         0.0001 - 0.001  0.951709  0.006306
# 12                  AF_bins              0.1 - 1.0  0.872199  0.022535
# 13                  AF_bins             0.01 - 0.1  0.914493  0.021988
# 14                   Status                 Benign  0.916591  0.014434
# 15                   Status             Pathogenic  1.090999  0.014434
# 16                 CCR_bins                90 - 95  1.318244  0.015543
# 17                 CCR_bins                 0 - 20  0.921647  0.002771
# 18                 CCR_bins                20 - 80  1.054371  0.002889
# 19                 CCR_bins               95 - 100  1.445647  0.018842
# 20                 CCR_bins                80 - 90  1.192001  0.009608
#
#     Lower_CI  Upper_CI
# 0   0.321367  0.381704
# 1   2.619831  3.111704
# 2   1.082335  1.094584
# 3   0.942035  0.952476
# 4   0.848226  0.880640
# 5   0.507335  0.584256
# 6   0.377857  0.417172
# 7   0.519111  0.665729
# 8   1.039796  1.051182
# 9   0.962806  0.973961
# 10  0.927291  0.971954
# 11  0.940019  0.963544
# 12  0.834513  0.911586
# 13  0.875919  0.954765
# 14  0.891024  0.942892
# 15  1.060567  1.122304
# 16  1.278690  1.359020
# 17  0.916655  0.926667
# 18  1.048417  1.060359
# 19  1.393232  1.500033
# 20  1.169763  1.214662
